# %% [markdown]
# # GridWorld_DQN

# %%
import numpy as np
import random
import copy
import datetime
import platform
import torch
import os
import torch.nn.functional as F
from torchvision.utils import save_image
from torch.utils.tensorboard import SummaryWriter
from collections import deque
from pathlib import Path
from mlagents_envs.environment import UnityEnvironment, ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel\
                             import EngineConfigurationChannel

# %% [markdown]
# ## Setting environments

# %%
# Global Setting
cur_dir = os.getcwd()
env_dir = os.path.abspath(os.path.join(cur_dir, "..", "Unity6000_Envs"))
test_dir = os.path.abspath(os.path.join(cur_dir, "temp", "pytorch_output"))

# %% [markdown]
# ### Pytorch Device

# %%
# Pytorch Device
if torch.backends.mps.is_available():
    g_device = torch.device("mps")
elif torch.cuda.is_available():
    g_device = torch.device("cuda")
else:
    g_device = torch.device("cpu")

print(g_device)
# Out:
# mps

# %% [markdown]
# ### Unity Enviroment

# %%
# Unity Enviroment
game = "GridWorld"
os_name = platform.system()

if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# %% [markdown]
# ### Seting parameters for DQN Network

# %%
# Seting parameters for DQN Network
state_size = [3*2, 64, 84]  # Channel, Height, Width
action_size = 4

load_model = False
train_mode = True

batch_size = 32
mem_maxlen = 10000
discount_factor = 0.9
learning_rate = 0.00025

run_step = 50000 if train_mode else 0
test_step = 5000
train_start_step = 5000
target_update_step = 500

print_interval = 10
save_interval = 100

epsilon_eval = 0.05
epsilon_init = 1.0 if train_mode else epsilon_eval
epsilon_min = 0.1
explore_step = run_step * 0.8
eplsilon_delta = (epsilon_init - epsilon_min)/explore_step if train_mode else 0.

VISUAL_OBS = 0
GOAL_OBS = 1
VECTOR_OBS = 2
OBS = VISUAL_OBS

unity_base_port = 1901

# %%
# NN model : Save and Load
date_time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
save_path = os.path.join(test_dir, f"saved_models/{game}/DQN/{date_time}")
Path(save_path).mkdir(parents=True, exist_ok=True)
save_model_path = os.path.join(save_path, 'GridWrod_DQN.ckpt')
# print(f"save_path :{save_path}")
# print(f"save_model_path :{save_model_path}")
load_path = os.path.join(test_dir, f"saved_models/{game}/DQN/20210514201212") # Need to update

# %% [markdown]
# ## DQN Class

# %%
# DQN Class
class DQN(torch.nn.Module):
    def __init__(self, **kwargs):
        # super(DQN, self).__init__(**kwargs)
        super().__init__(**kwargs)
        self.conv1 = torch.nn.Conv2d(in_channels=state_size[0], out_channels=32,
                                     kernel_size=8, stride=4)
        dim1 = ((state_size[1] - 8)//4 + 1, (state_size[2] - 8)//4 + 1)
        self.conv2 = torch.nn.Conv2d(in_channels=32, out_channels=64,
                                     kernel_size=4, stride=2)
        dim2 = ((dim1[0] - 4)//2 + 1, (dim1[1] - 4)//2 + 1)
        self.conv3 = torch.nn.Conv2d(in_channels=64, out_channels=64,
                                     kernel_size=3, stride=1)
        dim3 = ((dim2[0] - 3)//1 + 1, (dim2[1] - 3)//1 + 1)

        self.flat = torch.nn.Flatten()
        self.fc1 = torch.nn.Linear(64*dim3[0]*dim3[1], 512)
        self.q = torch.nn.Linear(512, action_size)

    def forward(self, x):
        # x = x.permute(0, 3, 1, 2)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = self.flat(x)
        x = F.relu(self.fc1(x))
        return self.q(x)

# %% [markdown]
# ## DQN Agent Class

# %%
# DQNAgent Class
class DQNAgent:
    def __init__(self):
        self.network = DQN().to(g_device)
        self.target_network = copy.deepcopy(self.network)
        self.optimizer = torch.optim.Adam(self.network.parameters(), lr=learning_rate)
        self.memory = deque(maxlen=mem_maxlen)
        self.epsilon = epsilon_init
        self.writer = SummaryWriter(save_path)

        if load_model == True:
            print(f"... Load Model from {load_path} ...")
            checkpoint = torch.load(load_path, map_location=g_device)
            self.network.load_state_dict(checkpoint["network"])
            self.target_network.load_state_dict(checkpoint["network"])
            self.optimizer.load_state_dict(checkpoint["optimizer"])

    # Action based on Epsilon greedy
    def get_action(self, state, training=True):
        self.network.train(training)
        epsilon = self.epsilon if training else epsilon_eval

        # Random action
        if epsilon > random.random():
            action = np.random.randint(0, action_size, size=(state.shape[0],1))
        # Action based on neetwork output
        else:
            q = self.network(torch.FloatTensor(state).to(g_device))
            action = torch.argmax(q, axis=-1, keepdim=True).data.cpu().numpy()
        return action

    # Replay Memory (State, action, Reward, next_state, done)
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # Train model
    def train_model(self):
        batch = random.sample(self.memory, batch_size)
        state      = np.stack([b[0] for b in batch], axis=0)
        action     = np.stack([b[1] for b in batch], axis=0)
        reward     = np.stack([b[2] for b in batch], axis=0)
        next_state = np.stack([b[3] for b in batch], axis=0)
        done       = np.stack([b[4] for b in batch], axis=0)

        state, action, reward, next_state, done = map(lambda x: torch.FloatTensor(x).to(g_device),
                                                        [state, action, reward, next_state, done])

        eye = torch.eye(action_size).to(g_device)
        one_hot_action = eye[action.view(-1).long()]
        q = (self.network(state) * one_hot_action).sum(1, keepdims=True)

        with torch.no_grad():
            next_q = self.target_network(next_state)
            target_q = reward + next_q.max(1, keepdims=True).values * ((1 - done) * discount_factor)

        loss = F.smooth_l1_loss(q, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Update Epsilon
        self.epsilon = max(epsilon_min, self.epsilon - eplsilon_delta)

        return loss.item()

    # Update target Network
    def update_target(self):
        self.target_network.load_state_dict(self.network.state_dict())

    # Save Network Modelk
    def save_model(self):
        print(f"... Save Model to {save_model_path}")
        torch.save({
            "network" : self.network.state_dict(),
            "optimizer" : self.optimizer.state_dict(),
        }, save_model_path)

    # tensorboard
    def write_summray(self, score, loss, epsilon, step):
        self.writer.add_scalar("run/score", score, step)
        self.writer.add_scalar("model/loss", loss, step)
        self.writer.add_scalar("model/epsilon", epsilon, step)

# %% [markdown]
# ## Train DQN Model

# %%
engine_configuration_channel = EngineConfigurationChannel()
env = UnityEnvironment(file_name=env_name,
                        side_channels=[engine_configuration_channel],
                        base_port=unity_base_port)
env.reset()

# Setup Unitu MLAgent
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=12.0)
dec, term = env.get_steps(behavior_name)

#### Debug
img1 = (dec.obs[OBS])[0]
img2 = (dec.obs[OBS]*dec.obs[GOAL_OBS][0][0])[0]
img3 = (dec.obs[OBS]*dec.obs[GOAL_OBS][0][1])[0]
save_image(torch.FloatTensor(img1), os.path.join(save_path, "image1.png"))
save_image(torch.FloatTensor(img2), os.path.join(save_path, "image2.png"))
save_image(torch.FloatTensor(img3), os.path.join(save_path, "image3.png"))
####

# DQNAgent
agent = DQNAgent()

losses, scores, episode, score = [], [], 0, 0
for step in range(run_step + test_step):
    if step == run_step:
        if train_mode:
            agent.save_model()
        print("TEST START")
        train_mode = False
        engine_configuration_channel.set_configuration_parameters(time_scale=1.0)

    # preprocess = lambda obs, goal: np.concatenate((obs*goal[0][0], obs*goal[0][1]), axis=-1)
    preprocess = lambda obs, goal: np.concatenate((obs*goal[0][0], obs*goal[0][1]), axis=1)
    state = preprocess(dec.obs[OBS],dec.obs[GOAL_OBS])

    action = agent.get_action(state, train_mode)
    real_action = action + 1
    action_tuple = ActionTuple()
    action_tuple.add_discrete(real_action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    dec, term = env.get_steps(behavior_name)
    done = len(term.agent_id) > 0
    reward = term.reward if done else dec.reward
    next_state = preprocess(term.obs[OBS], term.obs[GOAL_OBS]) if done\
                    else preprocess(dec.obs[OBS], dec.obs[GOAL_OBS])
    score += reward[0]

    if train_mode:
        agent.append_sample(state[0], action[0], reward, next_state[0], [done])

    if train_mode and step > max(batch_size, train_start_step):
        # Training
        loss = agent.train_model()
        losses.append(loss)

        # Update Target Network
        if step % target_update_step == 0:
            agent.update_target()

    if done:
        episode +=1
        scores.append(score)
        score = 0

        # Logging record
        if episode % print_interval == 0:
            mean_score = np.mean(scores)
            mean_loss = np.mean(losses)
            agent.write_summray(mean_score, mean_loss, agent.epsilon, step)
            losses, scores = [], []

            print(f"{episode} Episode / Step: {step} / Score: {mean_score:.2f} / " +\
                    f"Loss: {mean_loss:.4f} / Epsilon: {agent.epsilon:.4f}")

        # Save Model
        if train_mode and episode % save_interval == 0:
            agent.save_model()

env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# /Users/hyunjae.k/anaconda3/envs/mlagents/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/hyunjae.k/anaconda3/envs/mlagents/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 10 Episode / Step: 201 / Score: 0.21 / Loss: nan / Epsilon: 1.0000
# 20 Episode / Step: 392 / Score: -0.18 / Loss: nan / Epsilon: 1.0000
# 30 Episode / Step: 709 / Score: -0.31 / Loss: nan / Epsilon: 1.0000
# 40 Episode / Step: 916 / Score: -0.20 / Loss: nan / Epsilon: 1.0000
# 50 Episode / Step: 1045 / Score: -0.72 / Loss: nan / Epsilon: 1.0000
# 60 Episode / Step: 1290 / Score: -0.23 / Loss: nan / Epsilon: 1.0000
# 70 Episode / Step: 1504 / Score: 0.40 / Loss: nan / Epsilon: 1.0000
# 80 Episode / Step: 1625 / Score: -0.31 / Loss: nan / Epsilon: 1.0000
# 90 Episode / Step: 1901 / Score: -0.87 / Loss: nan / Epsilon: 1.0000
# 100 Episode / Step: 2255 / Score: -0.95 / Loss: nan / Epsilon: 1.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/GridWorld/DQN/20250917140151/GridWrod_DQN.ckpt
#
ec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=1.0)
dec, term = env.get_steps(behavior_name)

# DQNAgent
agent = DQNAgent()
score = 0
score_lst = {}
episode = 0
pre_step = 0
for step in range(test_step):
    preprocess = lambda obs, goal: np.concatenate((obs*goal[0][0], obs*goal[0][1]), axis=1)
    state = preprocess(dec.obs[OBS],dec.obs[GOAL_OBS])
    action = agent.get_action(state, train_mode)
    real_action = action + 1
    action_tuple = ActionTuple()
    action_tuple.add_discrete(real_action)
    env.set_actions(behavior_name, action_tuple)
    env.step()
    dec, term = env.get_steps(behavior_name)
    done = len(term.agent_id) > 0
    reward = term.reward if done else dec.reward
    score += reward[0]
    if done:
        episode +=1
        score_lst[episode] = score
        print(f"{episode} - episode ({step - pre_step} steps) is done with the score of {score}")
        pre_step = step
        score = 0

env.close()

print(score_lst)
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# ... Load Model from /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/GridWorld/DQN/20250917140151/GridWrod_DQN.ckpt ...
# 1 - episode (2 steps) is done with the score of 0.9800000004470348
# 2 - episode (3 steps) is done with the score of 0.9800000004470348
# 3 - episode (1 steps) is done with the score of 1.0
# 4 - episode (4 steps) is done with the score of 0.9700000006705523
# 5 - episode (6 steps) is done with the score of 0.9500000011175871
# 6 - episode (2 steps) is done with the score of 0.9900000002235174
# 7 - episode (5 steps) is done with the score of 0.9600000008940697
# 8 - episode (3 steps) is done with the score of 0.9800000004470348
# 9 - episode (5 steps) is done with the score of 0.9600000008940697
# 10 - episode (2 steps) is done with the score of 0.9900000002235174
# 11 - episode (3 steps) is done with the score of 0.9800000004470348
# 12 - episode (2 steps) is done with the score of 0.9900000002235174
# 13 - episode (1 steps) is done with the score of 1.0
# 14 - episode (5 steps) is done with the score of 0.9600000008940697
# 15 - episode (3 steps) is done with the score of 0.9800000004470348
# 16 - episode (8 steps) is done with the score of 0.9300000015646219
# 17 - episode (2 steps) is done with the score of 0.9900000002235174
# 18 - episode (4 steps) is done with the score of 0.9700000006705523
# 19 - episode (4 steps) is done with the score of 0.9700000006705523
# 20 - episode (3 steps) is done with the score of 0.9800000004470348
# 21 - episode (6 steps) is done with the score of 0.9500000011175871
# 22 - episode (3 steps) is done with the score of 0.9800000004470348
# 23 - episode (3 steps) is done with the score of 0.9800000004470348
# 24 - episode (3 steps) is done with the score of 0.9800000004470348
# 25 - episode (5 steps) is done with the score of 0.9600000008940697
# 26 - episode (2 steps) is done with the score of 0.9900000002235174
# 27 - episode (4 steps) is done with the score of 0.9700000006705523
# 28 - episode (1 steps) is done with the score of 1.0
# 29 - episode (5 steps) is done with the score of 0.9600000008940697
# 30 - episode (6 steps) is done with the score of 0.9500000011175871
# 31 - episode (5 steps) is done with the score of 0.9600000008940697
# 32 - episode (3 steps) is done with the score of 0.9800000004470348
# 33 - episode (5 steps) is done with the score of 0.9600000008940697
# 34 - episode (4 steps) is done with the score of 0.9700000006705523
# 35 - episode (7 steps) is done with the score of 0.9400000013411045
# 36 - episode (3 steps) is done with the score of 0.9800000004470348
# 37 - episode (1 steps) is done with the score of 1.0
# 38 - episode (1 steps) is done with the score of 1.0
# 39 - episode (5 steps) is done with the score of 0.9600000008940697
# 40 - episode (4 steps) is done with the score of 0.9700000006705523
# 41 - episode (2 steps) is done with the score of 0.9900000002235174
# 42 - episode (3 steps) is done with the score of 0.9800000004470348
# 43 - episode (2 steps) is done with the score of 0.9900000002235174
# 44 - episode (4 steps) is done with the score of 0.9700000006705523
# 45 - episode (4 steps) is done with the score of 0.9700000006705523
# 46 - episode (7 steps) is done with the score of 0.9400000013411045
# 47 - episode (2 steps) is done with the score of 0.9900000002235174
# 48 - episode (1 steps) is done with the score of 1.0
# 49 - episode (3 steps) is done with the score of 0.9800000004470348
# 50 - episode (3 steps) is done with the score of 0.9800000004470348
# 51 - episode (1 steps) is done with the score of 1.0
# 52 - episode (6 steps) is done with the score of 0.9500000011175871
# 53 - episode (3 steps) is done with the score of 0.9800000004470348
# 54 - episode (2 steps) is done with the score of 0.9900000002235174
# 55 - episode (2 steps) is done with the score of 0.9900000002235174
# 56 - episode (3 steps) is done with the score of 0.9800000004470348
# 57 - episode (3 steps) is done with the score of 0.9800000004470348
# 58 - episode (1 steps) is done with the score of 1.0
# 59 - episode (2 steps) is done with the score of 0.9900000002235174
# 60 - episode (5 steps) is done with the score of 0.9600000008940697
# 61 - episode (4 steps) is done with the score of 0.9700000006705523
# 62 - episode (2 steps) is done with the score of 0.9900000002235174
# 63 - episode (3 steps) is done with the score of 0.9800000004470348
# 64 - episode (2 steps) is done with the score of 0.9900000002235174
# 65 - episode (1 steps) is done with the score of 1.0
# 66 - episode (2 steps) is done with the score of 0.9900000002235174
# 67 - episode (3 steps) is done with the score of 0.9800000004470348
# 68 - episode (2 steps) is done with the score of 0.9900000002235174
# 69 - episode (4 steps) is done with the score of 0.9700000006705523
# 70 - episode (1 steps) is done with the score of 1.0
# 71 - episode (4 steps) is done with the score of 0.9700000006705523
# 72 - episode (4 steps) is done with the score of 0.9700000006705523
# 73 - episode (5 steps) is done with the score of 0.9600000008940697
# 74 - episode (4 steps) is done with the score of 0.9700000006705523
# 75 - episode (6 steps) is done with the score of 0.9500000011175871
# 76 - episode (2 steps) is done with the score of 0.9900000002235174
# 77 - episode (2 steps) is done with the score of 0.9900000002235174
# 78 - episode (5 steps) is done with the score of 0.9600000008940697
# 79 - episode (3 steps) is done with the score of 0.9800000004470348
# 80 - episode (2 steps) is done with the score of 0.9900000002235174
# 81 - episode (4 steps) is done with the score of 0.9700000006705523
# 82 - episode (4 steps) is done with the score of 0.9700000006705523
# 83 - episode (1 steps) is done with the score of 1.0
# 84 - episode (4 steps) is done with the score of 0.9700000006705523
# 85 - episode (1 steps) is done with the score of 1.0
# 86 - episode (2 steps) is done with the score of 0.9900000002235174
# 87 - episode (3 steps) is done with the score of 0.9800000004470348
# 88 - episode (3 steps) is done with the score of 0.9800000004470348
# 89 - episode (4 steps) is done with the score of 0.9700000006705523
# 90 - episode (5 steps) is done with the score of 0.9600000008940697
# 91 - episode (2 steps) is done with the score of 0.9900000002235174
# 92 - episode (4 steps) is done with the score of 0.9700000006705523
# 93 - episode (2 steps) is done with the score of 0.9900000002235174
# 94 - episode (3 steps) is done with the score of 0.9800000004470348
# 95 - episode (3 steps) is done with the score of 0.9800000004470348
# 96 - episode (2 steps) is done with the score of 0.9900000002235174
# 97 - episode (3 steps) is done with the score of 0.9800000004470348
# 98 - episode (5 steps) is done with the score of 0.9600000008940697
# 99 - episode (2 steps) is done with the score of 0.9900000002235174
# 100 - episode (6 steps) is done with the score of 0.9500000011175871
# 101 - episode (4 steps) is done with the score of 0.9700000006705523
# 102 - episode (1 steps) is done with the score of 1.0
# 103 - episode (3 steps) is done with the score of 0.9800000004470348
# 104 - episode (6 steps) is done with the score of 0.9500000011175871
# 105 - episode (4 steps) is done with the score of 0.9700000006705523
# 106 - episode (1 steps) is done with the score of 1.0
# 107 - episode (2 steps) is done with the score of 0.9900000002235174
# 108 - episode (5 steps) is done with the score of 0.9600000008940697
# 109 - episode (6 steps) is done with the score of 0.9500000011175871
# 110 - episode (4 steps) is done with the score of 0.9700000006705523
# 111 - episode (5 steps) is done with the score of 0.9600000008940697
# 112 - episode (8 steps) is done with the score of 0.9300000015646219
# 113 - episode (4 steps) is done with the score of 0.9700000006705523
# 114 - episode (1 steps) is done with the score of 1.0
# 115 - episode (6 steps) is done with the score of 0.9500000011175871
# 116 - episode (4 steps) is done with the score of 0.9700000006705523
# 117 - episode (1 steps) is done with the score of 1.0
# 118 - episode (2 steps) is done with the score of 0.9900000002235174
# 119 - episode (2 steps) is done with the score of 0.9900000002235174
# 120 - episode (4 steps) is done with the score of 0.9700000006705523
# 121 - episode (4 steps) is done with the score of 0.9700000006705523
# 122 - episode (2 steps) is done with the score of 0.9900000002235174
# 123 - episode (3 steps) is done with the score of 0.9800000004470348
# 124 - episode (6 steps) is done with the score of 0.9500000011175871
# 125 - episode (7 steps) is done with the score of 0.9400000013411045
# 126 - episode (2 steps) is done with the score of 0.9900000002235174
# 127 - episode (5 steps) is done with the score of 0.9600000008940697
# 128 - episode (4 steps) is done with the score of 0.9700000006705523
# 129 - episode (2 steps) is done with the score of 0.9900000002235174
# 130 - episode (4 steps) is done with the score of 0.9700000006705523
# 131 - episode (6 steps) is done with the score of 0.9500000011175871
# 132 - episode (2 steps) is done with the score of 0.9900000002235174
# 133 - episode (4 steps) is done with the score of 0.9700000006705523
# 134 - episode (2 steps) is done with the score of 0.9900000002235174
# 135 - episode (1 steps) is done with the score of 1.0
# 136 - episode (2 steps) is done with the score of 0.9900000002235174
# 137 - episode (1 steps) is done with the score of 1.0
# 138 - episode (5 steps) is done with the score of 0.9600000008940697
# 139 - episode (3 steps) is done with the score of 0.9800000004470348
# 140 - episode (3 steps) is done with the score of 0.9800000004470348
# 141 - episode (4 steps) is done with the score of 0.9700000006705523
# 142 - episode (3 steps) is done with the score of -1.0199999995529652
# 143 - episode (3 steps) is done with the score of 0.9800000004470348
# 144 - episode (8 steps) is done with the score of 0.9300000015646219
# 145 - episode (3 steps) is done with the score of 0.9800000004470348
# 146 - episode (1 steps) is done with the score of 1.0
# 147 - episode (1 steps) is done with the score of 1.0
# 148 - episode (2 steps) is done with the score of 0.9900000002235174
# 149 - episode (4 steps) is done with the score of 0.9700000006705523
# 150 - episode (2 steps) is done with the score of 0.9900000002235174
# 151 - episode (3 steps) is done with the score of 0.9800000004470348
# 152 - episode (3 steps) is done with the score of 0.9800000004470348
# 153 - episode (5 steps) is done with the score of 0.9600000008940697
# 154 - episode (3 steps) is done with the score of 0.9800000004470348
# 155 - episode (6 steps) is done with the score of 0.9500000011175871
# 156 - episode (3 steps) is done with the score of 0.9800000004470348
# 157 - episode (4 steps) is done with the score of 0.9700000006705523
# 158 - episode (9 steps) is done with the score of 0.9200000017881393
# 159 - episode (5 steps) is done with the score of 0.9600000008940697
# 160 - episode (5 steps) is done with the score of 0.9600000008940697
# 161 - episode (6 steps) is done with the score of 0.9500000011175871
# 162 - episode (8 steps) is done with the score of 0.9300000015646219
# 163 - episode (5 steps) is done with the score of 0.9600000008940697
# 164 - episode (3 steps) is done with the score of 0.9800000004470348
# 165 - episode (2 steps) is done with the score of 0.9900000002235174
# 166 - episode (4 steps) is done with the score of 0.9700000006705523
# 167 - episode (4 steps) is done with the score of 0.9700000006705523
# 168 - episode (2 steps) is done with the score of 0.9900000002235174
# 169 - episode (6 steps) is done with the score of 0.9500000011175871
# 170 - episode (2 steps) is done with the score of 0.9900000002235174
# 171 - episode (5 steps) is done with the score of 0.9600000008940697
# 172 - episode (1 steps) is done with the score of 1.0
# 173 - episode (3 steps) is done with the score of 0.9800000004470348
# 174 - episode (2 steps) is done with the score of 0.9900000002235174
# 175 - episode (3 steps) is done with the score of 0.9800000004470348
# 176 - episode (5 steps) is done with the score of 0.9600000008940697
# 177 - episode (2 steps) is done with the score of 0.9900000002235174
# 178 - episode (1 steps) is done with the score of 1.0
# 179 - episode (1 steps) is done with the score of 1.0
# 180 - episode (2 steps) is done with the score of 0.9900000002235174
# 181 - episode (6 steps) is done with the score of 0.9500000011175871
# 182 - episode (1 steps) is done with the score of 1.0
# 183 - episode (4 steps) is done with the score of 0.9700000006705523
# 184 - episode (5 steps) is done with the score of 0.9600000008940697
# 185 - episode (4 steps) is done with the score of 0.9700000006705523
# 186 - episode (2 steps) is done with the score of 0.9900000002235174
# 187 - episode (2 steps) is done with the score of 0.9900000002235174
# 188 - episode (3 steps) is done with the score of 0.9800000004470348
# 189 - episode (2 steps) is done with the score of 0.9900000002235174
# 190 - episode (2 steps) is done with the score of 0.9900000002235174
# 191 - episode (3 steps) is done with the score of 0.9800000004470348
# 192 - episode (3 steps) is done with the score of 0.9800000004470348
# 193 - episode (3 steps) is done with the score of 0.9800000004470348
# 194 - episode (8 steps) is done with the score of 0.9300000015646219
# 195 - episode (4 steps) is done with the score of 0.9700000006705523
# 196 - episode (6 steps) is done with the score of 0.9500000011175871
# 197 - episode (2 steps) is done with the score of 0.9900000002235174
# 198 - episode (5 steps) is done with the score of 0.9600000008940697
# 199 - episode (5 steps) is done with the score of 0.9600000008940697
# 200 - episode (1 steps) is done with the score of 1.0
# 201 - episode (4 steps) is done with the score of 0.9700000006705523
# 202 - episode (1 steps) is done with the score of 1.0
# 203 - episode (4 steps) is done with the score of 0.9700000006705523
# 204 - episode (4 steps) is done with the score of 0.9700000006705523
# 205 - episode (3 steps) is done with the score of 0.9800000004470348
# 206 - episode (1 steps) is done with the score of 1.0
# 207 - episode (4 steps) is done with the score of 0.9700000006705523
# 208 - episode (4 steps) is done with the score of 0.9700000006705523
# 209 - episode (3 steps) is done with the score of 0.9800000004470348
# 210 - episode (5 steps) is done with the score of 0.9600000008940697
# 211 - episode (2 steps) is done with the score of 0.9900000002235174
# 212 - episode (6 steps) is done with the score of 0.9500000011175871
# 213 - episode (7 steps) is done with the score of 0.9400000013411045
# 214 - episode (4 steps) is done with the score of 0.9700000006705523
# 215 - episode (6 steps) is done with the score of 0.9500000011175871
# 216 - episode (2 steps) is done with the score of 0.9900000002235174
# 217 - episode (2 steps) is done with the score of 0.9900000002235174
# 218 - episode (1 steps) is done with the score of 1.0
# 219 - episode (4 steps) is done with the score of 0.9700000006705523
# 220 - episode (3 steps) is done with the score of 0.9800000004470348
# 221 - episode (2 steps) is done with the score of 0.9900000002235174
# 222 - episode (2 steps) is done with the score of 0.9900000002235174
# 223 - episode (4 steps) is done with the score of 0.9700000006705523
# 224 - episode (2 steps) is done with the score of 0.9900000002235174
# 225 - episode (2 steps) is done with the score of 0.9900000002235174
# 226 - episode (3 steps) is done with the score of 0.9800000004470348
# 227 - episode (6 steps) is done with the score of 0.9500000011175871
# 228 - episode (1 steps) is done with the score of 1.0
# 229 - episode (8 steps) is done with the score of 0.9300000015646219
# 230 - episode (1 steps) is done with the score of 1.0
# 231 - episode (5 steps) is done with the score of 0.9600000008940697
# 232 - episode (3 steps) is done with the score of 0.9800000004470348
# 233 - episode (7 steps) is done with the score of 0.9400000013411045
# 234 - episode (5 steps) is done with the score of 0.9600000008940697
# 235 - episode (5 steps) is done with the score of 0.9600000008940697
# 236 - episode (6 steps) is done with the score of 0.9500000011175871
# 237 - episode (2 steps) is done with the score of 0.9900000002235174
# 238 - episode (4 steps) is done with the score of 0.9700000006705523
# 239 - episode (3 steps) is done with the score of 0.9800000004470348
# 240 - episode (2 steps) is done with the score of 0.9900000002235174
# 241 - episode (6 steps) is done with the score of 0.9500000011175871
# 242 - episode (6 steps) is done with the score of 0.9500000011175871
# 243 - episode (4 steps) is done with the score of 0.9700000006705523
# 244 - episode (3 steps) is done with the score of -1.0199999995529652
# 245 - episode (5 steps) is done with the score of 0.9600000008940697
# 246 - episode (4 steps) is done with the score of 0.9700000006705523
# 247 - episode (2 steps) is done with the score of 0.9900000002235174
# 248 - episode (1 steps) is done with the score of 1.0
# 249 - episode (7 steps) is done with the score of 0.9400000013411045
# 250 - episode (3 steps) is done with the score of 0.9800000004470348
# 251 - episode (3 steps) is done with the score of 0.9800000004470348
# 252 - episode (5 steps) is done with the score of 0.9600000008940697
# 253 - episode (2 steps) is done with the score of 0.9900000002235174
# 254 - episode (1 steps) is done with the score of 1.0
# 255 - episode (1 steps) is done with the score of 1.0
# 256 - episode (2 steps) is done with the score of 0.9900000002235174
# 257 - episode (3 steps) is done with the score of 0.9800000004470348
# 258 - episode (3 steps) is done with the score of 0.9800000004470348
# 259 - episode (6 steps) is done with the score of 0.9500000011175871
# 260 - episode (6 steps) is done with the score of 0.9500000011175871
# 261 - episode (4 steps) is done with the score of 0.9700000006705523
# 262 - episode (3 steps) is done with the score of 0.9800000004470348
# 263 - episode (1 steps) is done with the score of 1.0
# 264 - episode (8 steps) is done with the score of 0.9300000015646219
# 265 - episode (3 steps) is done with the score of 0.9800000004470348
# 266 - episode (3 steps) is done with the score of 0.9800000004470348
# 267 - episode (1 steps) is done with the score of 1.0
# 268 - episode (3 steps) is done with the score of 0.9800000004470348
# 269 - episode (2 steps) is done with the score of 0.9900000002235174
# 270 - episode (3 steps) is done with the score of 0.9800000004470348
# 271 - episode (5 steps) is done with the score of 0.9600000008940697
# 272 - episode (6 steps) is done with the score of 0.9500000011175871
# 273 - episode (1 steps) is done with the score of 1.0
# 274 - episode (5 steps) is done with the score of 0.9600000008940697
# 275 - episode (3 steps) is done with the score of 0.9800000004470348
# 276 - episode (4 steps) is done with the score of 0.9700000006705523
# 277 - episode (6 steps) is done with the score of 0.9500000011175871
# 278 - episode (1 steps) is done with the score of 1.0
# 279 - episode (5 steps) is done with the score of 0.9600000008940697
# 280 - episode (4 steps) is done with the score of 0.9700000006705523
# 281 - episode (4 steps) is done with the score of 0.9700000006705523
# 282 - episode (1 steps) is done with the score of 1.0
# 283 - episode (1 steps) is done with the score of 1.0
# 284 - episode (1 steps) is done with the score of 1.0
# 285 - episode (1 steps) is done with the score of 1.0
# 286 - episode (2 steps) is done with the score of 0.9900000002235174
# 287 - episode (4 steps) is done with the score of 0.9700000006705523
# 288 - episode (2 steps) is done with the score of 0.9900000002235174
# 289 - episode (3 steps) is done with the score of 0.9800000004470348
# 290 - episode (2 steps) is done with the score of 0.9900000002235174
# 291 - episode (10 steps) is done with the score of 0.9100000020116568
# 292 - episode (1 steps) is done with the score of 1.0
# 293 - episode (5 steps) is done with the score of 0.9600000008940697
# 294 - episode (5 steps) is done with the score of 0.9600000008940697
# 295 - episode (4 steps) is done with the score of 0.9700000006705523
# 296 - episode (4 steps) is done with the score of 0.9700000006705523
# 297 - episode (4 steps) is done with the score of 0.9700000006705523
# 298 - episode (8 steps) is done with the score of 0.9300000015646219
# 299 - episode (4 steps) is done with the score of 0.9700000006705523
# 300 - episode (4 steps) is done with the score of 0.9700000006705523
# 301 - episode (6 steps) is done with the score of 0.9500000011175871
# 302 - episode (3 steps) is done with the score of 0.9800000004470348
# 303 - episode (4 steps) is done with the score of 0.9700000006705523
# 304 - episode (6 steps) is done with the score of 0.9500000011175871
# 305 - episode (3 steps) is done with the score of 0.9800000004470348
# 306 - episode (1 steps) is done with the score of 1.0
# 307 - episode (3 steps) is done with the score of 0.9800000004470348
# 308 - episode (100 steps) is done with the score of -0.9999999776482582
# 309 - episode (3 steps) is done with the score of 0.9800000004470348
# 310 - episode (4 steps) is done with the score of 0.9700000006705523
# 311 - episode (5 steps) is done with the score of 0.9600000008940697
# 312 - episode (5 steps) is done with the score of 0.9600000008940697
# 313 - episode (1 steps) is done with the score of 1.0
# 314 - episode (2 steps) is done with the score of 0.9900000002235174
# 315 - episode (5 steps) is done with the score of 0.9600000008940697
# 316 - episode (1 steps) is done with the score of 1.0
# 317 - episode (4 steps) is done with the score of 0.9700000006705523
# 318 - episode (2 steps) is done with the score of 0.9900000002235174
# 319 - episode (4 steps) is done with the score of 0.9700000006705523
# 320 - episode (2 steps) is done with the score of 0.9900000002235174
# 321 - episode (4 steps) is done with the score of 0.9700000006705523
# 322 - episode (5 steps) is done with the score of 0.9600000008940697
# 323 - episode (3 steps) is done with the score of 0.9800000004470348
# 324 - episode (1 steps) is done with the score of 1.0
# 325 - episode (6 steps) is done with the score of 0.9500000011175871
# 326 - episode (3 steps) is done with the score of 0.9800000004470348
# 327 - episode (3 steps) is done with the score of 0.9800000004470348
# 328 - episode (4 steps) is done with the score of 0.9700000006705523
# 329 - episode (3 steps) is done with the score of 0.9800000004470348
# 330 - episode (1 steps) is done with the score of 1.0
# 331 - episode (2 steps) is done with the score of 0.9900000002235174
# 332 - episode (4 steps) is done with the score of 0.9700000006705523
# 333 - episode (4 steps) is done with the score of 0.9700000006705523
# 334 - episode (3 steps) is done with the score of 0.9800000004470348
# 335 - episode (3 steps) is done with the score of 0.9800000004470348
# 336 - episode (1 steps) is done with the score of 1.0
# 337 - episode (3 steps) is done with the score of 0.9800000004470348
# 338 - episode (2 steps) is done with the score of 0.9900000002235174
# 339 - episode (4 steps) is done with the score of 0.9700000006705523
# 340 - episode (5 steps) is done with the score of 0.9600000008940697
# 341 - episode (1 steps) is done with the score of 1.0
# 342 - episode (1 steps) is done with the score of 1.0
# 343 - episode (2 steps) is done with the score of 0.9900000002235174
# 344 - episode (7 steps) is done with the score of 0.9400000013411045
# 345 - episode (6 steps) is done with the score of 0.9500000011175871
# 346 - episode (4 steps) is done with the score of 0.9700000006705523
# 347 - episode (1 steps) is done with the score of 1.0
# 348 - episode (5 steps) is done with the score of 0.9600000008940697
# 349 - episode (4 steps) is done with the score of 0.9700000006705523
# 350 - episode (2 steps) is done with the score of 0.9900000002235174
# 351 - episode (5 steps) is done with the score of 0.9600000008940697
# 352 - episode (7 steps) is done with the score of 0.9400000013411045
# 353 - episode (6 steps) is done with the score of 0.9500000011175871
# 354 - episode (5 steps) is done with the score of 0.9600000008940697
# 355 - episode (4 steps) is done with the score of 0.9700000006705523
# 356 - episode (7 steps) is done with the score of 0.9400000013411045
# 357 - episode (6 steps) is done with the score of 0.9500000011175871
# 358 - episode (5 steps) is done with the score of 0.9600000008940697
# 359 - episode (2 steps) is done with the score of 0.9900000002235174
# 360 - episode (6 steps) is done with the score of 0.9500000011175871
# 361 - episode (3 steps) is done with the score of 0.9800000004470348
# 362 - episode (4 steps) is done with the score of 0.9700000006705523
# 363 - episode (7 steps) is done with the score of 0.9400000013411045
# 364 - episode (3 steps) is done with the score of 0.9800000004470348
# 365 - episode (11 steps) is done with the score of 0.9000000022351742
# 366 - episode (2 steps) is done with the score of 0.9900000002235174
# 367 - episode (7 steps) is done with the score of 0.9400000013411045
# 368 - episode (4 steps) is done with the score of 0.9700000006705523
# 369 - episode (3 steps) is done with the score of 0.9800000004470348
# 370 - episode (3 steps) is done with the score of 0.9800000004470348
# 371 - episode (1 steps) is done with the score of 1.0
# 372 - episode (1 steps) is done with the score of 1.0
# 373 - episode (4 steps) is done with the score of 0.9700000006705523
# 374 - episode (4 steps) is done with the score of 0.9700000006705523
# 375 - episode (4 steps) is done with the score of 0.9700000006705523
# 376 - episode (4 steps) is done with the score of 0.9700000006705523
# 377 - episode (4 steps) is done with the score of 0.9700000006705523
# 378 - episode (6 steps) is done with the score of 0.9500000011175871
# 379 - episode (1 steps) is done with the score of 1.0
# 380 - episode (1 steps) is done with the score of 1.0
# 381 - episode (11 steps) is done with the score of 0.9000000022351742
# 382 - episode (6 steps) is done with the score of 0.9500000011175871
# 383 - episode (4 steps) is done with the score of 0.9700000006705523
# 384 - episode (4 steps) is done with the score of 0.9700000006705523
# 385 - episode (6 steps) is done with the score of 0.9500000011175871
# 386 - episode (1 steps) is done with the score of 1.0
# 387 - episode (4 steps) is done with the score of 0.9700000006705523
# 388 - episode (2 steps) is done with the score of 0.9900000002235174
# 389 - episode (2 steps) is done with the score of 0.9900000002235174
# 390 - episode (3 steps) is done with the score of 0.9800000004470348
# 391 - episode (1 steps) is done with the score of 1.0
# 392 - episode (1 steps) is done with the score of 1.0
# 393 - episode (4 steps) is done with the score of 0.9700000006705523
# 394 - episode (4 steps) is done with the score of 0.9700000006705523
# 395 - episode (5 steps) is done with the score of 0.9600000008940697
# 396 - episode (2 steps) is done with the score of 0.9900000002235174
# 397 - episode (3 steps) is done with the score of 0.9800000004470348
# 398 - episode (5 steps) is done with the score of 0.9600000008940697
# 399 - episode (4 steps) is done with the score of 0.9700000006705523
# 400 - episode (5 steps) is done with the score of 0.9600000008940697
# 401 - episode (3 steps) is done with the score of 0.9800000004470348
# 402 - episode (1 steps) is done with the score of 1.0
# 403 - episode (4 steps) is done with the score of 0.9700000006705523
# 404 - episode (4 steps) is done with the score of 0.9700000006705523
# 405 - episode (2 steps) is done with the score of 0.9900000002235174
# 406 - episode (6 steps) is done with the score of 0.9500000011175871
# 407 - episode (8 steps) is done with the score of 0.9300000015646219
# 408 - episode (7 steps) is done with the score of 0.9400000013411045
# 409 - episode (6 steps) is done with the score of 0.9500000011175871
# 410 - episode (4 steps) is done with the score of 0.9700000006705523
# 411 - episode (5 steps) is done with the score of 0.9600000008940697
# 412 - episode (2 steps) is done with the score of 0.9900000002235174
# 413 - episode (5 steps) is done with the score of 0.9600000008940697
# 414 - episode (2 steps) is done with the score of 0.9900000002235174
# 415 - episode (3 steps) is done with the score of 0.9800000004470348
# 416 - episode (2 steps) is done with the score of 0.9900000002235174
# 417 - episode (7 steps) is done with the score of 0.9400000013411045
# 418 - episode (6 steps) is done with the score of 0.9500000011175871
# 419 - episode (2 steps) is done with the score of 0.9900000002235174
# 420 - episode (1 steps) is done with the score of 1.0
# 421 - episode (2 steps) is done with the score of 0.9900000002235174
# 422 - episode (3 steps) is done with the score of 0.9800000004470348
# 423 - episode (1 steps) is done with the score of 1.0
# 424 - episode (2 steps) is done with the score of 0.9900000002235174
# 425 - episode (3 steps) is done with the score of 0.9800000004470348
# 426 - episode (3 steps) is done with the score of 0.9800000004470348
# 427 - episode (5 steps) is done with the score of 0.9600000008940697
# 428 - episode (2 steps) is done with the score of 0.9900000002235174
# 429 - episode (3 steps) is done with the score of 0.9800000004470348
# 430 - episode (5 steps) is done with the score of 0.9600000008940697
# 431 - episode (4 steps) is done with the score of 0.9700000006705523
# 432 - episode (2 steps) is done with the score of 0.9900000002235174
# 433 - episode (1 steps) is done with the score of 1.0
# 434 - episode (5 steps) is done with the score of 0.9600000008940697
# 435 - episode (5 steps) is done with the score of 0.9600000008940697
# 436 - episode (2 steps) is done with the score of 0.9900000002235174
# 437 - episode (2 steps) is done with the score of 0.9900000002235174
# 438 - episode (1 steps) is done with the score of 1.0
# 439 - episode (5 steps) is done with the score of 0.9600000008940697
# 440 - episode (2 steps) is done with the score of 0.9900000002235174
# 441 - episode (1 steps) is done with the score of 1.0
# 442 - episode (2 steps) is done with the score of 0.9900000002235174
# 443 - episode (3 steps) is done with the score of 0.9800000004470348
# 444 - episode (1 steps) is done with the score of 1.0
# 445 - episode (1 steps) is done with the score of -1.0
# 446 - episode (4 steps) is done with the score of 0.9700000006705523
# 447 - episode (3 steps) is done with the score of 0.9800000004470348
# 448 - episode (6 steps) is done with the score of 0.9500000011175871
# 449 - episode (5 steps) is done with the score of 0.9600000008940697
# 450 - episode (3 steps) is done with the score of 0.9800000004470348
# 451 - episode (1 steps) is done with the score of 1.0
# 452 - episode (6 steps) is done with the score of 0.9500000011175871
# 453 - episode (3 steps) is done with the score of 0.9800000004470348
# 454 - episode (5 steps) is done with the score of 0.9600000008940697
# 455 - episode (5 steps) is done with the score of 0.9600000008940697
# 456 - episode (3 steps) is done with the score of 0.9800000004470348
# 457 - episode (2 steps) is done with the score of 0.9900000002235174
# 458 - episode (2 steps) is done with the score of 0.9900000002235174
# 459 - episode (4 steps) is done with the score of 0.9700000006705523
# 460 - episode (3 steps) is done with the score of 0.9800000004470348
# 461 - episode (4 steps) is done with the score of 0.9700000006705523
# 462 - episode (5 steps) is done with the score of 0.9600000008940697
# 463 - episode (3 steps) is done with the score of 0.9800000004470348
# 464 - episode (4 steps) is done with the score of 0.9700000006705523
# 465 - episode (4 steps) is done with the score of 0.9700000006705523
# 466 - episode (2 steps) is done with the score of 0.9900000002235174
# 467 - episode (3 steps) is done with the score of 0.9800000004470348
# 468 - episode (6 steps) is done with the score of 0.9500000011175871
# 469 - episode (6 steps) is done with the score of 0.9500000011175871
# 470 - episode (3 steps) is done with the score of 0.9800000004470348
# 471 - episode (1 steps) is done with the score of 1.0
# 472 - episode (6 steps) is done with the score of 0.9500000011175871
# 473 - episode (1 steps) is done with the score of 1.0
# 474 - episode (1 steps) is done with the score of 1.0
# 475 - episode (5 steps) is done with the score of 0.9600000008940697
# 476 - episode (4 steps) is done with the score of 0.9700000006705523
# 477 - episode (2 steps) is done with the score of 0.9900000002235174
# 478 - episode (5 steps) is done with the score of 0.9600000008940697
# 479 - episode (1 steps) is done with the score of 1.0
# 480 - episode (5 steps) is done with the score of 0.9600000008940697
# 481 - episode (1 steps) is done with the score of 1.0
# 482 - episode (8 steps) is done with the score of 0.9300000015646219
# 483 - episode (1 steps) is done with the score of 1.0
# 484 - episode (5 steps) is done with the score of 0.9600000008940697
# 485 - episode (6 steps) is done with the score of 0.9500000011175871
# 486 - episode (7 steps) is done with the score of 0.9400000013411045
# 487 - episode (3 steps) is done with the score of 0.9800000004470348
# 488 - episode (5 steps) is done with the score of 0.9600000008940697
# 489 - episode (2 steps) is done with the score of 0.9900000002235174
# 490 - episode (3 steps) is done with the score of 0.9800000004470348
# 491 - episode (5 steps) is done with the score of 0.9600000008940697
# 492 - episode (3 steps) is done with the score of 0.9800000004470348
# 493 - episode (5 steps) is done with the score of 0.9600000008940697
# 494 - episode (2 steps) is done with the score of 0.9900000002235174
# 495 - episode (1 steps) is done with the score of 1.0
# 496 - episode (4 steps) is done with the score of 0.9700000006705523
# 497 - episode (3 steps) is done with the score of 0.9800000004470348
# 498 - episode (1 steps) is done with the score of 1.0
# 499 - episode (2 steps) is done with the score of 0.9900000002235174
# 500 - episode (1 steps) is done with the score of 1.0
# 501 - episode (4 steps) is done with the score of 0.9700000006705523
# 502 - episode (1 steps) is done with the score of 1.0
# 503 - episode (3 steps) is done with the score of 0.9800000004470348
# 504 - episode (6 steps) is done with the score of 0.9500000011175871
# 505 - episode (6 steps) is done with the score of 0.9500000011175871
# 506 - episode (1 steps) is done with the score of 1.0
# 507 - episode (3 steps) is done with the score of 0.9800000004470348
# 508 - episode (4 steps) is done with the score of 0.9700000006705523
# 509 - episode (8 steps) is done with the score of 0.9300000015646219
# 510 - episode (4 steps) is done with the score of 0.9700000006705523
# 511 - episode (7 steps) is done with the score of 0.9400000013411045
# 512 - episode (4 steps) is done with the score of 0.9700000006705523
# 513 - episode (2 steps) is done with the score of 0.9900000002235174
# 514 - episode (4 steps) is done with the score of 0.9700000006705523
# 515 - episode (1 steps) is done with the score of 1.0
# 516 - episode (2 steps) is done with the score of 0.9900000002235174
# 517 - episode (3 steps) is done with the score of 0.9800000004470348
# 518 - episode (2 steps) is done with the score of 0.9900000002235174
# 519 - episode (3 steps) is done with the score of 0.9800000004470348
# 520 - episode (3 steps) is done with the score of 0.9800000004470348
# 521 - episode (2 steps) is done with the score of 0.9900000002235174
# 522 - episode (2 steps) is done with the score of 0.9900000002235174
# 523 - episode (6 steps) is done with the score of 0.9500000011175871
# 524 - episode (7 steps) is done with the score of 0.9400000013411045
# 525 - episode (4 steps) is done with the score of 0.9700000006705523
# 526 - episode (1 steps) is done with the score of 1.0
# 527 - episode (2 steps) is done with the score of 0.9900000002235174
# 528 - episode (5 steps) is done with the score of 0.9600000008940697
# 529 - episode (1 steps) is done with the score of 1.0
# 530 - episode (5 steps) is done with the score of 0.9600000008940697
# 531 - episode (5 steps) is done with the score of 0.9600000008940697
# 532 - episode (5 steps) is done with the score of 0.9600000008940697
# 533 - episode (2 steps) is done with the score of 0.9900000002235174
# 534 - episode (5 steps) is done with the score of 0.9600000008940697
# 535 - episode (3 steps) is done with the score of 0.9800000004470348
# 536 - episode (4 steps) is done with the score of 0.9700000006705523
# 537 - episode (5 steps) is done with the score of 0.9600000008940697
# 538 - episode (4 steps) is done with the score of 0.9700000006705523
# 539 - episode (3 steps) is done with the score of 0.9800000004470348
# 540 - episode (4 steps) is done with the score of 0.9700000006705523
# 541 - episode (4 steps) is done with the score of 0.9700000006705523
# 542 - episode (4 steps) is done with the score of 0.9700000006705523
# 543 - episode (5 steps) is done with the score of 0.9600000008940697
# 544 - episode (5 steps) is done with the score of 0.9600000008940697
# 545 - episode (2 steps) is done with the score of 0.9900000002235174
# 546 - episode (4 steps) is done with the score of 0.9700000006705523
# 547 - episode (6 steps) is done with the score of 0.9500000011175871
# 548 - episode (2 steps) is done with the score of 0.9900000002235174
# 549 - episode (7 steps) is done with the score of 0.9400000013411045
# 550 - episode (3 steps) is done with the score of 0.9800000004470348
# 551 - episode (4 steps) is done with the score of 0.9700000006705523
# 552 - episode (4 steps) is done with the score of 0.9700000006705523
# 553 - episode (3 steps) is done with the score of 0.9800000004470348
# 554 - episode (3 steps) is done with the score of 0.9800000004470348
# 555 - episode (2 steps) is done with the score of 0.9900000002235174
# 556 - episode (4 steps) is done with the score of 0.9700000006705523
# 557 - episode (2 steps) is done with the score of 0.9900000002235174
# 558 - episode (5 steps) is done with the score of 0.9600000008940697
# 559 - episode (2 steps) is done with the score of 0.9900000002235174
# 560 - episode (3 steps) is done with the score of 0.9800000004470348
# 561 - episode (1 steps) is done with the score of 1.0
# 562 - episode (2 steps) is done with the score of 0.9900000002235174
# 563 - episode (2 steps) is done with the score of 0.9900000002235174
# 564 - episode (3 steps) is done with the score of 0.9800000004470348
# 565 - episode (1 steps) is done with the score of 1.0
# 566 - episode (2 steps) is done with the score of 0.9900000002235174
# 567 - episode (7 steps) is done with the score of 0.9400000013411045
# 568 - episode (5 steps) is done with the score of 0.9600000008940697
# 569 - episode (5 steps) is done with the score of 0.9600000008940697
# 570 - episode (5 steps) is done with the score of 0.9600000008940697
# 571 - episode (5 steps) is done with the score of 0.9600000008940697
# 572 - episode (5 steps) is done with the score of 0.9600000008940697
# 573 - episode (1 steps) is done with the score of 1.0
# 574 - episode (5 steps) is done with the score of 0.9600000008940697
# 575 - episode (2 steps) is done with the score of 0.9900000002235174
# 576 - episode (7 steps) is done with the score of 0.9400000013411045
# 577 - episode (4 steps) is done with the score of 0.9700000006705523
# 578 - episode (2 steps) is done with the score of 0.9900000002235174
# 579 - episode (3 steps) is done with the score of 0.9800000004470348
# 580 - episode (8 steps) is done with the score of 0.9300000015646219
# 581 - episode (3 steps) is done with the score of 0.9800000004470348
# 582 - episode (4 steps) is done with the score of 0.9700000006705523
# 583 - episode (1 steps) is done with the score of 1.0
# 584 - episode (4 steps) is done with the score of 0.9700000006705523
# 585 - episode (5 steps) is done with the score of 0.9600000008940697
# 586 - episode (1 steps) is done with the score of 1.0
# 587 - episode (5 steps) is done with the score of 0.9600000008940697
# 588 - episode (3 steps) is done with the score of 0.9800000004470348
# 589 - episode (4 steps) is done with the score of 0.9700000006705523
# 590 - episode (5 steps) is done with the score of 0.9600000008940697
# 591 - episode (7 steps) is done with the score of 0.9400000013411045
# 592 - episode (4 steps) is done with the score of 0.9700000006705523
# 593 - episode (8 steps) is done with the score of 0.9300000015646219
# 594 - episode (6 steps) is done with the score of 0.9500000011175871
# 595 - episode (1 steps) is done with the score of 1.0
# 596 - episode (1 steps) is done with the score of 1.0
# 597 - episode (2 steps) is done with the score of 0.9900000002235174
# 598 - episode (6 steps) is done with the score of 0.9500000011175871
# 599 - episode (5 steps) is done with the score of 0.9600000008940697
# 600 - episode (2 steps) is done with the score of 0.9900000002235174
# 601 - episode (9 steps) is done with the score of 0.9200000017881393
# 602 - episode (3 steps) is done with the score of 0.9800000004470348
# 603 - episode (1 steps) is done with the score of 1.0
# 604 - episode (2 steps) is done with the score of 0.9900000002235174
# 605 - episode (6 steps) is done with the score of 0.9500000011175871
# 606 - episode (2 steps) is done with the score of 0.9900000002235174
# 607 - episode (5 steps) is done with the score of 0.9600000008940697
# 608 - episode (4 steps) is done with the score of 0.9700000006705523
# 609 - episode (3 steps) is done with the score of 0.9800000004470348
# 610 - episode (1 steps) is done with the score of 1.0
# 611 - episode (5 steps) is done with the score of 0.9600000008940697
# 612 - episode (5 steps) is done with the score of 0.9600000008940697
# 613 - episode (3 steps) is done with the score of 0.9800000004470348
# 614 - episode (4 steps) is done with the score of 0.9700000006705523
# 615 - episode (4 steps) is done with the score of 0.9700000006705523
# 616 - episode (4 steps) is done with the score of 0.9700000006705523
# 617 - episode (1 steps) is done with the score of 1.0
# 618 - episode (2 steps) is done with the score of 0.9900000002235174
# 619 - episode (2 steps) is done with the score of 0.9900000002235174
# 620 - episode (3 steps) is done with the score of 0.9800000004470348
# 621 - episode (3 steps) is done with the score of 0.9800000004470348
# 622 - episode (6 steps) is done with the score of 0.9500000011175871
# 623 - episode (2 steps) is done with the score of 0.9900000002235174
# 624 - episode (1 steps) is done with the score of 1.0
# 625 - episode (2 steps) is done with the score of 0.9900000002235174
# 626 - episode (1 steps) is done with the score of 1.0
# 627 - episode (1 steps) is done with the score of 1.0
# 628 - episode (7 steps) is done with the score of 0.9400000013411045
# 629 - episode (3 steps) is done with the score of 0.9800000004470348
# 630 - episode (1 steps) is done with the score of 1.0
# 631 - episode (3 steps) is done with the score of 0.9800000004470348
# 632 - episode (5 steps) is done with the score of 0.9600000008940697
# 633 - episode (5 steps) is done with the score of 0.9600000008940697
# 634 - episode (3 steps) is done with the score of 0.9800000004470348
# 635 - episode (2 steps) is done with the score of 0.9900000002235174
# 636 - episode (4 steps) is done with the score of 0.9700000006705523
# 637 - episode (3 steps) is done with the score of 0.9800000004470348
# 638 - episode (6 steps) is done with the score of 0.9500000011175871
# 639 - episode (5 steps) is done with the score of 0.9600000008940697
# 640 - episode (1 steps) is done with the score of 1.0
# 641 - episode (1 steps) is done with the score of 1.0
# 642 - episode (3 steps) is done with the score of 0.9800000004470348
# 643 - episode (1 steps) is done with the score of 1.0
# 644 - episode (3 steps) is done with the score of 0.9800000004470348
# 645 - episode (2 steps) is done with the score of 0.9900000002235174
# 646 - episode (4 steps) is done with the score of 0.9700000006705523
# 647 - episode (1 steps) is done with the score of 1.0
# 648 - episode (3 steps) is done with the score of 0.9800000004470348
# 649 - episode (3 steps) is done with the score of 0.9800000004470348
# 650 - episode (1 steps) is done with the score of 1.0
# 651 - episode (2 steps) is done with the score of 0.9900000002235174
# 652 - episode (3 steps) is done with the score of 0.9800000004470348
# 653 - episode (3 steps) is done with the score of 0.9800000004470348
# 654 - episode (1 steps) is done with the score of 1.0
# 655 - episode (2 steps) is done with the score of 0.9900000002235174
# 656 - episode (9 steps) is done with the score of 0.9200000017881393
# 657 - episode (4 steps) is done with the score of 0.9700000006705523
# 658 - episode (4 steps) is done with the score of 0.9700000006705523
# 659 - episode (4 steps) is done with the score of 0.9700000006705523
# 660 - episode (2 steps) is done with the score of 0.9900000002235174
# 661 - episode (4 steps) is done with the score of 0.9700000006705523
# 662 - episode (3 steps) is done with the score of 0.9800000004470348
# 663 - episode (3 steps) is done with the score of 0.9800000004470348
# 664 - episode (1 steps) is done with the score of 1.0
# 665 - episode (2 steps) is done with the score of 0.9900000002235174
# 666 - episode (5 steps) is done with the score of 0.9600000008940697
# 667 - episode (3 steps) is done with the score of 0.9800000004470348
# 668 - episode (5 steps) is done with the score of 0.9600000008940697
# 669 - episode (8 steps) is done with the score of 0.9300000015646219
# 670 - episode (4 steps) is done with the score of 0.9700000006705523
# 671 - episode (1 steps) is done with the score of 1.0
# 672 - episode (5 steps) is done with the score of -1.0399999991059303
# 673 - episode (5 steps) is done with the score of 0.9600000008940697
# 674 - episode (7 steps) is done with the score of 0.9400000013411045
# 675 - episode (2 steps) is done with the score of 0.9900000002235174
# 676 - episode (3 steps) is done with the score of 0.9800000004470348
# 677 - episode (5 steps) is done with the score of 0.9600000008940697
# 678 - episode (3 steps) is done with the score of 0.9800000004470348
# 679 - episode (4 steps) is done with the score of 0.9700000006705523
# 680 - episode (2 steps) is done with the score of 0.9900000002235174
# 681 - episode (3 steps) is done with the score of 0.9800000004470348
# 682 - episode (7 steps) is done with the score of 0.9400000013411045
# 683 - episode (2 steps) is done with the score of 0.9900000002235174
# 684 - episode (2 steps) is done with the score of 0.9900000002235174
# 685 - episode (2 steps) is done with the score of 0.9900000002235174
# 686 - episode (3 steps) is done with the score of 0.9800000004470348
# 687 - episode (3 steps) is done with the score of 0.9800000004470348
# 688 - episode (7 steps) is done with the score of 0.9400000013411045
# 689 - episode (3 steps) is done with the score of 0.9800000004470348
# 690 - episode (3 steps) is done with the score of 0.9800000004470348
# 691 - episode (6 steps) is done with the score of 0.9500000011175871
# ...
# 1183 - episode (4 steps) is done with the score of 0.9700000006705523
# 1184 - episode (4 steps) is done with the score of 0.9700000006705523
# 1185 - episode (4 steps) is done with the score of 0.9700000006705523
# 1186 - episode (2 steps) is done with the score of 0.9900000002235174
# 1187 - episode (4 steps) is done with the score of 0.9700000006705523
# 1188 - episode (3 steps) is done with the score of 0.9800000004470348
# 1189 - episode (5 steps) is done with the score of 0.9600000008940697
# 1190 - episode (5 steps) is done with the score of 0.9600000008940697
# 1191 - episode (3 steps) is done with the score of 0.9800000004470348
# 1192 - episode (2 steps) is done with the score of 0.9900000002235174
# 1193 - episode (3 steps) is done with the score of 0.9800000004470348
# 1194 - episode (4 steps) is done with the score of 0.9700000006705523
# 1195 - episode (1 steps) is done with the score of 1.0
# 1196 - episode (7 steps) is done with the score of 0.9400000013411045
# 1197 - episode (3 steps) is done with the score of 0.9800000004470348
# 1198 - episode (3 steps) is done with the score of 0.9800000004470348
# 1199 - episode (6 steps) is done with the score of 0.9500000011175871
# 1200 - episode (1 steps) is done with the score of 1.0
# 1201 - episode (3 steps) is done with the score of 0.9800000004470348
# 1202 - episode (5 steps) is done with the score of 0.9600000008940697
# 1203 - episode (1 steps) is done with the score of 1.0
# 1204 - episode (2 steps) is done with the score of 0.9900000002235174
# 1205 - episode (2 steps) is done with the score of 0.9900000002235174
# 1206 - episode (5 steps) is done with the score of 0.9600000008940697
# 1207 - episode (2 steps) is done with the score of 0.9900000002235174
# 1208 - episode (4 steps) is done with the score of 0.9700000006705523
# 1209 - episode (1 steps) is done with the score of 1.0
# 1210 - episode (4 steps) is done with the score of 0.9700000006705523
# 1211 - episode (2 steps) is done with the score of 0.9900000002235174
# 1212 - episode (6 steps) is done with the score of 0.9500000011175871
# 1213 - episode (3 steps) is done with the score of 0.9800000004470348
# 1214 - episode (3 steps) is done with the score of 0.9800000004470348
# 1215 - episode (5 steps) is done with the score of 0.9600000008940697
# 1216 - episode (2 steps) is done with the score of 0.9900000002235174
# 1217 - episode (3 steps) is done with the score of 0.9800000004470348
# 1218 - episode (1 steps) is done with the score of 1.0
# 1219 - episode (4 steps) is done with the score of 0.9700000006705523
# 1220 - episode (3 steps) is done with the score of 0.9800000004470348
# 1221 - episode (2 steps) is done with the score of 0.9900000002235174
# 1222 - episode (4 steps) is done with the score of 0.9700000006705523
# 1223 - episode (2 steps) is done with the score of 0.9900000002235174
# 1224 - episode (1 steps) is done with the score of 1.0
# 1225 - episode (4 steps) is done with the score of 0.9700000006705523
# 1226 - episode (5 steps) is done with the score of 0.9600000008940697
# 1227 - episode (3 steps) is done with the score of 0.9800000004470348
# 1228 - episode (1 steps) is done with the score of 1.0
# 1229 - episode (1 steps) is done with the score of 1.0
# 1230 - episode (3 steps) is done with the score of 0.9800000004470348
# 1231 - episode (5 steps) is done with the score of 0.9600000008940697
# 1232 - episode (5 steps) is done with the score of 0.9600000008940697
# 1233 - episode (1 steps) is done with the score of 1.0
# 1234 - episode (3 steps) is done with the score of 0.9800000004470348
# 1235 - episode (6 steps) is done with the score of 0.9500000011175871
# 1236 - episode (6 steps) is done with the score of 0.9500000011175871
# 1237 - episode (2 steps) is done with the score of 0.9900000002235174
# 1238 - episode (24 steps) is done with the score of -1.2299999948590994
# 1239 - episode (4 steps) is done with the score of 0.9700000006705523
# 1240 - episode (4 steps) is done with the score of 0.9700000006705523
# 1241 - episode (2 steps) is done with the score of 0.9900000002235174
# 1242 - episode (5 steps) is done with the score of 0.9600000008940697
# 1243 - episode (3 steps) is done with the score of 0.9800000004470348
# 1244 - episode (1 steps) is done with the score of 1.0
# 1245 - episode (2 steps) is done with the score of 0.9900000002235174
# 1246 - episode (2 steps) is done with the score of 0.9900000002235174
# 1247 - episode (2 steps) is done with the score of 0.9900000002235174
# 1248 - episode (5 steps) is done with the score of 0.9600000008940697
# 1249 - episode (3 steps) is done with the score of 0.9800000004470348
# 1250 - episode (2 steps) is done with the score of 0.9900000002235174
# 1251 - episode (6 steps) is done with the score of 0.9500000011175871
# 1252 - episode (4 steps) is done with the score of 0.9700000006705523
# 1253 - episode (6 steps) is done with the score of 0.9500000011175871
# 1254 - episode (5 steps) is done with the score of 0.9600000008940697
# 1255 - episode (7 steps) is done with the score of 0.9400000013411045
# 1256 - episode (5 steps) is done with the score of 0.9600000008940697
# 1257 - episode (3 steps) is done with the score of 0.9800000004470348
# 1258 - episode (2 steps) is done with the score of 0.9900000002235174
# 1259 - episode (5 steps) is done with the score of 0.9600000008940697
# 1260 - episode (3 steps) is done with the score of 0.9800000004470348
# 1261 - episode (7 steps) is done with the score of 0.9400000013411045
# 1262 - episode (7 steps) is done with the score of 0.9400000013411045
# 1263 - episode (3 steps) is done with the score of 0.9800000004470348
# 1264 - episode (6 steps) is done with the score of 0.9500000011175871
# 1265 - episode (2 steps) is done with the score of 0.9900000002235174
# 1266 - episode (2 steps) is done with the score of 0.9900000002235174
# 1267 - episode (5 steps) is done with the score of 0.9600000008940697
# 1268 - episode (1 steps) is done with the score of 1.0
# 1269 - episode (5 steps) is done with the score of 0.9600000008940697
# 1270 - episode (3 steps) is done with the score of 0.9800000004470348
# 1271 - episode (4 steps) is done with the score of 0.9700000006705523
# 1272 - episode (2 steps) is done with the score of 0.9900000002235174
# 1273 - episode (1 steps) is done with the score of 1.0
# 1274 - episode (4 steps) is done with the score of 0.9700000006705523
# 1275 - episode (6 steps) is done with the score of 0.9500000011175871
# 1276 - episode (2 steps) is done with the score of 0.9900000002235174
# 1277 - episode (2 steps) is done with the score of 0.9900000002235174
# 1278 - episode (1 steps) is done with the score of 1.0
# 1279 - episode (5 steps) is done with the score of 0.9600000008940697
# 1280 - episode (3 steps) is done with the score of 0.9800000004470348
# 1281 - episode (4 steps) is done with the score of 0.9700000006705523
# 1282 - episode (6 steps) is done with the score of 0.9500000011175871
# 1283 - episode (1 steps) is done with the score of 1.0
# 1284 - episode (3 steps) is done with the score of 0.9800000004470348
# 1285 - episode (4 steps) is done with the score of 0.9700000006705523
# 1286 - episode (1 steps) is done with the score of 1.0
# 1287 - episode (8 steps) is done with the score of 0.9300000015646219
# 1288 - episode (6 steps) is done with the score of 0.9500000011175871
# 1289 - episode (3 steps) is done with the score of 0.9800000004470348
# 1290 - episode (7 steps) is done with the score of 0.9400000013411045
# 1291 - episode (7 steps) is done with the score of 0.9400000013411045
# 1292 - episode (1 steps) is done with the score of 1.0
# 1293 - episode (1 steps) is done with the score of 1.0
# 1294 - episode (5 steps) is done with the score of 0.9600000008940697
# 1295 - episode (5 steps) is done with the score of 0.9600000008940697
# 1296 - episode (5 steps) is done with the score of 0.9600000008940697
# 1297 - episode (5 steps) is done with the score of 0.9600000008940697
# 1298 - episode (7 steps) is done with the score of 0.9400000013411045
# 1299 - episode (3 steps) is done with the score of 0.9800000004470348
# 1300 - episode (2 steps) is done with the score of 0.9900000002235174
# 1301 - episode (3 steps) is done with the score of 0.9800000004470348
# 1302 - episode (5 steps) is done with the score of 0.9600000008940697
# 1303 - episode (5 steps) is done with the score of 0.9600000008940697
# 1304 - episode (3 steps) is done with the score of 0.9800000004470348
# 1305 - episode (4 steps) is done with the score of 0.9700000006705523
# 1306 - episode (8 steps) is done with the score of 0.9300000015646219
# 1307 - episode (4 steps) is done with the score of 0.9700000006705523
# 1308 - episode (2 steps) is done with the score of 0.9900000002235174
# 1309 - episode (3 steps) is done with the score of 0.9800000004470348
# 1310 - episode (1 steps) is done with the score of 1.0
# 1311 - episode (1 steps) is done with the score of 1.0
# 1312 - episode (4 steps) is done with the score of 0.9700000006705523
# 1313 - episode (3 steps) is done with the score of 0.9800000004470348
# 1314 - episode (4 steps) is done with the score of 0.9700000006705523
# 1315 - episode (2 steps) is done with the score of 0.9900000002235174
# 1316 - episode (3 steps) is done with the score of 0.9800000004470348
# 1317 - episode (5 steps) is done with the score of 0.9600000008940697
# 1318 - episode (3 steps) is done with the score of 0.9800000004470348
# 1319 - episode (5 steps) is done with the score of 0.9600000008940697
# 1320 - episode (3 steps) is done with the score of 0.9800000004470348
# 1321 - episode (6 steps) is done with the score of 0.9500000011175871
# 1322 - episode (4 steps) is done with the score of 0.9700000006705523
# 1323 - episode (1 steps) is done with the score of 1.0
# 1324 - episode (5 steps) is done with the score of 0.9600000008940697
# 1325 - episode (6 steps) is done with the score of 0.9500000011175871
# 1326 - episode (3 steps) is done with the score of 0.9800000004470348
# 1327 - episode (1 steps) is done with the score of 1.0
# 1328 - episode (6 steps) is done with the score of 0.9500000011175871
# 1329 - episode (1 steps) is done with the score of 1.0
# 1330 - episode (3 steps) is done with the score of 0.9800000004470348
# 1331 - episode (1 steps) is done with the score of 1.0
# 1332 - episode (4 steps) is done with the score of 0.9700000006705523
# 1333 - episode (5 steps) is done with the score of 0.9600000008940697
# 1334 - episode (4 steps) is done with the score of 0.9700000006705523
# 1335 - episode (2 steps) is done with the score of 0.9900000002235174
# 1336 - episode (2 steps) is done with the score of 0.9900000002235174
# 1337 - episode (4 steps) is done with the score of 0.9700000006705523
# 1338 - episode (3 steps) is done with the score of 0.9800000004470348
# 1339 - episode (4 steps) is done with the score of 0.9700000006705523
# 1340 - episode (2 steps) is done with the score of 0.9900000002235174
# 1341 - episode (2 steps) is done with the score of 0.9900000002235174
# 1342 - episode (3 steps) is done with the score of 0.9800000004470348
# 1343 - episode (5 steps) is done with the score of 0.9600000008940697
# 1344 - episode (5 steps) is done with the score of 0.9600000008940697
# 1345 - episode (4 steps) is done with the score of 0.9700000006705523
# 1346 - episode (4 steps) is done with the score of 0.9700000006705523
# 1347 - episode (2 steps) is done with the score of 0.9900000002235174
# 1348 - episode (3 steps) is done with the score of 0.9800000004470348
# 1349 - episode (9 steps) is done with the score of 0.9200000017881393
# 1350 - episode (5 steps) is done with the score of 0.9600000008940697
# 1351 - episode (4 steps) is done with the score of 0.9700000006705523
# 1352 - episode (5 steps) is done with the score of 0.9600000008940697
# 1353 - episode (1 steps) is done with the score of 1.0
# 1354 - episode (2 steps) is done with the score of 0.9900000002235174
# 1355 - episode (5 steps) is done with the score of 0.9600000008940697
# 1356 - episode (4 steps) is done with the score of 0.9700000006705523
# 1357 - episode (5 steps) is done with the score of 0.9600000008940697
# 1358 - episode (1 steps) is done with the score of 1.0
# {1: 0.9800000004470348, 2: 0.9800000004470348, 3: 1.0, 4: 0.9700000006705523, 5: 0.9500000011175871, 6: 0.9900000002235174, 7: 0.9600000008940697, 8: 0.9800000004470348, 9: 0.9600000008940697, 10: 0.9900000002235174, 11: 0.9800000004470348, 12: 0.9900000002235174, 13: 1.0, 14: 0.9600000008940697, 15: 0.9800000004470348, 16: 0.9300000015646219, 17: 0.9900000002235174, 18: 0.9700000006705523, 19: 0.9700000006705523, 20: 0.9800000004470348, 21: 0.9500000011175871, 22: 0.9800000004470348, 23: 0.9800000004470348, 24: 0.9800000004470348, 25: 0.9600000008940697, 26: 0.9900000002235174, 27: 0.9700000006705523, 28: 1.0, 29: 0.9600000008940697, 30: 0.9500000011175871, 31: 0.9600000008940697, 32: 0.9800000004470348, 33: 0.9600000008940697, 34: 0.9700000006705523, 35: 0.9400000013411045, 36: 0.9800000004470348, 37: 1.0, 38: 1.0, 39: 0.9600000008940697, 40: 0.9700000006705523, 41: 0.9900000002235174, 42: 0.9800000004470348, 43: 0.9900000002235174, 44: 0.9700000006705523, 45: 0.9700000006705523, 46: 0.9400000013411045, 47: 0.9900000002235174, 48: 1.0, 49: 0.9800000004470348, 50: 0.9800000004470348, 51: 1.0, 52: 0.9500000011175871, 53: 0.9800000004470348, 54: 0.9900000002235174, 55: 0.9900000002235174,