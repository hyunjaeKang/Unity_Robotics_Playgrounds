# %% [markdown]
# # Kart Behvior-Clone

# %%
import numpy as np
import random
import copy
import datetime
import platform
import torch
import os
import torch.nn.functional as F
from torchvision.utils import save_image
from torch.utils.tensorboard import SummaryWriter
from collections import deque
from pathlib import Path
from mlagents_envs.environment import UnityEnvironment, ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel\
                             import EngineConfigurationChannel
from mlagents.trainers.demo_loader import demo_to_buffer
from mlagents.trainers.buffer import BufferKey, ObservationKeyPrefix

# %% [markdown]
# ## Setting environments

# %%
# Global Setting
cur_dir = os.getcwd()
env_dir = os.path.abspath(os.path.join(cur_dir, "..", "Unity6000_Envs"))
test_dir = os.path.abspath(os.path.join(cur_dir, "temp", "pytorch_output"))

# %% [markdown]
# ### Pytorch Device

# %%
# Pytorch Device
if torch.backends.mps.is_available():
    g_device = torch.device("mps")
elif torch.cuda.is_available():
    g_device = torch.device("cuda")
else:
    g_device = torch.device("cpu")

print(g_device)
# Out:
# mps

# %% [markdown]
# ### Unity Enviroment

# %%
# Unity Enviroment
game = "Kart"
os_name = platform.system()

if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# %% [markdown]
# ### Seting parameters for BC Network

# %%
# Seting parameters for Behavior Clone Network
state_size = 12 * 4
action_size = 1

load_model = False
train_mode = True

batch_size = 128
learning_rate = 3e-4
discount_factor = 0.9

train_epoch = 50000
test_step = 1000

print_interval = 10
save_interval = 100

unity_base_port = 1800

# %%
# NN model : Save and Load
date_time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
save_path = os.path.join(test_dir, f"saved_models/{game}/BC/{date_time}")
Path(save_path).mkdir(parents=True, exist_ok=True)
save_model_path = os.path.join(save_path, 'Kart_BC.ckpt')
# print(f"save_path :{save_path}")
# print(f"save_model_path :{save_model_path}")
load_path = "" # Need to update

# %% [markdown]
# ## Actor class -> Behavioral Cloning Actor class

# %%
# Actor class -> Behavioral Cloning Actor class
class Actor(torch.nn.Module):
    def __init__(self):
        super(Actor, self).__init__()
        self.fc1 = torch.nn.Linear(state_size, 128)
        self.fc2 = torch.nn.Linear(128, 128)
        self.fc3 = torch.nn.Linear(128, 128)
        self.fc4 = torch.nn.Linear(128, 64)
        self.fc5 = torch.nn.Linear(64, 32)
        self.mu = torch.nn.Linear(32, action_size)

    def forward(self, state):
        x = torch.tanh(self.fc1(state))
        x = torch.tanh(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        x = torch.tanh(self.fc4(x))
        x = torch.tanh(self.fc5(x))
        return torch.tanh(self.mu(x))

# %% [markdown]
# ## BCAgent class

# %%
# BCAgent class
class BCAgent():
    def __init__(self):
        self.actor = Actor().to(g_device)
        self.optimizer = torch.optim.Adam(self.actor.parameters(), lr=learning_rate)
        self.writer = SummaryWriter(save_path)

        if load_model == True:
            print(f"... Load Model from {load_path} ...")
            checkpoint = torch.load(load_path, map_location=g_device)
            self.actor.load_state_dict(checkpoint["actor"])
            self.optimizer.load_state_dict(checkpoint["optimizer"])

    #
    def get_action(self, state, training=False):
        self.actor.train(training)
        action = self.actor(torch.FloatTensor(state).to(g_device)).cpu().detach().numpy()
        return action

    #
    def train_model(self, state, action):
        losses = []

        rand_idx = torch.randperm(len(state))
        for iter in range(int(np.ceil(len(state)/batch_size))):
            _state = state[rand_idx[iter*batch_size: (iter+1)*batch_size]]
            _action = action[rand_idx[iter*batch_size: (iter+1)*batch_size]]

            action_pred = self.actor(_state)
            loss = F.mse_loss(_action, action_pred).mean()

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            losses.append(loss.item())

        return np.mean(losses)

    #
    def save_model(self):
        print(f"... Save Model to {save_model_path} ...")
        torch.save({
            "actor" : self.actor.state_dict(),
            "optimizer" : self.optimizer.state_dict(),
        }, save_model_path)


    def write_summray(self, loss, epoch):
        self.writer.add_scalar("model/loss", loss, epoch)

# %% [markdown]
# ## Train BC Model

# %%
agent = BCAgent()
# Demonstration
demo_path = os.path.abspath(os.path.join(cur_dir, "demo", "KartAgent.demo"))

if train_mode:
    # get the information of demo
    behavior_spec, demo_buffer = demo_to_buffer(demo_path, 1)
    print(demo_buffer._fields.keys())

    demo_to_tensor = lambda key: torch.FloatTensor(demo_buffer[key]).to(g_device)
    state = demo_to_tensor((ObservationKeyPrefix.OBSERVATION, 0))
    action = demo_to_tensor(BufferKey.CONTINUOUS_ACTION)
    reward = demo_to_tensor(BufferKey.ENVIRONMENT_REWARDS)
    done = demo_to_tensor(BufferKey.DONE)

    ret = reward.clone()
    for t in reversed(range(len(ret) - 1)):
        ret[t] += (1. - done[t]) * (discount_factor * ret[t+1])

    # use the pair of (state, action) which is greater than 0
    state, action = map(lambda x: x[ret > 0], [state, action])

    losses = []
    for epoch in range(1, train_epoch+1):
        loss = agent.train_model(state, action)
        losses.append(loss)

        # record tensorboard
        if epoch % print_interval == 0:
            mean_loss = np.mean(losses)
            print(f"{epoch} Epoch / Loss: {mean_loss:.8f}" )
            agent.write_summray(mean_loss, epoch)
            losses = []

        if epoch % save_interval == 0:
            agent.save_model()
# Out:
# dict_keys([<BufferKey.DONE: 'done'>, <BufferKey.ENVIRONMENT_REWARDS: 'environment_rewards'>, (<ObservationKeyPrefix.OBSERVATION: 'obs'>, 0), <BufferKey.CONTINUOUS_ACTION: 'continuous_action'>, <BufferKey.PREV_ACTION: 'prev_action'>])
# /var/folders/xk/hd_6wmxj32ngdnnm2x5h1_7r0000gn/T/ipykernel_96015/3016488891.py:10: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   demo_to_tensor = lambda key: torch.FloatTensor(demo_buffer[key]).to(g_device)
# 10 Epoch / Loss: 0.02545110
# 20 Epoch / Loss: 0.01323099
# 30 Epoch / Loss: 0.01052011
# 40 Epoch / Loss: 0.01000504
# 50 Epoch / Loss: 0.00937358
# 60 Epoch / Loss: 0.00918963
# 70 Epoch / Loss: 0.00888231
# 80 Epoch / Loss: 0.00875164
# 90 Epoch / Loss: 0.00839109
# 100 Epoch / Loss: 0.00785837
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 110 Epoch / Loss: 0.00749971
# 120 Epoch / Loss: 0.00818769
# 130 Epoch / Loss: 0.00723078
# 140 Epoch / Loss: 0.00727901
# 150 Epoch / Loss: 0.00727741
# 160 Epoch / Loss: 0.00718506
# 170 Epoch / Loss: 0.00698049
# 180 Epoch / Loss: 0.00697632
# 190 Epoch / Loss: 0.00671814
# 200 Epoch / Loss: 0.00657916
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
#
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 6710 Epoch / Loss: 0.00035660
# 6720 Epoch / Loss: 0.00025719
# 6730 Epoch / Loss: 0.00024853
# 6740 Epoch / Loss: 0.00041438
# 6750 Epoch / Loss: 0.00028081
# 6760 Epoch / Loss: 0.00126384
# 6770 Epoch / Loss: 0.00017879
# 6780 Epoch / Loss: 0.00014031
# 6790 Epoch / Loss: 0.00025899
# 6800 Epoch / Loss: 0.00024846
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 6810 Epoch / Loss: 0.00032394
# 6820 Epoch / Loss: 0.00016220
# 6830 Epoch / Loss: 0.00033009
# 6840 Epoch / Loss: 0.00057085
# 6850 Epoch / Loss: 0.00019534
# 6860 Epoch / Loss: 0.00035966
# 6870 Epoch / Loss: 0.00019864
# 6880 Epoch / Loss: 0.00039882
# 6890 Epoch / Loss: 0.00057903
# 6900 Epoch / Loss: 0.00025431
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 6910 Epoch / Loss: 0.00018969
# 6920 Epoch / Loss: 0.00022142
# 6930 Epoch / Loss: 0.00032045
# 6940 Epoch / Loss: 0.00022338
# 6950 Epoch / Loss: 0.00133435
# 6960 Epoch / Loss: 0.00021834
# 6970 Epoch / Loss: 0.00016212
# 6980 Epoch / Loss: 0.00043474
# 6990 Epoch / Loss: 0.00035922
# 7000 Epoch / Loss: 0.00013253
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7010 Epoch / Loss: 0.00037483
# 7020 Epoch / Loss: 0.00015933
# 7030 Epoch / Loss: 0.00029623
# 7040 Epoch / Loss: 0.00022984
# 7050 Epoch / Loss: 0.00055125
# 7060 Epoch / Loss: 0.00036790
# 7070 Epoch / Loss: 0.00026783
# 7080 Epoch / Loss: 0.00047140
# 7090 Epoch / Loss: 0.00021444
# 7100 Epoch / Loss: 0.00034023
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7110 Epoch / Loss: 0.00029425
# 7120 Epoch / Loss: 0.00023712
# 7130 Epoch / Loss: 0.00029404
# 7140 Epoch / Loss: 0.00052740
# 7150 Epoch / Loss: 0.00017442
# 7160 Epoch / Loss: 0.00056359
# 7170 Epoch / Loss: 0.00016141
# 7180 Epoch / Loss: 0.00027212
# 7190 Epoch / Loss: 0.00067872
# 7200 Epoch / Loss: 0.00017779
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7210 Epoch / Loss: 0.00029453
# 7220 Epoch / Loss: 0.00019181
# 7230 Epoch / Loss: 0.00021525
# 7240 Epoch / Loss: 0.00030433
# 7250 Epoch / Loss: 0.00037602
# 7260 Epoch / Loss: 0.00045414
# 7270 Epoch / Loss: 0.00018880
# 7280 Epoch / Loss: 0.00026048
# 7290 Epoch / Loss: 0.00020160
# 7300 Epoch / Loss: 0.00036274
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7310 Epoch / Loss: 0.00049932
# 7320 Epoch / Loss: 0.00036744
# 7330 Epoch / Loss: 0.00019390
# 7340 Epoch / Loss: 0.00027987
# 7350 Epoch / Loss: 0.00025250
# 7360 Epoch / Loss: 0.00051482
# 7370 Epoch / Loss: 0.00015088
# 7380 Epoch / Loss: 0.00039373
# 7390 Epoch / Loss: 0.00028523
# 7400 Epoch / Loss: 0.00052581
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7410 Epoch / Loss: 0.00033593
# 7420 Epoch / Loss: 0.00015117
# 7430 Epoch / Loss: 0.00052064
# 7440 Epoch / Loss: 0.00015606
# 7450 Epoch / Loss: 0.00029827
# 7460 Epoch / Loss: 0.00019277
# 7470 Epoch / Loss: 0.00038316
# 7480 Epoch / Loss: 0.00045124
# 7490 Epoch / Loss: 0.00022121
# 7500 Epoch / Loss: 0.00024336
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7510 Epoch / Loss: 0.00024376
# 7520 Epoch / Loss: 0.00043291
# 7530 Epoch / Loss: 0.00036806
# 7540 Epoch / Loss: 0.00013335
# 7550 Epoch / Loss: 0.00030963
# 7560 Epoch / Loss: 0.00024563
# 7570 Epoch / Loss: 0.00022284
# 7580 Epoch / Loss: 0.00027833
# 7590 Epoch / Loss: 0.00045926
# 7600 Epoch / Loss: 0.00054511
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7610 Epoch / Loss: 0.00014206
# 7620 Epoch / Loss: 0.00021053
# 7630 Epoch / Loss: 0.00041815
# 7640 Epoch / Loss: 0.00033967
# 7650 Epoch / Loss: 0.00051426
# 7660 Epoch / Loss: 0.00016246
# 7670 Epoch / Loss: 0.00031132
# 7680 Epoch / Loss: 0.00043122
# 7690 Epoch / Loss: 0.00015731
# 7700 Epoch / Loss: 0.00023781
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7710 Epoch / Loss: 0.00029630
# 7720 Epoch / Loss: 0.00026270
# 7730 Epoch / Loss: 0.00037705
# 7740 Epoch / Loss: 0.00029273
# 7750 Epoch / Loss: 0.00026426
# 7760 Epoch / Loss: 0.00040516
# 7770 Epoch / Loss: 0.00024098
# 7780 Epoch / Loss: 0.00028953
# 7790 Epoch / Loss: 0.00039880
# 7800 Epoch / Loss: 0.00029586
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7810 Epoch / Loss: 0.00014464
# 7820 Epoch / Loss: 0.00032221
# 7830 Epoch / Loss: 0.00023162
# 7840 Epoch / Loss: 0.00029921
# 7850 Epoch / Loss: 0.00044001
# 7860 Epoch / Loss: 0.00041741
# 7870 Epoch / Loss: 0.00012952
# 7880 Epoch / Loss: 0.00024677
# 7890 Epoch / Loss: 0.00024270
# 7900 Epoch / Loss: 0.00050068
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 7910 Epoch / Loss: 0.00045434
# 7920 Epoch / Loss: 0.00024257
# 7930 Epoch / Loss: 0.00014920
# 7940 Epoch / Loss: 0.00025376
# 7950 Epoch / Loss: 0.00080545
# 7960 Epoch / Loss: 0.00013467
# 7970 Epoch / Loss: 0.00022294
# 7980 Epoch / Loss: 0.00041251
# 7990 Epoch / Loss: 0.00026015
# 8000 Epoch / Loss: 0.00020660
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 8010 Epoch / Loss: 0.00072603
# 8020 Epoch / Loss: 0.00018882
# 8030 Epoch / Loss: 0.00024311
# 8040 Epoch / Loss: 0.00016343
# 8050 Epoch / Loss: 0.00027582
# 8060 Epoch / Loss: 0.00023220
# 8070 Epoch / Loss: 0.00041088
# 8080 Epoch / Loss: 0.00022783
# 8090 Epoch / Loss: 0.00027292
# 8100 Epoch / Loss: 0.00020199
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 8110 Epoch / Loss: 0.00021121
# 8120 Epoch / Loss: 0.00042160
# 8130 Epoch / Loss: 0.00044681
# 8140 Epoch / Loss: 0.00035696
# 8150 Epoch / Loss: 0.00013952
# 8160 Epoch / Loss: 0.00017245
# 8170 Epoch / Loss: 0.00024538
# 8180 Epoch / Loss: 0.00048639
# 8190 Epoch / Loss: 0.00023181
# 8200 Epoch / Loss: 0.00040851
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
#
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 47310 Epoch / Loss: 0.00007324
# 47320 Epoch / Loss: 0.00006739
# 47330 Epoch / Loss: 0.00044946
# 47340 Epoch / Loss: 0.00004445
# 47350 Epoch / Loss: 0.00003827
# 47360 Epoch / Loss: 0.00007998
# 47370 Epoch / Loss: 0.00033971
# 47380 Epoch / Loss: 0.00007366
# 47390 Epoch / Loss: 0.00014305
# 47400 Epoch / Loss: 0.00020287
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 47410 Epoch / Loss: 0.00005364
# 47420 Epoch / Loss: 0.00018182
# 47430 Epoch / Loss: 0.00006271
# 47440 Epoch / Loss: 0.00005787
# 47450 Epoch / Loss: 0.00018566
# 47460 Epoch / Loss: 0.00021451
# 47470 Epoch / Loss: 0.00005737
# 47480 Epoch / Loss: 0.00007454
# 47490 Epoch / Loss: 0.00013129
# 47500 Epoch / Loss: 0.00033875
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 47510 Epoch / Loss: 0.00011239
# 47520 Epoch / Loss: 0.00005447
# 47530 Epoch / Loss: 0.00004783
# 47540 Epoch / Loss: 0.00009754
# 47550 Epoch / Loss: 0.00008933
# 47560 Epoch / Loss: 0.00008137
# 47570 Epoch / Loss: 0.00011178
# 47580 Epoch / Loss: 0.00022290
# 47590 Epoch / Loss: 0.00018036
# 47600 Epoch / Loss: 0.00015831
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 47610 Epoch / Loss: 0.00005774
# 47620 Epoch / Loss: 0.00008590
# 47630 Epoch / Loss: 0.00028486
# 47640 Epoch / Loss: 0.00005117
# 47650 Epoch / Loss: 0.00005555
# 47660 Epoch / Loss: 0.00016488
# 47670 Epoch / Loss: 0.00020648
# 47680 Epoch / Loss: 0.00010527
# 47690 Epoch / Loss: 0.00005301
# 47700 Epoch / Loss: 0.00007632
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 47710 Epoch / Loss: 0.00007229
# 47720 Epoch / Loss: 0.00008179
# 47730 Epoch / Loss: 0.00046559
# 47740 Epoch / Loss: 0.00006122
# 47750 Epoch / Loss: 0.00006295
# 47760 Epoch / Loss: 0.00033704
# 47770 Epoch / Loss: 0.00016390
# 47780 Epoch / Loss: 0.00007416
# 47790 Epoch / Loss: 0.00008095
# 47800 Epoch / Loss: 0.00007778
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 47810 Epoch / Loss: 0.00011750
# 47820 Epoch / Loss: 0.00013751
# 47830 Epoch / Loss: 0.00006221
# 47840 Epoch / Loss: 0.00006947
# 47850 Epoch / Loss: 0.00018475
# 47860 Epoch / Loss: 0.00007464
# 47870 Epoch / Loss: 0.00019462
# 47880 Epoch / Loss: 0.00011493
# 47890 Epoch / Loss: 0.00005213
# 47900 Epoch / Loss: 0.00027709
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 47910 Epoch / Loss: 0.00006160
# 47920 Epoch / Loss: 0.00005340
# 47930 Epoch / Loss: 0.00041413
# 47940 Epoch / Loss: 0.00019361
# 47950 Epoch / Loss: 0.00006398
# 47960 Epoch / Loss: 0.00005598
# 47970 Epoch / Loss: 0.00006330
# 47980 Epoch / Loss: 0.00011785
# 47990 Epoch / Loss: 0.00017409
# 48000 Epoch / Loss: 0.00054296
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48010 Epoch / Loss: 0.00005659
# 48020 Epoch / Loss: 0.00002996
# 48030 Epoch / Loss: 0.00007425
# 48040 Epoch / Loss: 0.00005278
# 48050 Epoch / Loss: 0.00013843
# 48060 Epoch / Loss: 0.00005088
# 48070 Epoch / Loss: 0.00006772
# 48080 Epoch / Loss: 0.00018250
# 48090 Epoch / Loss: 0.00020821
# 48100 Epoch / Loss: 0.00012197
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48110 Epoch / Loss: 0.00012557
# 48120 Epoch / Loss: 0.00005455
# 48130 Epoch / Loss: 0.00015301
# 48140 Epoch / Loss: 0.00007022
# 48150 Epoch / Loss: 0.00009634
# 48160 Epoch / Loss: 0.00030261
# 48170 Epoch / Loss: 0.00013167
# 48180 Epoch / Loss: 0.00006108
# 48190 Epoch / Loss: 0.00016320
# 48200 Epoch / Loss: 0.00010681
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48210 Epoch / Loss: 0.00009019
# 48220 Epoch / Loss: 0.00009684
# 48230 Epoch / Loss: 0.00013667
# 48240 Epoch / Loss: 0.00009113
# 48250 Epoch / Loss: 0.00031685
# 48260 Epoch / Loss: 0.00010952
# 48270 Epoch / Loss: 0.00028445
# 48280 Epoch / Loss: 0.00009080
# 48290 Epoch / Loss: 0.00005969
# 48300 Epoch / Loss: 0.00009661
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48310 Epoch / Loss: 0.00015484
# 48320 Epoch / Loss: 0.00004193
# 48330 Epoch / Loss: 0.00010417
# 48340 Epoch / Loss: 0.00008048
# 48350 Epoch / Loss: 0.00019076
# 48360 Epoch / Loss: 0.00017445
# 48370 Epoch / Loss: 0.00008316
# 48380 Epoch / Loss: 0.00006950
# 48390 Epoch / Loss: 0.00010977
# 48400 Epoch / Loss: 0.00007128
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48410 Epoch / Loss: 0.00013783
# 48420 Epoch / Loss: 0.00030965
# 48430 Epoch / Loss: 0.00013973
# 48440 Epoch / Loss: 0.00010358
# 48450 Epoch / Loss: 0.00010118
# 48460 Epoch / Loss: 0.00011079
# 48470 Epoch / Loss: 0.00011693
# 48480 Epoch / Loss: 0.00004886
# 48490 Epoch / Loss: 0.00016754
# 48500 Epoch / Loss: 0.00014806
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48510 Epoch / Loss: 0.00004424
# 48520 Epoch / Loss: 0.00010660
# 48530 Epoch / Loss: 0.00012125
# 48540 Epoch / Loss: 0.00025945
# 48550 Epoch / Loss: 0.00021204
# 48560 Epoch / Loss: 0.00011551
# 48570 Epoch / Loss: 0.00010484
# 48580 Epoch / Loss: 0.00010993
# 48590 Epoch / Loss: 0.00020298
# 48600 Epoch / Loss: 0.00004826
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48610 Epoch / Loss: 0.00005699
# 48620 Epoch / Loss: 0.00034683
# 48630 Epoch / Loss: 0.00005843
# 48640 Epoch / Loss: 0.00006580
# 48650 Epoch / Loss: 0.00009846
# 48660 Epoch / Loss: 0.00016960
# 48670 Epoch / Loss: 0.00006810
# 48680 Epoch / Loss: 0.00008771
# 48690 Epoch / Loss: 0.00016650
# 48700 Epoch / Loss: 0.00023579
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48710 Epoch / Loss: 0.00006932
# 48720 Epoch / Loss: 0.00005470
# 48730 Epoch / Loss: 0.00008918
# 48740 Epoch / Loss: 0.00022748
# 48750 Epoch / Loss: 0.00010095
# 48760 Epoch / Loss: 0.00011898
# 48770 Epoch / Loss: 0.00008453
# 48780 Epoch / Loss: 0.00010217
# 48790 Epoch / Loss: 0.00007635
# 48800 Epoch / Loss: 0.00025380
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48810 Epoch / Loss: 0.00024743
# 48820 Epoch / Loss: 0.00006088
# 48830 Epoch / Loss: 0.00004620
# 48840 Epoch / Loss: 0.00032136
# 48850 Epoch / Loss: 0.00003909
# 48860 Epoch / Loss: 0.00010006
# 48870 Epoch / Loss: 0.00004744
# 48880 Epoch / Loss: 0.00006451
# 48890 Epoch / Loss: 0.00008304
# 48900 Epoch / Loss: 0.00034203
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 48910 Epoch / Loss: 0.00005764
# 48920 Epoch / Loss: 0.00007019
# 48930 Epoch / Loss: 0.00039695
# 48940 Epoch / Loss: 0.00006488
# 48950 Epoch / Loss: 0.00004836
# 48960 Epoch / Loss: 0.00015385
# 48970 Epoch / Loss: 0.00007617
# 48980 Epoch / Loss: 0.00013582
# 48990 Epoch / Loss: 0.00008564
# 49000 Epoch / Loss: 0.00017084
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49010 Epoch / Loss: 0.00018752
# 49020 Epoch / Loss: 0.00016580
# 49030 Epoch / Loss: 0.00015344
# 49040 Epoch / Loss: 0.00018941
# 49050 Epoch / Loss: 0.00004355
# 49060 Epoch / Loss: 0.00029898
# 49070 Epoch / Loss: 0.00008216
# 49080 Epoch / Loss: 0.00008621
# 49090 Epoch / Loss: 0.00005871
# 49100 Epoch / Loss: 0.00014362
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49110 Epoch / Loss: 0.00008155
# 49120 Epoch / Loss: 0.00009249
# 49130 Epoch / Loss: 0.00007426
# 49140 Epoch / Loss: 0.00006035
# 49150 Epoch / Loss: 0.00019656
# 49160 Epoch / Loss: 0.00005631
# 49170 Epoch / Loss: 0.00007303
# 49180 Epoch / Loss: 0.00016392
# 49190 Epoch / Loss: 0.00017413
# 49200 Epoch / Loss: 0.00005233
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49210 Epoch / Loss: 0.00024403
# 49220 Epoch / Loss: 0.00004973
# 49230 Epoch / Loss: 0.00004970
# 49240 Epoch / Loss: 0.00035246
# 49250 Epoch / Loss: 0.00028371
# 49260 Epoch / Loss: 0.00009677
# 49270 Epoch / Loss: 0.00004206
# 49280 Epoch / Loss: 0.00013584
# 49290 Epoch / Loss: 0.00007755
# 49300 Epoch / Loss: 0.00008697
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49310 Epoch / Loss: 0.00008796
# 49320 Epoch / Loss: 0.00014120
# 49330 Epoch / Loss: 0.00034182
# 49340 Epoch / Loss: 0.00015686
# 49350 Epoch / Loss: 0.00009027
# 49360 Epoch / Loss: 0.00041048
# 49370 Epoch / Loss: 0.00004816
# 49380 Epoch / Loss: 0.00005680
# 49390 Epoch / Loss: 0.00004135
# 49400 Epoch / Loss: 0.00006789
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49410 Epoch / Loss: 0.00013414
# 49420 Epoch / Loss: 0.00009464
# 49430 Epoch / Loss: 0.00006299
# 49440 Epoch / Loss: 0.00014119
# 49450 Epoch / Loss: 0.00020834
# 49460 Epoch / Loss: 0.00007578
# 49470 Epoch / Loss: 0.00033023
# 49480 Epoch / Loss: 0.00010846
# 49490 Epoch / Loss: 0.00012890
# 49500 Epoch / Loss: 0.00008092
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49510 Epoch / Loss: 0.00005888
# 49520 Epoch / Loss: 0.00012820
# 49530 Epoch / Loss: 0.00008973
# 49540 Epoch / Loss: 0.00023071
# 49550 Epoch / Loss: 0.00004892
# 49560 Epoch / Loss: 0.00004858
# 49570 Epoch / Loss: 0.00016667
# 49580 Epoch / Loss: 0.00043388
# 49590 Epoch / Loss: 0.00003331
# 49600 Epoch / Loss: 0.00010939
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49610 Epoch / Loss: 0.00005327
# 49620 Epoch / Loss: 0.00006240
# 49630 Epoch / Loss: 0.00010025
# 49640 Epoch / Loss: 0.00011502
# 49650 Epoch / Loss: 0.00019673
# 49660 Epoch / Loss: 0.00008911
# 49670 Epoch / Loss: 0.00006048
# 49680 Epoch / Loss: 0.00010592
# 49690 Epoch / Loss: 0.00014378
# 49700 Epoch / Loss: 0.00013837
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49710 Epoch / Loss: 0.00005958
# 49720 Epoch / Loss: 0.00019939
# 49730 Epoch / Loss: 0.00018841
# 49740 Epoch / Loss: 0.00018626
# 49750 Epoch / Loss: 0.00005649
# 49760 Epoch / Loss: 0.00011400
# 49770 Epoch / Loss: 0.00010806
# 49780 Epoch / Loss: 0.00009653
# 49790 Epoch / Loss: 0.00017516
# 49800 Epoch / Loss: 0.00004572
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49810 Epoch / Loss: 0.00013409
# 49820 Epoch / Loss: 0.00036156
# 49830 Epoch / Loss: 0.00006866
# 49840 Epoch / Loss: 0.00011768
# 49850 Epoch / Loss: 0.00013491
# 49860 Epoch / Loss: 0.00006329
# 49870 Epoch / Loss: 0.00017319
# 49880 Epoch / Loss: 0.00009381
# 49890 Epoch / Loss: 0.00009853
# 49900 Epoch / Loss: 0.00026488
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...
# 49910 Epoch / Loss: 0.00014957
# 49920 Epoch / Loss: 0.00006791
# 49930 Epoch / Loss: 0.00006734
# 49940 Epoch / Loss: 0.00009012
# 49950 Epoch / Loss: 0.00010930
# 49960 Epoch / Loss: 0.00006468
# 49970 Epoch / Loss: 0.00010978
# 49980 Epoch / Loss: 0.00017341
# 49990 Epoch / Loss: 0.00022068
# 50000 Epoch / Loss: 0.00020407
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Kart/BC/20250919103153/Kart_BC.ckpt ...

# %% [markdown]
# ## Test the pretrained BC model

# %%
# Start Play for testing
print("PLAY START-Kart")

# Unity Enviroment
game = "Kart"
os_name = platform.system()
if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# Setup Unity Environment
engine_configuration_channel = EngineConfigurationChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel],
                       base_port=unity_base_port)
env.reset()

# setup unity ml agent
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=1.0)
dec, term = env.get_steps(behavior_name)

# TEST
episode, score = 0, 0
for step in range(test_step):
    state = dec.obs[0]
    action = agent.get_action(state, False)
    action_tuple = ActionTuple()
    action_tuple.add_continuous(action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    dec, term = env.get_steps(behavior_name)
    done = len(term.agent_id) > 0
    reward = term.reward if done else dec.reward
    next_state = term.obs[0] if done else dec.obs[0]
    score += reward[0]

    if done:
        episode += 1

        # print out
        print(f"{episode} Episode / Step: {step} / Score: {score:.2f} ")
        score = 0

env.close()
# Out:
# PLAY START-Kart
# ---------------------------------------------------------------------------
# UnityEnvironmentException                 Traceback (most recent call last)
# Cell In[10], line 14
#      12 # Setup Unity Environment
#      13 engine_configuration_channel = EngineConfigurationChannel()
# ---> 14 env = UnityEnvironment(file_name=env_name,
#      15                        side_channels=[engine_configuration_channel],
#      16                        base_port=unity_base_port)
#      17 env.reset()
#      19 # setup unity ml agent
#
# File ~/anaconda3/envs/mlagents/lib/python3.10/site-packages/mlagents_envs/environment.py:215, in UnityEnvironment.__init__(self, file_name, worker_id, base_port, seed, no_graphics, no_graphics_monitor, timeout_wait, additional_args, side_channels, log_folder, num_areas)
#     213 if file_name is not None:
#     214     try:
# --> 215         self._process = env_utils.launch_executable(
#     216             file_name, self._executable_args()
#     217         )
#     218     except UnityEnvironmentException:
#     219         self._close(0)
#
# File ~/anaconda3/envs/mlagents/lib/python3.10/site-packages/mlagents_envs/env_utils.py:101, in launch_executable(file_name, args)
#      99 launch_string = validate_environment_path(file_name)
#     100 if launch_string is None:
# --> 101     raise UnityEnvironmentException(
#     102         f"Couldn't launch the {file_name} environment. Provided filename does not match any environments."
#     103     )
#     104 else:
#     105     logger.debug(f"The launch string is {launch_string}")
#
# UnityEnvironmentException: Couldn't launch the /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Unity6000_Envs/Kart_Darwin.app environment. Provided filename does not match any environments.

# %%
# Start Play for testing
print("PLAY START-Kart-Country")

# Unity Enviroment
game = "Kart_Country"
os_name = platform.system()
if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# Setup Unity Environment
engine_configuration_channel = EngineConfigurationChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel],
                       base_port=1999)
env.reset()

# setup unity ml agent
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=1.0)
dec, term = env.get_steps(behavior_name)

# TEST
episode, score = 0, 0
for step in range(5000):
    state = dec.obs[0]
    action = agent.get_action(state, False)
    action_tuple = ActionTuple()
    action_tuple.add_continuous(action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    dec, term = env.get_steps(behavior_name)
    done = len(term.agent_id) > 0
    reward = term.reward if done else dec.reward
    next_state = term.obs[0] if done else dec.obs[0]
    score += reward[0]

    if done:
        episode += 1

        # print out
        print(f"{episode} Episode / Step: {step} / Score: {score:.2f} ")
        score = 0

env.close()

# %%
# Start Play for testing
print("PLAY START-Kart-Mountain")

# Unity Enviroment
game = "Kart_Mountain"
os_name = platform.system()
if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# Setup Unity Environment
engine_configuration_channel = EngineConfigurationChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel],
                       base_port=1999)
env.reset()

# setup unity ml agent
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=1.0)
dec, term = env.get_steps(behavior_name)

# TEST
episode, score = 0, 0
for step in range(5000):
    state = dec.obs[0]
    action = agent.get_action(state, False)
    action_tuple = ActionTuple()
    action_tuple.add_continuous(action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    dec, term = env.get_steps(behavior_name)
    done = len(term.agent_id) > 0
    reward = term.reward if done else dec.reward
    next_state = term.obs[0] if done else dec.obs[0]
    score += reward[0]

    if done:
        episode += 1

        # print out
        print(f"{episode} Episode / Step: {step} / Score: {score:.2f} ")
        score = 0

env.close()
