# %% [markdown]
# # Pong Adversarial

# %%
import os
from pathlib import Path
import numpy as np
import datetime
import platform
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from mlagents_envs.environment import UnityEnvironment, ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel\
                             import EngineConfigurationChannel
from mlagents_envs.side_channel.environment_parameters_channel\
                             import EnvironmentParametersChannel

# %% [markdown]
# ## Setting environments

# %%
# Global Setting
cur_dir = os.getcwd()
env_dir = os.path.abspath(os.path.join(cur_dir, "..", "Unity6000_Envs"))
test_dir = os.path.abspath(os.path.join(cur_dir, "temp", "pytorch_output"))

# %% [markdown]
# ### Pytorch Device

# %%
# Pytorch Device
if torch.backends.mps.is_available():
    g_device = torch.device("mps")
elif torch.cuda.is_available():
    g_device = torch.device("cuda")
else:
    g_device = torch.device("cpu")

print(g_device)
# Out:
# mps

# %% [markdown]
# ### Unity Enviroment

# %%
# Unity Enviroment
game = "Pong"
os_name = platform.system()

if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# %% [markdown]
# ### Seting parameters for PPO

# %%
# Parameters
state_size = 6
action_size = 3

load_model = False
train_mode = True

discount_factor = 0.99
learning_rate = 5e-4
n_step = 512
batch_size = 128
n_epoch = 3
_lambda = 0.95
epsilon = 0.2

run_step = 1000000 if train_mode else 0
test_step = 50000

print_interval = 10
save_interval = 100

# Setting parameters for Dodge Environments
env_static_config = {"ballSpeed": 4, "ballRandom": 0.2, "agentSpeed": 3}
env_dynamic_config = {"boardRadius": {"min":6, "max": 8, "seed": 77},
                      "ballNums": {"min": 10, "max": 15, "seed": 77}}


unity_base_port = 1766

# %%
# NN model : Save and Load
date_time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
save_path = os.path.join(test_dir, f"saved_models/{game}/Adversarial/{date_time}")
Path(save_path).mkdir(parents=True, exist_ok=True)
save_model_path = os.path.join(save_path, 'Pong_Adversarial.ckpt')
# print(f"save_path :{save_path}")
# print(f"save_model_path :{save_model_path}")
load_path = "" # Need to update

# %% [markdown]
# ## Model for Actor-Critic

# %%
class ActorCritic(torch.nn.Module):
    def __init__(self, **kwargs):
        super(ActorCritic, self).__init__(**kwargs)
        self.d1 = torch.nn.Linear(state_size, 128)
        self.d2 = torch.nn.Linear(128, 128)
        self.pi = torch.nn.Linear(128, action_size)
        self.v = torch.nn.Linear(128, 1)

    def forward(self, x):
        x = F.relu(self.d1(x))
        x = F.relu(self.d2(x))
        return F.softmax(self.pi(x), dim=-1), self.v(x)

# %% [markdown]
# ## Agent class

# %%
# Agent Class
class PPOAgent:
    def __init__(self, id):
        self.network = ActorCritic().to(g_device)
        self.optimizer = torch.optim.Adam(self.network.parameters(), lr = learning_rate)
        self.memory = list()
        self.save_path = f"{save_path}/{id}"
        self.load_path = f"{load_path}/{id}"
        self.writer = SummaryWriter(self.save_path)
        self.save_model_path = os.path.join(self.save_path, 'Pong_Adversarial.ckpt')
        self.load_model_path = os.path.join(self.load_path, 'Pong_Adversarial.ckpt')

        if load_model == True:
            print(f"... Load Model from {self.load_model_path} ...")
            checkpoint = torch.load(self.load_model_path, map_location=g_device)
            self.network.load_state_dict(checkpoint["network"])
            self.optimizer.load_state_dict(checkpoint["optimizer"])

    def get_action(self, state, training = True):
        self.network.train(training)
        pi, _ = self.network(torch.FloatTensor(state).to(g_device))
        action = torch.multinomial(pi, num_samples=1).cpu().numpy()
        return action

    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def train_model(self):
        self.network.train()

        state      = np.stack([m[0] for m in self.memory], axis=0)
        action     = np.stack([m[1] for m in self.memory], axis=0)
        reward     = np.stack([m[2] for m in self.memory], axis=0)
        next_state = np.stack([m[3] for m in self.memory], axis=0)
        done       = np.stack([m[4] for m in self.memory], axis=0)
        self.memory.clear()

        state, action, reward, next_state, done = map(lambda x: torch.FloatTensor(x).to(g_device),
                                                        [state, action, reward, next_state, done])
        # prob_old, adv, ret
        with torch.no_grad():
            pi_old, value = self.network(state)
            prob_old = pi_old.gather(1, action.long())

            _, next_value = self.network(next_state)
            delta = reward + (1 - done) * discount_factor * next_value - value
            adv = delta.clone()
            adv, done = map(lambda x: x.view(n_step, -1).transpose(0,1).contiguous(), [adv, done])
            for t in reversed(range(n_step-1)):
                adv[:, t] += (1 - done[:, t]) * discount_factor * _lambda * adv[:, t+1]
            adv = adv.transpose(0,1).contiguous().view(-1, 1)

            ret = adv + value

        # training
        actor_losses, critic_losses = [], []
        idxs = np.arange(len(reward))
        for _ in range(n_epoch):
            np.random.shuffle(idxs)
            for offset in range(0, len(reward), batch_size):
                idx = idxs[offset : offset + batch_size]

                _state, _action, _ret, _adv, _prob_old =\
                    map(lambda x: x[idx], [state, action, ret, adv, prob_old])

                pi, value = self.network(_state)
                prob = pi.gather(1, _action.long())

                # loss function for policy network
                ratio = prob / (_prob_old + 1e-7)
                surr1 = ratio * _adv
                surr2 = torch.clamp(ratio, min=1-epsilon, max=1+epsilon) * _adv
                actor_loss = -torch.min(surr1, surr2).mean()

                # loss function for value network
                critic_loss = F.mse_loss(value, _ret).mean()

                total_loss = actor_loss + critic_loss

                self.optimizer.zero_grad()
                total_loss.backward()
                self.optimizer.step()

                actor_losses.append(actor_loss.item())
                critic_losses.append(critic_loss.item())

        return np.mean(actor_losses), np.mean(critic_losses)


    def save_model(self):
        print(f"... Save Model to {self.save_path}/ckpt ...")
        torch.save({
            "network" : self.network.state_dict(),
            "optimizer" : self.optimizer.state_dict(),
        }, self.save_model_path)

    def write_summary(self, score, actor_loss, critic_loss, step):
        self.writer.add_scalar("PPO_Random_run/score", score, step)
        self.writer.add_scalar("PPO_Random_model/actor_loss", actor_loss, step)
        self.writer.add_scalar("PPO_Random_model/critic_loss", critic_loss, step)
        # self.writer.add_scalar("PPO_Random_model/total_loss", total_loss, step)

# %% [markdown]
# ## Train Model

# %%
engine_configuration_channel = EngineConfigurationChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel],
                       base_port=unity_base_port)
env.reset()

# Setup Unity Behavior
behavior_name_list = list(env.behavior_specs.keys())
behavior_A = behavior_name_list[0]
behavior_B = behavior_name_list[1]
engine_configuration_channel.set_configuration_parameters(time_scale=12.0)
dec_A, term_A = env.get_steps(behavior_A)
dec_B, term_B = env.get_steps(behavior_B)

# Setup objects of PPOAgent for agent_A and agent_B
agent_A = PPOAgent("A")
agent_B = PPOAgent("B")

episode = 0
actor_losses_A, critic_losses_A, scores_A, score_A = [], [], [], 0
actor_losses_B, critic_losses_B, scores_B, score_B = [], [], [], 0
for step in range(run_step + test_step):
    if step == run_step:
        if train_mode:
            agent_A.save_model()
            agent_B.save_model()
        print("TEST START")
        train_mode = False
        engine_configuration_channel.set_configuration_parameters(time_scale=1.0)

    state_A = dec_A.obs[0]
    state_B = dec_B.obs[0]
    action_A = agent_A.get_action(state_A, train_mode)
    action_B = agent_B.get_action(state_B, train_mode)
    action_tuple_A, action_tuple_B = map(lambda x: ActionTuple(discrete=x), [action_A, action_B])
    env.set_actions(behavior_A, action_tuple_A)
    env.set_actions(behavior_B, action_tuple_B)
    env.step()

    dec_A, term_A = env.get_steps(behavior_A)
    dec_B, term_B = env.get_steps(behavior_B)
    done_A = len(term_A.agent_id) > 0
    done_B = len(term_B.agent_id) > 0
    next_state_A = term_A.obs[0] if done_A else dec_A.obs[0]
    next_state_B = term_B.obs[0] if done_B else dec_B.obs[0]
    reward_A = term_A.reward if done_A else dec_A.reward
    reward_B = term_B.reward if done_B else dec_B.reward
    score_A += reward_A[0]
    score_B += reward_B[0]

    if train_mode:
        agent_A.append_sample(state_A[0], action_A[0], reward_A, next_state_A[0], [done_A])
        agent_B.append_sample(state_B[0], action_B[0], reward_B, next_state_B[0], [done_B])

        if (step+1) % n_step == 0:
            # Training
            actor_loss_A, critic_loss_A = agent_A.train_model()
            actor_loss_B, critic_loss_B = agent_B.train_model()
            actor_losses_A.append(actor_loss_A)
            critic_losses_A.append(critic_loss_A)
            actor_losses_B.append(actor_loss_B)
            critic_losses_B.append(critic_loss_B)

    if done_A or done_B:
        episode +=1
        scores_A.append(score_A)
        scores_B.append(score_B)
        score_A = score_B = 0

        # logging tensorboard
        if episode % print_interval == 0:
            mean_score_A = np.mean(scores_A)
            mean_score_B = np.mean(scores_B)
            mean_actor_loss_A = np.mean(actor_losses_A) if len(actor_losses_A) > 0 else 0
            mean_critic_loss_A = np.mean(critic_losses_A) if len(critic_losses_A) > 0 else 0
            mean_actor_loss_B = np.mean(actor_losses_B) if len(actor_losses_B) > 0 else 0
            mean_critic_loss_B = np.mean(critic_losses_B) if len(critic_losses_B) > 0 else 0
            agent_A.write_summary(mean_score_A, mean_actor_loss_A, mean_critic_loss_A, step)
            agent_B.write_summary(mean_score_B, mean_actor_loss_B, mean_critic_loss_B, step)
            actor_losses_A, critic_losses_A, scores_A = [], [], []
            actor_losses_B, critic_losses_B, scores_B = [], [], []

            print(f"{episode} Episode / Step: {step} / "  +\
                    f"A Score: {mean_score_A:.2f} / B Score: {mean_score_B:.2f} / " +\
                    f"A Actor Loss: {mean_actor_loss_A:.4f} / A Critic Loss: {mean_critic_loss_A:.4f} / " +\
                    f"B Actor Loss: {mean_actor_loss_B:.4f} / B Critic Loss: {mean_critic_loss_B:.4f}")

        # save network model
        if train_mode and episode % save_interval == 0:
            agent_A.save_model()
            agent_B.save_model()

env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# 10 Episode / Step: 600 / A Score: -0.15 / B Score: 0.30 / A Actor Loss: 0.0458 / A Critic Loss: 0.0605 / B Actor Loss: -0.0746 / B Critic Loss: 0.1377
# 20 Episode / Step: 1212 / A Score: 0.30 / B Score: -0.15 / A Actor Loss: -0.0199 / A Critic Loss: 0.0504 / B Actor Loss: 0.0195 / B Critic Loss: 0.0726
# 30 Episode / Step: 1980 / A Score: -0.30 / B Score: 0.55 / A Actor Loss: 0.0335 / A Critic Loss: 0.0882 / B Actor Loss: -0.0589 / B Critic Loss: 0.0514
# 40 Episode / Step: 2758 / A Score: -0.10 / B Score: 0.35 / A Actor Loss: -0.0337 / A Critic Loss: 0.0810 / B Actor Loss: -0.0169 / B Critic Loss: 0.0620
# 50 Episode / Step: 3357 / A Score: -0.35 / B Score: 0.50 / A Actor Loss: 0.0445 / A Critic Loss: 0.0577 / B Actor Loss: -0.0694 / B Critic Loss: 0.0805
# 60 Episode / Step: 3830 / A Score: -0.20 / B Score: 0.25 / A Actor Loss: 0.1309 / A Critic Loss: 0.0403 / B Actor Loss: -0.1250 / B Critic Loss: 0.0653
# 70 Episode / Step: 4473 / A Score: -0.20 / B Score: 0.35 / A Actor Loss: -0.0366 / A Critic Loss: 0.0306 / B Actor Loss: 0.0346 / B Critic Loss: 0.0475
# 80 Episode / Step: 5201 / A Score: -0.15 / B Score: 0.25 / A Actor Loss: 0.0025 / A Critic Loss: 0.0332 / B Actor Loss: 0.0089 / B Critic Loss: 0.0502
# 90 Episode / Step: 5589 / A Score: -0.20 / B Score: 0.20 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 100 Episode / Step: 6236 / A Score: -0.35 / B Score: 0.50 / A Actor Loss: -0.0288 / A Critic Loss: 0.0311 / B Actor Loss: 0.0368 / B Critic Loss: 0.0522
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 110 Episode / Step: 6762 / A Score: 0.00 / B Score: 0.10 / A Actor Loss: -0.0006 / A Critic Loss: 0.0225 / B Actor Loss: -0.0009 / B Critic Loss: 0.0429
# 120 Episode / Step: 7407 / A Score: -0.40 / B Score: 0.50 / A Actor Loss: 0.0617 / A Critic Loss: 0.0464 / B Actor Loss: -0.0748 / B Critic Loss: 0.0828
# 130 Episode / Step: 7936 / A Score: -0.60 / B Score: 0.65 / A Actor Loss: 0.0377 / A Critic Loss: 0.0291 / B Actor Loss: -0.0532 / B Critic Loss: 0.0524
# 140 Episode / Step: 8570 / A Score: 0.50 / B Score: -0.35 / A Actor Loss: -0.1741 / A Critic Loss: 0.0810 / B Actor Loss: 0.1740 / B Critic Loss: 0.0653
# 150 Episode / Step: 9204 / A Score: -0.55 / B Score: 0.75 / A Actor Loss: 0.0638 / A Critic Loss: 0.0369 / B Actor Loss: -0.0471 / B Critic Loss: 0.0598
# 160 Episode / Step: 9888 / A Score: -0.15 / B Score: 0.35 / A Actor Loss: 0.0050 / A Critic Loss: 0.0745 / B Actor Loss: -0.0319 / B Critic Loss: 0.0833
# 170 Episode / Step: 10879 / A Score: 0.35 / B Score: 0.00 / A Actor Loss: -0.0234 / A Critic Loss: 0.0749 / B Actor Loss: 0.0324 / B Critic Loss: 0.0797
# 180 Episode / Step: 11532 / A Score: 0.45 / B Score: -0.30 / A Actor Loss: -0.1095 / A Critic Loss: 0.0514 / B Actor Loss: 0.1265 / B Critic Loss: 0.0617
# 190 Episode / Step: 11911 / A Score: 0.00 / B Score: 0.00 / A Actor Loss: 0.0744 / A Critic Loss: 0.0646 / B Actor Loss: -0.0261 / B Critic Loss: 0.0651
# 200 Episode / Step: 12692 / A Score: 0.15 / B Score: 0.10 / A Actor Loss: -0.0324 / A Critic Loss: 0.0662 / B Actor Loss: 0.0493 / B Critic Loss: 0.0616
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 210 Episode / Step: 13407 / A Score: 0.45 / B Score: -0.30 / A Actor Loss: 0.0117 / A Critic Loss: 0.0711 / B Actor Loss: -0.0205 / B Critic Loss: 0.0663
# 220 Episode / Step: 14023 / A Score: 0.50 / B Score: -0.40 / A Actor Loss: -0.0209 / A Critic Loss: 0.0473 / B Actor Loss: 0.0640 / B Critic Loss: 0.0331
# 230 Episode / Step: 14771 / A Score: -0.35 / B Score: 0.60 / A Actor Loss: 0.0582 / A Critic Loss: 0.0906 / B Actor Loss: -0.0326 / B Critic Loss: 0.1171
# 240 Episode / Step: 15417 / A Score: 0.25 / B Score: -0.15 / A Actor Loss: 0.0419 / A Critic Loss: 0.0587 / B Actor Loss: -0.0229 / B Critic Loss: 0.0681
# 250 Episode / Step: 16343 / A Score: -0.05 / B Score: 0.35 / A Actor Loss: 0.0427 / A Critic Loss: 0.0577 / B Actor Loss: -0.0708 / B Critic Loss: 0.0690
# 260 Episode / Step: 16894 / A Score: -0.15 / B Score: 0.25 / A Actor Loss: -0.1077 / A Critic Loss: 0.0755 / B Actor Loss: 0.0764 / B Critic Loss: 0.0541
# 270 Episode / Step: 17943 / A Score: 1.00 / B Score: -0.75 / A Actor Loss: -0.0397 / A Critic Loss: 0.0470 / B Actor Loss: 0.0394 / B Critic Loss: 0.0396
# 280 Episode / Step: 18649 / A Score: -0.30 / B Score: 0.55 / A Actor Loss: 0.1961 / A Critic Loss: 0.1057 / B Actor Loss: -0.1912 / B Critic Loss: 0.1134
# 290 Episode / Step: 19251 / A Score: -0.15 / B Score: 0.30 / A Actor Loss: 0.0518 / A Critic Loss: 0.0800 / B Actor Loss: -0.0201 / B Critic Loss: 0.0652
# 300 Episode / Step: 19750 / A Score: 0.45 / B Score: -0.40 / A Actor Loss: 0.0317 / A Critic Loss: 0.0288 / B Actor Loss: 0.0117 / B Critic Loss: 0.0401
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 310 Episode / Step: 20549 / A Score: 0.10 / B Score: 0.15 / A Actor Loss: -0.0239 / A Critic Loss: 0.0633 / B Actor Loss: 0.0180 / B Critic Loss: 0.0649
# 320 Episode / Step: 21496 / A Score: 0.20 / B Score: 0.10 / A Actor Loss: -0.0669 / A Critic Loss: 0.0752 / B Actor Loss: 0.0794 / B Critic Loss: 0.0383
# 330 Episode / Step: 22088 / A Score: 0.05 / B Score: 0.05 / A Actor Loss: 0.0184 / A Critic Loss: 0.0528 / B Actor Loss: -0.0359 / B Critic Loss: 0.0516
# 340 Episode / Step: 22851 / A Score: 0.75 / B Score: -0.50 / A Actor Loss: -0.0718 / A Critic Loss: 0.1016 / B Actor Loss: 0.0606 / B Critic Loss: 0.0785
# 350 Episode / Step: 23313 / A Score: 0.05 / B Score: 0.00 / A Actor Loss: -0.0054 / A Critic Loss: 0.0618 / B Actor Loss: 0.0382 / B Critic Loss: 0.0480
# 360 Episode / Step: 23910 / A Score: 0.10 / B Score: 0.00 / A Actor Loss: -0.0872 / A Critic Loss: 0.0560 / B Actor Loss: 0.0998 / B Critic Loss: 0.0274
# 370 Episode / Step: 24573 / A Score: 0.50 / B Score: -0.30 / A Actor Loss: 0.0788 / A Critic Loss: 0.0686 / B Actor Loss: -0.0020 / B Critic Loss: 0.0338
# 380 Episode / Step: 25369 / A Score: -0.40 / B Score: 0.55 / A Actor Loss: 0.0923 / A Critic Loss: 0.0731 / B Actor Loss: -0.0916 / B Critic Loss: 0.0900
# 390 Episode / Step: 26474 / A Score: 0.15 / B Score: 0.20 / A Actor Loss: 0.0218 / A Critic Loss: 0.0688 / B Actor Loss: -0.0500 / B Critic Loss: 0.0556
# 400 Episode / Step: 27079 / A Score: 0.00 / B Score: 0.10 / A Actor Loss: -0.0489 / A Critic Loss: 0.0479 / B Actor Loss: 0.1253 / B Critic Loss: 0.0794
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 410 Episode / Step: 27627 / A Score: -0.40 / B Score: 0.50 / A Actor Loss: 0.0948 / A Critic Loss: 0.0527 / B Actor Loss: -0.0804 / B Critic Loss: 0.0931
# 420 Episode / Step: 28572 / A Score: -0.30 / B Score: 0.50 / A Actor Loss: -0.0060 / A Critic Loss: 0.0356 / B Actor Loss: 0.0126 / B Critic Loss: 0.0363
# 430 Episode / Step: 29118 / A Score: 0.45 / B Score: -0.35 / A Actor Loss: 0.0218 / A Critic Loss: 0.0318 / B Actor Loss: 0.0287 / B Critic Loss: 0.0458
# 440 Episode / Step: 29744 / A Score: 0.25 / B Score: -0.10 / A Actor Loss: -0.0416 / A Critic Loss: 0.0792 / B Actor Loss: 0.0572 / B Critic Loss: 0.0896
# 450 Episode / Step: 31087 / A Score: 0.35 / B Score: 0.25 / A Actor Loss: 0.0058 / A Critic Loss: 0.0785 / B Actor Loss: -0.0347 / B Critic Loss: 0.0752
# 460 Episode / Step: 32110 / A Score: 0.00 / B Score: 0.40 / A Actor Loss: -0.0333 / A Critic Loss: 0.0801 / B Actor Loss: 0.0352 / B Critic Loss: 0.0673
# 470 Episode / Step: 33000 / A Score: -0.25 / B Score: 0.60 / A Actor Loss: 0.0515 / A Critic Loss: 0.0721 / B Actor Loss: -0.0455 / B Critic Loss: 0.0482
# 480 Episode / Step: 33834 / A Score: 0.35 / B Score: -0.15 / A Actor Loss: 0.0099 / A Critic Loss: 0.0486 / B Actor Loss: 0.0353 / B Critic Loss: 0.0519
# 490 Episode / Step: 34495 / A Score: 0.30 / B Score: -0.15 / A Actor Loss: -0.0288 / A Critic Loss: 0.0611 / B Actor Loss: 0.0624 / B Critic Loss: 0.0470
# 500 Episode / Step: 35475 / A Score: 0.30 / B Score: 0.00 / A Actor Loss: 0.0355 / A Critic Loss: 0.0582 / B Actor Loss: 0.0040 / B Critic Loss: 0.0952
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 510 Episode / Step: 36330 / A Score: 0.35 / B Score: -0.10 / A Actor Loss: -0.0890 / A Critic Loss: 0.0679 / B Actor Loss: 0.0816 / B Critic Loss: 0.0587
# 520 Episode / Step: 36849 / A Score: 0.25 / B Score: -0.20 / A Actor Loss: 0.0076 / A Critic Loss: 0.0673 / B Actor Loss: 0.0258 / B Critic Loss: 0.0765
# 530 Episode / Step: 37750 / A Score: 0.10 / B Score: 0.20 / A Actor Loss: -0.0196 / A Critic Loss: 0.0556 / B Actor Loss: 0.0279 / B Critic Loss: 0.0452
# 540 Episode / Step: 38867 / A Score: 0.45 / B Score: 0.05 / A Actor Loss: 0.0121 / A Critic Loss: 0.0763 / B Actor Loss: -0.0218 / B Critic Loss: 0.0979
# 550 Episode / Step: 39577 / A Score: 0.35 / B Score: -0.15 / A Actor Loss: -0.0673 / A Critic Loss: 0.0901 / B Actor Loss: 0.0595 / B Critic Loss: 0.0757
# 560 Episode / Step: 40895 / A Score: 0.20 / B Score: 0.20 / A Actor Loss: -0.0102 / A Critic Loss: 0.0407 / B Actor Loss: 0.0206 / B Critic Loss: 0.0400
# 570 Episode / Step: 41613 / A Score: 0.55 / B Score: -0.35 / A Actor Loss: -0.0485 / A Critic Loss: 0.0584 / B Actor Loss: 0.0640 / B Critic Loss: 0.0527
# 580 Episode / Step: 42341 / A Score: 0.15 / B Score: 0.10 / A Actor Loss: -0.0127 / A Critic Loss: 0.0852 / B Actor Loss: 0.0645 / B Critic Loss: 0.0706
# 590 Episode / Step: 43383 / A Score: 0.50 / B Score: -0.05 / A Actor Loss: 0.0001 / A Critic Loss: 0.0665 / B Actor Loss: 0.0027 / B Critic Loss: 0.0626
# 600 Episode / Step: 44228 / A Score: 0.35 / B Score: -0.05 / A Actor Loss: -0.0314 / A Critic Loss: 0.0814 / B Actor Loss: 0.0119 / B Critic Loss: 0.0728
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 610 Episode / Step: 44814 / A Score: -0.10 / B Score: 0.25 / A Actor Loss: 0.1396 / A Critic Loss: 0.0947 / B Actor Loss: -0.0610 / B Critic Loss: 0.0881
# 620 Episode / Step: 45594 / A Score: 0.50 / B Score: -0.30 / A Actor Loss: -0.0171 / A Critic Loss: 0.0633 / B Actor Loss: 0.0078 / B Critic Loss: 0.0523
# 630 Episode / Step: 46502 / A Score: 0.30 / B Score: -0.10 / A Actor Loss: -0.0259 / A Critic Loss: 0.0351 / B Actor Loss: 0.0045 / B Critic Loss: 0.0339
# 640 Episode / Step: 47178 / A Score: -0.10 / B Score: 0.25 / A Actor Loss: 0.0186 / A Critic Loss: 0.0654 / B Actor Loss: -0.0245 / B Critic Loss: 0.0610
# 650 Episode / Step: 47598 / A Score: -0.20 / B Score: 0.20 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 660 Episode / Step: 48054 / A Score: 0.25 / B Score: -0.20 / A Actor Loss: 0.0738 / A Critic Loss: 0.0227 / B Actor Loss: -0.0252 / B Critic Loss: 0.0173
# 670 Episode / Step: 48533 / A Score: 0.05 / B Score: 0.00 / A Actor Loss: -0.0405 / A Critic Loss: 0.0653 / B Actor Loss: 0.0376 / B Critic Loss: 0.0362
# 680 Episode / Step: 49012 / A Score: -0.15 / B Score: 0.20 / A Actor Loss: -0.0688 / A Critic Loss: 0.0706 / B Actor Loss: 0.0730 / B Critic Loss: 0.0466
# 690 Episode / Step: 49493 / A Score: -0.20 / B Score: 0.25 / A Actor Loss: 0.0994 / A Critic Loss: 0.0298 / B Actor Loss: -0.0664 / B Critic Loss: 0.0410
# 700 Episode / Step: 50919 / A Score: 1.10 / B Score: -0.50 / A Actor Loss: -0.0115 / A Critic Loss: 0.0432 / B Actor Loss: -0.0257 / B Critic Loss: 0.0488
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 710 Episode / Step: 51901 / A Score: 0.25 / B Score: 0.10 / A Actor Loss: -0.0075 / A Critic Loss: 0.0642 / B Actor Loss: 0.0147 / B Critic Loss: 0.0586
# 720 Episode / Step: 52639 / A Score: 0.55 / B Score: -0.35 / A Actor Loss: 0.0304 / A Critic Loss: 0.0612 / B Actor Loss: -0.0419 / B Critic Loss: 0.0349
# 730 Episode / Step: 53486 / A Score: 0.15 / B Score: 0.10 / A Actor Loss: -0.0231 / A Critic Loss: 0.0612 / B Actor Loss: 0.0187 / B Critic Loss: 0.0408
# 740 Episode / Step: 54134 / A Score: 0.10 / B Score: 0.05 / A Actor Loss: 0.0414 / A Critic Loss: 0.0533 / B Actor Loss: -0.0379 / B Critic Loss: 0.0420
# 750 Episode / Step: 54647 / A Score: 0.00 / B Score: 0.05 / A Actor Loss: 0.0741 / A Critic Loss: 0.0474 / B Actor Loss: -0.0611 / B Critic Loss: 0.0473
# 760 Episode / Step: 55392 / A Score: 0.75 / B Score: -0.50 / A Actor Loss: 0.0100 / A Critic Loss: 0.0612 / B Actor Loss: -0.0201 / B Critic Loss: 0.0681
# 770 Episode / Step: 56183 / A Score: 0.60 / B Score: -0.35 / A Actor Loss: -0.0643 / A Critic Loss: 0.0723 / B Actor Loss: 0.0156 / B Critic Loss: 0.0529
# 780 Episode / Step: 56739 / A Score: 0.30 / B Score: -0.20 / A Actor Loss: 0.0122 / A Critic Loss: 0.0919 / B Actor Loss: 0.0240 / B Critic Loss: 0.0409
# 790 Episode / Step: 57246 / A Score: 0.85 / B Score: -0.80 / A Actor Loss: -0.0007 / A Critic Loss: 0.0321 / B Actor Loss: 0.0172 / B Critic Loss: 0.0171
# 800 Episode / Step: 57769 / A Score: 0.65 / B Score: -0.60 / A Actor Loss: -0.0522 / A Critic Loss: 0.0160 / B Actor Loss: 0.0518 / B Critic Loss: 0.0104
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 810 Episode / Step: 58453 / A Score: 0.55 / B Score: -0.40 / A Actor Loss: -0.0504 / A Critic Loss: 0.0357 / B Actor Loss: 0.0338 / B Critic Loss: 0.0223
# 820 Episode / Step: 59298 / A Score: 0.40 / B Score: -0.10 / A Actor Loss: 0.0750 / A Critic Loss: 0.0517 / B Actor Loss: -0.1024 / B Critic Loss: 0.0402
# 830 Episode / Step: 60363 / A Score: 0.70 / B Score: -0.25 / A Actor Loss: 0.0269 / A Critic Loss: 0.0893 / B Actor Loss: -0.0782 / B Critic Loss: 0.0693
# 840 Episode / Step: 60921 / A Score: 0.30 / B Score: -0.20 / A Actor Loss: -0.0160 / A Critic Loss: 0.0807 / B Actor Loss: -0.0319 / B Critic Loss: 0.0664
# 850 Episode / Step: 61640 / A Score: 1.20 / B Score: -0.95 / A Actor Loss: -0.0288 / A Critic Loss: 0.0509 / B Actor Loss: 0.0280 / B Critic Loss: 0.0434
# 860 Episode / Step: 62792 / A Score: 0.90 / B Score: -0.50 / A Actor Loss: -0.0229 / A Critic Loss: 0.0154 / B Actor Loss: -0.0085 / B Critic Loss: 0.0196
# 870 Episode / Step: 63543 / A Score: 0.45 / B Score: -0.20 / A Actor Loss: 0.0505 / A Critic Loss: 0.0978 / B Actor Loss: -0.0505 / B Critic Loss: 0.0516
# 880 Episode / Step: 64313 / A Score: 0.20 / B Score: 0.05 / A Actor Loss: 0.0833 / A Critic Loss: 0.1120 / B Actor Loss: -0.1062 / B Critic Loss: 0.0594
# 890 Episode / Step: 65370 / A Score: 0.60 / B Score: -0.20 / A Actor Loss: 0.0063 / A Critic Loss: 0.0648 / B Actor Loss: -0.0614 / B Critic Loss: 0.0679
# 900 Episode / Step: 65959 / A Score: 0.70 / B Score: -0.60 / A Actor Loss: -0.0862 / A Critic Loss: 0.0498 / B Actor Loss: 0.0857 / B Critic Loss: 0.0390
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 910 Episode / Step: 66691 / A Score: 0.10 / B Score: 0.15 / A Actor Loss: 0.0302 / A Critic Loss: 0.0634 / B Actor Loss: -0.0155 / B Critic Loss: 0.0583
# 920 Episode / Step: 67801 / A Score: 0.55 / B Score: -0.05 / A Actor Loss: -0.0031 / A Critic Loss: 0.0965 / B Actor Loss: -0.0270 / B Critic Loss: 0.0796
# 930 Episode / Step: 68908 / A Score: 0.90 / B Score: -0.45 / A Actor Loss: -0.0440 / A Critic Loss: 0.0649 / B Actor Loss: 0.0230 / B Critic Loss: 0.0576
# 940 Episode / Step: 69640 / A Score: 0.30 / B Score: -0.15 / A Actor Loss: -0.0133 / A Critic Loss: 0.0519 / B Actor Loss: 0.0656 / B Critic Loss: 0.0404
# 950 Episode / Step: 70405 / A Score: 0.80 / B Score: -0.55 / A Actor Loss: -0.0801 / A Critic Loss: 0.0292 / B Actor Loss: 0.0612 / B Critic Loss: 0.0370
# 960 Episode / Step: 71429 / A Score: 0.60 / B Score: -0.25 / A Actor Loss: 0.0075 / A Critic Loss: 0.0683 / B Actor Loss: -0.0108 / B Critic Loss: 0.0466
# 970 Episode / Step: 72141 / A Score: 0.15 / B Score: 0.10 / A Actor Loss: 0.0265 / A Critic Loss: 0.0823 / B Actor Loss: -0.0331 / B Critic Loss: 0.0729
# 980 Episode / Step: 73671 / A Score: 0.80 / B Score: -0.10 / A Actor Loss: 0.0070 / A Critic Loss: 0.0764 / B Actor Loss: -0.0364 / B Critic Loss: 0.0717
# 990 Episode / Step: 74950 / A Score: 0.70 / B Score: -0.15 / A Actor Loss: -0.0221 / A Critic Loss: 0.0449 / B Actor Loss: -0.0018 / B Critic Loss: 0.0588
# 1000 Episode / Step: 76791 / A Score: 0.40 / B Score: 0.25 / A Actor Loss: -0.0107 / A Critic Loss: 0.0392 / B Actor Loss: 0.0258 / B Critic Loss: 0.0374
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1010 Episode / Step: 77469 / A Score: 0.45 / B Score: -0.35 / A Actor Loss: 0.0291 / A Critic Loss: 0.0510 / B Actor Loss: -0.0180 / B Critic Loss: 0.0392
# 1020 Episode / Step: 77952 / A Score: -0.15 / B Score: 0.20 / A Actor Loss: -0.0187 / A Critic Loss: 0.0505 / B Actor Loss: 0.1187 / B Critic Loss: 0.0284
# 1030 Episode / Step: 78395 / A Score: -0.15 / B Score: 0.20 / A Actor Loss: 0.0656 / A Critic Loss: 0.0575 / B Actor Loss: 0.0319 / B Critic Loss: 0.0347
# 1040 Episode / Step: 79377 / A Score: 0.35 / B Score: 0.05 / A Actor Loss: 0.0181 / A Critic Loss: 0.1052 / B Actor Loss: -0.0528 / B Critic Loss: 0.1260
# 1050 Episode / Step: 81048 / A Score: 0.65 / B Score: 0.15 / A Actor Loss: -0.0433 / A Critic Loss: 0.0689 / B Actor Loss: 0.0189 / B Critic Loss: 0.0716
# 1060 Episode / Step: 82287 / A Score: 0.45 / B Score: -0.05 / A Actor Loss: 0.0018 / A Critic Loss: 0.0361 / B Actor Loss: -0.0046 / B Critic Loss: 0.0402
# 1070 Episode / Step: 82837 / A Score: 0.10 / B Score: 0.00 / A Actor Loss: 0.0513 / A Critic Loss: 0.0869 / B Actor Loss: 0.0065 / B Critic Loss: 0.0717
# 1080 Episode / Step: 83983 / A Score: 0.95 / B Score: -0.45 / A Actor Loss: -0.0248 / A Critic Loss: 0.0779 / B Actor Loss: 0.0151 / B Critic Loss: 0.0602
# 1090 Episode / Step: 85165 / A Score: 0.95 / B Score: -0.40 / A Actor Loss: -0.0059 / A Critic Loss: 0.0634 / B Actor Loss: -0.0281 / B Critic Loss: 0.0692
# 1100 Episode / Step: 86075 / A Score: 0.05 / B Score: 0.10 / A Actor Loss: 0.0607 / A Critic Loss: 0.0484 / B Actor Loss: -0.0320 / B Critic Loss: 0.0418
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1110 Episode / Step: 86922 / A Score: 0.10 / B Score: 0.05 / A Actor Loss: 0.1006 / A Critic Loss: 0.0481 / B Actor Loss: -0.0069 / B Critic Loss: 0.0156
# 1120 Episode / Step: 87431 / A Score: 0.30 / B Score: -0.20 / A Actor Loss: -0.0497 / A Critic Loss: 0.0673 / B Actor Loss: 0.0497 / B Critic Loss: 0.0497
# 1130 Episode / Step: 88120 / A Score: 0.50 / B Score: -0.35 / A Actor Loss: -0.0070 / A Critic Loss: 0.0617 / B Actor Loss: 0.0188 / B Critic Loss: 0.0450
# 1140 Episode / Step: 88912 / A Score: 0.75 / B Score: -0.50 / A Actor Loss: 0.0013 / A Critic Loss: 0.0429 / B Actor Loss: 0.0013 / B Critic Loss: 0.0488
# 1150 Episode / Step: 89681 / A Score: 0.55 / B Score: -0.40 / A Actor Loss: -0.0140 / A Critic Loss: 0.0571 / B Actor Loss: 0.0044 / B Critic Loss: 0.0448
# 1160 Episode / Step: 90327 / A Score: 0.70 / B Score: -0.60 / A Actor Loss: -0.0617 / A Critic Loss: 0.0326 / B Actor Loss: 0.0716 / B Critic Loss: 0.0206
# 1170 Episode / Step: 91366 / A Score: 0.40 / B Score: -0.15 / A Actor Loss: 0.0286 / A Critic Loss: 0.0694 / B Actor Loss: -0.0273 / B Critic Loss: 0.0426
# 1180 Episode / Step: 92868 / A Score: 0.75 / B Score: -0.05 / A Actor Loss: -0.0431 / A Critic Loss: 0.0432 / B Actor Loss: 0.0072 / B Critic Loss: 0.0483
# 1190 Episode / Step: 93600 / A Score: 0.10 / B Score: 0.10 / A Actor Loss: 0.1686 / A Critic Loss: 0.0922 / B Actor Loss: -0.1870 / B Critic Loss: 0.0942
# 1200 Episode / Step: 94352 / A Score: 0.35 / B Score: -0.10 / A Actor Loss: 0.0159 / A Critic Loss: 0.0695 / B Actor Loss: 0.0028 / B Critic Loss: 0.0692
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1210 Episode / Step: 94849 / A Score: 0.05 / B Score: 0.05 / A Actor Loss: 0.0405 / A Critic Loss: 0.1040 / B Actor Loss: -0.0049 / B Critic Loss: 0.0863
# 1220 Episode / Step: 96349 / A Score: 0.30 / B Score: 0.25 / A Actor Loss: -0.0171 / A Critic Loss: 0.0668 / B Actor Loss: -0.0002 / B Critic Loss: 0.0695
# 1230 Episode / Step: 97321 / A Score: 0.80 / B Score: -0.35 / A Actor Loss: -0.0325 / A Critic Loss: 0.0788 / B Actor Loss: 0.0141 / B Critic Loss: 0.0910
# 1240 Episode / Step: 97804 / A Score: 0.20 / B Score: -0.15 / A Actor Loss: -0.0237 / A Critic Loss: 0.0481 / B Actor Loss: 0.0837 / B Critic Loss: 0.0693
# 1250 Episode / Step: 98442 / A Score: 0.10 / B Score: 0.05 / A Actor Loss: -0.0284 / A Critic Loss: 0.0768 / B Actor Loss: 0.0376 / B Critic Loss: 0.0791
# 1260 Episode / Step: 99177 / A Score: -0.30 / B Score: 0.55 / A Actor Loss: 0.1280 / A Critic Loss: 0.0749 / B Actor Loss: -0.1406 / B Critic Loss: 0.0837
# 1270 Episode / Step: 99748 / A Score: -0.20 / B Score: 0.30 / A Actor Loss: 0.0806 / A Critic Loss: 0.0668 / B Actor Loss: -0.0526 / B Critic Loss: 0.0702
# 1280 Episode / Step: 100281 / A Score: -0.20 / B Score: 0.30 / A Actor Loss: 0.0054 / A Critic Loss: 0.0268 / B Actor Loss: 0.0438 / B Critic Loss: 0.0528
# 1290 Episode / Step: 101158 / A Score: 0.00 / B Score: 0.25 / A Actor Loss: -0.0270 / A Critic Loss: 0.0783 / B Actor Loss: 0.0109 / B Critic Loss: 0.0745
# 1300 Episode / Step: 101995 / A Score: 0.65 / B Score: -0.35 / A Actor Loss: -0.0554 / A Critic Loss: 0.0931 / B Actor Loss: 0.0466 / B Critic Loss: 0.0588
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1310 Episode / Step: 103014 / A Score: 0.50 / B Score: 0.00 / A Actor Loss: -0.0328 / A Critic Loss: 0.1075 / B Actor Loss: -0.0186 / B Critic Loss: 0.0982
# 1320 Episode / Step: 104986 / A Score: 0.25 / B Score: 0.55 / A Actor Loss: 0.0004 / A Critic Loss: 0.0511 / B Actor Loss: -0.0244 / B Critic Loss: 0.0471
# 1330 Episode / Step: 106081 / A Score: 0.60 / B Score: -0.20 / A Actor Loss: 0.0020 / A Critic Loss: 0.0506 / B Actor Loss: 0.0062 / B Critic Loss: 0.0667
# 1340 Episode / Step: 106979 / A Score: 0.45 / B Score: -0.05 / A Actor Loss: -0.0238 / A Critic Loss: 0.0848 / B Actor Loss: 0.0103 / B Critic Loss: 0.0691
# 1350 Episode / Step: 108305 / A Score: 0.50 / B Score: 0.10 / A Actor Loss: -0.0233 / A Critic Loss: 0.0496 / B Actor Loss: 0.0214 / B Critic Loss: 0.0504
# 1360 Episode / Step: 108843 / A Score: 0.05 / B Score: 0.05 / A Actor Loss: 0.1605 / A Critic Loss: 0.0607 / B Actor Loss: -0.0950 / B Critic Loss: 0.0663
# 1370 Episode / Step: 109567 / A Score: 0.70 / B Score: -0.50 / A Actor Loss: -0.0358 / A Critic Loss: 0.0544 / B Actor Loss: 0.0476 / B Critic Loss: 0.0613
# 1380 Episode / Step: 110702 / A Score: 0.25 / B Score: 0.25 / A Actor Loss: 0.0000 / A Critic Loss: 0.0988 / B Actor Loss: -0.0464 / B Critic Loss: 0.0960
# 1390 Episode / Step: 111518 / A Score: 0.50 / B Score: -0.25 / A Actor Loss: 0.0273 / A Critic Loss: 0.0573 / B Actor Loss: -0.0039 / B Critic Loss: 0.0696
# 1400 Episode / Step: 113773 / A Score: 0.45 / B Score: 0.50 / A Actor Loss: -0.0077 / A Critic Loss: 0.0519 / B Actor Loss: -0.0116 / B Critic Loss: 0.0511
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1410 Episode / Step: 114974 / A Score: 0.25 / B Score: 0.30 / A Actor Loss: -0.0264 / A Critic Loss: 0.0518 / B Actor Loss: -0.0008 / B Critic Loss: 0.0534
# 1420 Episode / Step: 115703 / A Score: -0.10 / B Score: 0.30 / A Actor Loss: 0.0858 / A Critic Loss: 0.0541 / B Actor Loss: 0.0257 / B Critic Loss: 0.0545
# 1430 Episode / Step: 116801 / A Score: 0.65 / B Score: -0.20 / A Actor Loss: -0.0253 / A Critic Loss: 0.0765 / B Actor Loss: 0.0159 / B Critic Loss: 0.0777
# 1440 Episode / Step: 117716 / A Score: 1.05 / B Score: -0.70 / A Actor Loss: -0.0888 / A Critic Loss: 0.0646 / B Actor Loss: 0.0966 / B Critic Loss: 0.0682
# 1450 Episode / Step: 118907 / A Score: 1.10 / B Score: -0.70 / A Actor Loss: -0.0281 / A Critic Loss: 0.0374 / B Actor Loss: 0.0139 / B Critic Loss: 0.0390
# 1460 Episode / Step: 119887 / A Score: 0.15 / B Score: 0.25 / A Actor Loss: 0.0634 / A Critic Loss: 0.0683 / B Actor Loss: -0.0796 / B Critic Loss: 0.0717
# 1470 Episode / Step: 120879 / A Score: 0.35 / B Score: -0.05 / A Actor Loss: 0.0170 / A Critic Loss: 0.0650 / B Actor Loss: -0.0001 / B Critic Loss: 0.0679
# 1480 Episode / Step: 121440 / A Score: 0.30 / B Score: -0.15 / A Actor Loss: -0.0703 / A Critic Loss: 0.0564 / B Actor Loss: 0.1062 / B Critic Loss: 0.0614
# 1490 Episode / Step: 122744 / A Score: 0.55 / B Score: 0.00 / A Actor Loss: 0.0084 / A Critic Loss: 0.0829 / B Actor Loss: -0.0357 / B Critic Loss: 0.0774
# 1500 Episode / Step: 124568 / A Score: 0.50 / B Score: 0.50 / A Actor Loss: -0.0013 / A Critic Loss: 0.0580 / B Actor Loss: -0.0254 / B Critic Loss: 0.0569
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1510 Episode / Step: 125342 / A Score: 0.60 / B Score: -0.30 / A Actor Loss: 0.0195 / A Critic Loss: 0.0759 / B Actor Loss: -0.0024 / B Critic Loss: 0.1054
# 1520 Episode / Step: 126477 / A Score: 0.65 / B Score: -0.10 / A Actor Loss: -0.0427 / A Critic Loss: 0.0631 / B Actor Loss: 0.0410 / B Critic Loss: 0.0732
# 1530 Episode / Step: 128720 / A Score: 1.10 / B Score: -0.30 / A Actor Loss: -0.0087 / A Critic Loss: 0.0244 / B Actor Loss: 0.0015 / B Critic Loss: 0.0286
# 1540 Episode / Step: 130010 / A Score: 0.30 / B Score: 0.35 / A Actor Loss: -0.0121 / A Critic Loss: 0.0558 / B Actor Loss: 0.0049 / B Critic Loss: 0.0567
# 1550 Episode / Step: 131054 / A Score: 0.40 / B Score: -0.05 / A Actor Loss: 0.0588 / A Critic Loss: 0.0568 / B Actor Loss: -0.0584 / B Critic Loss: 0.0425
# 1560 Episode / Step: 131771 / A Score: 0.70 / B Score: -0.55 / A Actor Loss: 0.0003 / A Critic Loss: 0.0592 / B Actor Loss: 0.0417 / B Critic Loss: 0.0621
# 1570 Episode / Step: 132963 / A Score: 0.95 / B Score: -0.50 / A Actor Loss: -0.0454 / A Critic Loss: 0.0544 / B Actor Loss: 0.0261 / B Critic Loss: 0.0504
# 1580 Episode / Step: 133716 / A Score: 0.50 / B Score: -0.35 / A Actor Loss: -0.0023 / A Critic Loss: 0.0471 / B Actor Loss: 0.0075 / B Critic Loss: 0.0373
# 1590 Episode / Step: 134548 / A Score: 0.50 / B Score: -0.25 / A Actor Loss: 0.1145 / A Critic Loss: 0.0659 / B Actor Loss: -0.1210 / B Critic Loss: 0.0859
# 1600 Episode / Step: 135205 / A Score: 0.05 / B Score: 0.10 / A Actor Loss: 0.0194 / A Critic Loss: 0.0490 / B Actor Loss: -0.0038 / B Critic Loss: 0.0456
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1610 Episode / Step: 135972 / A Score: -0.45 / B Score: 0.70 / A Actor Loss: 0.0241 / A Critic Loss: 0.0721 / B Actor Loss: -0.0233 / B Critic Loss: 0.0513
# 1620 Episode / Step: 136585 / A Score: -0.10 / B Score: 0.25 / A Actor Loss: 0.0322 / A Critic Loss: 0.0753 / B Actor Loss: -0.0186 / B Critic Loss: 0.0542
# 1630 Episode / Step: 137608 / A Score: 0.75 / B Score: -0.35 / A Actor Loss: 0.0549 / A Critic Loss: 0.0599 / B Actor Loss: -0.0617 / B Critic Loss: 0.0705
# 1640 Episode / Step: 138166 / A Score: 0.65 / B Score: -0.55 / A Actor Loss: -0.1538 / A Critic Loss: 0.0634 / B Actor Loss: 0.1742 / B Critic Loss: 0.0890
# 1650 Episode / Step: 138906 / A Score: 0.10 / B Score: 0.10 / A Actor Loss: 0.0021 / A Critic Loss: 0.0463 / B Actor Loss: 0.0038 / B Critic Loss: 0.0555
# 1660 Episode / Step: 139965 / A Score: 0.45 / B Score: -0.05 / A Actor Loss: -0.0080 / A Critic Loss: 0.0695 / B Actor Loss: 0.0020 / B Critic Loss: 0.0713
# 1670 Episode / Step: 140790 / A Score: 0.60 / B Score: -0.30 / A Actor Loss: -0.0041 / A Critic Loss: 0.1163 / B Actor Loss: -0.0394 / B Critic Loss: 0.1017
# 1680 Episode / Step: 142273 / A Score: 0.40 / B Score: 0.35 / A Actor Loss: -0.0159 / A Critic Loss: 0.0671 / B Actor Loss: -0.0032 / B Critic Loss: 0.0658
# 1690 Episode / Step: 142900 / A Score: 0.70 / B Score: -0.60 / A Actor Loss: -0.1051 / A Critic Loss: 0.0521 / B Actor Loss: 0.1081 / B Critic Loss: 0.0408
# 1700 Episode / Step: 144306 / A Score: 0.40 / B Score: 0.25 / A Actor Loss: 0.0202 / A Critic Loss: 0.0607 / B Actor Loss: -0.0400 / B Critic Loss: 0.0594
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1710 Episode / Step: 145148 / A Score: 0.55 / B Score: -0.30 / A Actor Loss: 0.0330 / A Critic Loss: 0.0598 / B Actor Loss: -0.0092 / B Critic Loss: 0.0546
# 1720 Episode / Step: 145944 / A Score: 0.05 / B Score: 0.05 / A Actor Loss: -0.0004 / A Critic Loss: 0.0353 / B Actor Loss: 0.0259 / B Critic Loss: 0.0398
# 1730 Episode / Step: 148339 / A Score: 0.75 / B Score: 0.25 / A Actor Loss: -0.0262 / A Critic Loss: 0.0533 / B Actor Loss: -0.0108 / B Critic Loss: 0.0721
# 1740 Episode / Step: 150398 / A Score: 0.25 / B Score: 0.30 / A Actor Loss: 0.0302 / A Critic Loss: 0.0367 / B Actor Loss: -0.0402 / B Critic Loss: 0.0273
# 1750 Episode / Step: 151797 / A Score: 0.35 / B Score: 0.35 / A Actor Loss: -0.0302 / A Critic Loss: 0.0673 / B Actor Loss: 0.0274 / B Critic Loss: 0.0756
# 1760 Episode / Step: 154669 / A Score: 1.10 / B Score: 0.15 / A Actor Loss: -0.0181 / A Critic Loss: 0.0429 / B Actor Loss: 0.0009 / B Critic Loss: 0.0414
# 1770 Episode / Step: 156743 / A Score: 0.85 / B Score: 0.30 / A Actor Loss: -0.0147 / A Critic Loss: 0.0447 / B Actor Loss: -0.0111 / B Critic Loss: 0.0506
# 1780 Episode / Step: 157893 / A Score: 0.65 / B Score: -0.20 / A Actor Loss: -0.0025 / A Critic Loss: 0.0412 / B Actor Loss: 0.0203 / B Critic Loss: 0.0540
# 1790 Episode / Step: 159452 / A Score: 1.25 / B Score: -0.45 / A Actor Loss: -0.0423 / A Critic Loss: 0.0298 / B Actor Loss: 0.0542 / B Critic Loss: 0.0504
# 1800 Episode / Step: 161077 / A Score: 0.95 / B Score: -0.05 / A Actor Loss: -0.0103 / A Critic Loss: 0.0465 / B Actor Loss: 0.0081 / B Critic Loss: 0.0522
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1810 Episode / Step: 162590 / A Score: 0.10 / B Score: 0.55 / A Actor Loss: 0.0413 / A Critic Loss: 0.0619 / B Actor Loss: -0.0302 / B Critic Loss: 0.0614
# 1820 Episode / Step: 163980 / A Score: 0.90 / B Score: -0.05 / A Actor Loss: -0.0047 / A Critic Loss: 0.0678 / B Actor Loss: -0.0023 / B Critic Loss: 0.0715
# 1830 Episode / Step: 164809 / A Score: 0.20 / B Score: 0.10 / A Actor Loss: 0.0244 / A Critic Loss: 0.0736 / B Actor Loss: 0.0582 / B Critic Loss: 0.0774
# 1840 Episode / Step: 165466 / A Score: 0.55 / B Score: -0.35 / A Actor Loss: -0.0119 / A Critic Loss: 0.0747 / B Actor Loss: 0.0276 / B Critic Loss: 0.0713
# 1850 Episode / Step: 167501 / A Score: 1.00 / B Score: 0.10 / A Actor Loss: -0.0212 / A Critic Loss: 0.0492 / B Actor Loss: -0.0007 / B Critic Loss: 0.0608
# 1860 Episode / Step: 168723 / A Score: -0.40 / B Score: 0.90 / A Actor Loss: 0.0764 / A Critic Loss: 0.0616 / B Actor Loss: -0.0937 / B Critic Loss: 0.0554
# 1870 Episode / Step: 170206 / A Score: 1.10 / B Score: -0.45 / A Actor Loss: -0.0144 / A Critic Loss: 0.0584 / B Actor Loss: 0.0094 / B Critic Loss: 0.0688
# 1880 Episode / Step: 172374 / A Score: 0.85 / B Score: 0.00 / A Actor Loss: -0.0368 / A Critic Loss: 0.0371 / B Actor Loss: 0.0279 / B Critic Loss: 0.0524
# 1890 Episode / Step: 174734 / A Score: 0.95 / B Score: 0.10 / A Actor Loss: -0.0105 / A Critic Loss: 0.0304 / B Actor Loss: 0.0004 / B Critic Loss: 0.0373
# 1900 Episode / Step: 176740 / A Score: 0.45 / B Score: 0.40 / A Actor Loss: 0.0152 / A Critic Loss: 0.0510 / B Actor Loss: -0.0216 / B Critic Loss: 0.0508
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 1910 Episode / Step: 179343 / A Score: 1.05 / B Score: 0.20 / A Actor Loss: -0.0332 / A Critic Loss: 0.0353 / B Actor Loss: 0.0070 / B Critic Loss: 0.0435
# 1920 Episode / Step: 180812 / A Score: 0.75 / B Score: -0.10 / A Actor Loss: 0.0249 / A Critic Loss: 0.0404 / B Actor Loss: -0.0108 / B Critic Loss: 0.0546
# 1930 Episode / Step: 183094 / A Score: 0.75 / B Score: 0.35 / A Actor Loss: 0.0031 / A Critic Loss: 0.0362 / B Actor Loss: -0.0169 / B Critic Loss: 0.0442
# 1940 Episode / Step: 185602 / A Score: 1.70 / B Score: -0.55 / A Actor Loss: -0.0244 / A Critic Loss: 0.0300 / B Actor Loss: 0.0244 / B Critic Loss: 0.0472
# 1950 Episode / Step: 187243 / A Score: 0.65 / B Score: 0.15 / A Actor Loss: 0.0214 / A Critic Loss: 0.0453 / B Actor Loss: -0.0178 / B Critic Loss: 0.0433
# 1960 Episode / Step: 190140 / A Score: 1.70 / B Score: -0.20 / A Actor Loss: -0.0291 / A Critic Loss: 0.0220 / B Actor Loss: 0.0170 / B Critic Loss: 0.0341
# 1970 Episode / Step: 194370 / A Score: 1.45 / B Score: 0.50 / A Actor Loss: 0.0150 / A Critic Loss: 0.0179 / B Actor Loss: -0.0162 / B Critic Loss: 0.0316
# 1980 Episode / Step: 196877 / A Score: 0.70 / B Score: 0.70 / A Actor Loss: 0.0354 / A Critic Loss: 0.0471 / B Actor Loss: -0.0370 / B Critic Loss: 0.0377
# 1990 Episode / Step: 198673 / A Score: 0.30 / B Score: 0.45 / A Actor Loss: -0.0097 / A Critic Loss: 0.0422 / B Actor Loss: 0.0202 / B Critic Loss: 0.0508
# 2000 Episode / Step: 199771 / A Score: 0.30 / B Score: 0.15 / A Actor Loss: 0.0228 / A Critic Loss: 0.0635 / B Actor Loss: 0.0037 / B Critic Loss: 0.0520
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 2010 Episode / Step: 201157 / A Score: 1.30 / B Score: -0.65 / A Actor Loss: -0.0891 / A Critic Loss: 0.0537 / B Actor Loss: 0.0907 / B Critic Loss: 0.0491
# 2020 Episode / Step: 202407 / A Score: 0.55 / B Score: 0.00 / A Actor Loss: -0.0175 / A Critic Loss: 0.0407 / B Actor Loss: 0.0221 / B Critic Loss: 0.0465
# 2030 Episode / Step: 203219 / A Score: 1.00 / B Score: -0.70 / A Actor Loss: 0.0101 / A Critic Loss: 0.0704 / B Actor Loss: 0.0370 / B Critic Loss: 0.0574
# 2040 Episode / Step: 204713 / A Score: 0.95 / B Score: -0.30 / A Actor Loss: 0.0113 / A Critic Loss: 0.0509 / B Actor Loss: -0.0188 / B Critic Loss: 0.0525
# 2050 Episode / Step: 206104 / A Score: 1.10 / B Score: -0.35 / A Actor Loss: -0.0299 / A Critic Loss: 0.0388 / B Actor Loss: 0.0008 / B Critic Loss: 0.0711
# 2060 Episode / Step: 208118 / A Score: 1.30 / B Score: -0.50 / A Actor Loss: -0.0026 / A Critic Loss: 0.0347 / B Actor Loss: -0.0049 / B Critic Loss: 0.0399
# 2070 Episode / Step: 208954 / A Score: 0.85 / B Score: -0.55 / A Actor Loss: -0.0324 / A Critic Loss: 0.0436 / B Actor Loss: 0.0481 / B Critic Loss: 0.0445
# 2080 Episode / Step: 209997 / A Score: 1.10 / B Score: -0.65 / A Actor Loss: -0.0293 / A Critic Loss: 0.0327 / B Actor Loss: 0.0254 / B Critic Loss: 0.0462
# 2090 Episode / Step: 211438 / A Score: 0.55 / B Score: 0.10 / A Actor Loss: 0.0330 / A Critic Loss: 0.0488 / B Actor Loss: -0.0326 / B Critic Loss: 0.0507
# 2100 Episode / Step: 212199 / A Score: 0.55 / B Score: -0.30 / A Actor Loss: 0.0251 / A Critic Loss: 0.0575 / B Actor Loss: -0.0042 / B Critic Loss: 0.0521
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 2110 Episode / Step: 212976 / A Score: 0.75 / B Score: -0.50 / A Actor Loss: -0.0337 / A Critic Loss: 0.0607 / B Actor Loss: 0.0117 / B Critic Loss: 0.0652
# 2120 Episode / Step: 213670 / A Score: 0.35 / B Score: -0.15 / A Actor Loss: 0.0519 / A Critic Loss: 0.0676 / B Actor Loss: -0.0293 / B Critic Loss: 0.0593
# 2130 Episode / Step: 215061 / A Score: 1.30 / B Score: -0.55 / A Actor Loss: -0.0861 / A Critic Loss: 0.0512 / B Actor Loss: 0.0401 / B Critic Loss: 0.0431
# 2140 Episode / Step: 216720 / A Score: 0.40 / B Score: 0.40 / A Actor Loss: 0.0296 / A Critic Loss: 0.0437 / B Actor Loss: -0.0571 / B Critic Loss: 0.0452
# 2150 Episode / Step: 217669 / A Score: 1.10 / B Score: -0.70 / A Actor Loss: 0.0083 / A Critic Loss: 0.0688 / B Actor Loss: 0.0138 / B Critic Loss: 0.0548
# 2160 Episode / Step: 218920 / A Score: 1.00 / B Score: -0.50 / A Actor Loss: -0.0273 / A Critic Loss: 0.0611 / B Actor Loss: 0.0349 / B Critic Loss: 0.0627
# 2170 Episode / Step: 221508 / A Score: 1.70 / B Score: -0.60 / A Actor Loss: -0.0222 / A Critic Loss: 0.0208 / B Actor Loss: 0.0084 / B Critic Loss: 0.0367
# 2180 Episode / Step: 222568 / A Score: 0.70 / B Score: -0.20 / A Actor Loss: -0.0214 / A Critic Loss: 0.0122 / B Actor Loss: 0.0223 / B Critic Loss: 0.0371
# 2190 Episode / Step: 224704 / A Score: 0.55 / B Score: 0.55 / A Actor Loss: 0.0485 / A Critic Loss: 0.0628 / B Actor Loss: -0.0531 / B Critic Loss: 0.0598
# 2200 Episode / Step: 229338 / A Score: 0.50 / B Score: 1.50 / A Actor Loss: 0.0050 / A Critic Loss: 0.0287 / B Actor Loss: -0.0184 / B Critic Loss: 0.0233
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 2210 Episode / Step: 230367 / A Score: -0.60 / B Score: 1.05 / A Actor Loss: 0.1306 / A Critic Loss: 0.0680 / B Actor Loss: -0.0631 / B Critic Loss: 0.0318
# 2220 Episode / Step: 231355 / A Score: -0.15 / B Score: 0.40 / A Actor Loss: 0.0049 / A Critic Loss: 0.0717 / B Actor Loss: 0.0286 / B Critic Loss: 0.0770
# 2230 Episode / Step: 232881 / A Score: 0.10 / B Score: 0.60 / A Actor Loss: -0.0051 / A Critic Loss: 0.0570 / B Actor Loss: 0.0095 / B Critic Loss: 0.0548
# 2240 Episode / Step: 234739 / A Score: 0.40 / B Score: 0.35 / A Actor Loss: -0.0440 / A Critic Loss: 0.0451 / B Actor Loss: 0.0127 / B Critic Loss: 0.0486
# 2250 Episode / Step: 236916 / A Score: 0.85 / B Score: 0.35 / A Actor Loss: 0.0134 / A Critic Loss: 0.0537 / B Actor Loss: -0.0327 / B Critic Loss: 0.0465
# 2260 Episode / Step: 237989 / A Score: 0.70 / B Score: -0.25 / A Actor Loss: -0.0717 / A Critic Loss: 0.0584 / B Actor Loss: 0.1054 / B Critic Loss: 0.0556
# 2270 Episode / Step: 238969 / A Score: 0.45 / B Score: -0.05 / A Actor Loss: -0.0301 / A Critic Loss: 0.0604 / B Actor Loss: 0.0655 / B Critic Loss: 0.0638
# 2280 Episode / Step: 240260 / A Score: 1.15 / B Score: -0.60 / A Actor Loss: -0.0482 / A Critic Loss: 0.0492 / B Actor Loss: 0.0316 / B Critic Loss: 0.0725
# 2290 Episode / Step: 242165 / A Score: 1.40 / B Score: -0.50 / A Actor Loss: -0.0190 / A Critic Loss: 0.0177 / B Actor Loss: -0.0028 / B Critic Loss: 0.0342
# 2300 Episode / Step: 242842 / A Score: 1.15 / B Score: -0.95 / A Actor Loss: -0.0269 / A Critic Loss: 0.0281 / B Actor Loss: 0.0640 / B Critic Loss: 0.0381
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 2310 Episode / Step: 244281 / A Score: 0.50 / B Score: 0.00 / A Actor Loss: 0.0400 / A Critic Loss: 0.0454 / B Actor Loss: -0.0346 / B Critic Loss: 0.0458
# 2320 Episode / Step: 245845 / A Score: 0.75 / B Score: -0.05 / A Actor Loss: 0.0039 / A Critic Loss: 0.0468 / B Actor Loss: -0.0280 / B Critic Loss: 0.0627
# 2330 Episode / Step: 246491 / A Score: 0.75 / B Score: -0.55 / A Actor Loss: -0.0661 / A Critic Loss: 0.0538 / B Actor Loss: 0.1004 / B Critic Loss: 0.0757
# 2340 Episode / Step: 248318 / A Score: 0.30 / B Score: 0.75 / A Actor Loss: 0.0310 / A Critic Loss: 0.0710 / B Actor Loss: -0.0378 / B Critic Loss: 0.0771
# 2350 Episode / Step: 250719 / A Score: 1.05 / B Score: 0.10 / A Actor Loss: -0.0023 / A Critic Loss: 0.0372 / B Actor Loss: -0.0177 / B Critic Loss: 0.0458
# 2360 Episode / Step: 253018 / A Score: 1.00 / B Score: 0.05 / A Actor Loss: -0.0055 / A Critic Loss: 0.0351 / B Actor Loss: 0.0148 / B Critic Loss: 0.0461
# 2370 Episode / Step: 255903 / A Score: 0.80 / B Score: 0.40 / A Actor Loss: -0.0025 / A Critic Loss: 0.0255 / B Actor Loss: -0.0072 / B Critic Loss: 0.0327
# 2380 Episode / Step: 258742 / A Score: 1.00 / B Score: 0.55 / A Actor Loss: -0.0097 / A Critic Loss: 0.0437 / B Actor Loss: -0.0115 / B Critic Loss: 0.0494
# 2390 Episode / Step: 261260 / A Score: 0.80 / B Score: 0.65 / A Actor Loss: -0.0103 / A Critic Loss: 0.0381 / B Actor Loss: -0.0045 / B Critic Loss: 0.0423
# 2400 Episode / Step: 262780 / A Score: 0.30 / B Score: 0.40 / A Actor Loss: 0.0472 / A Critic Loss: 0.0630 / B Actor Loss: -0.0303 / B Critic Loss: 0.0502
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 2410 Episode / Step: 264778 / A Score: 1.50 / B Score: -0.45 / A Actor Loss: -0.0605 / A Critic Loss: 0.0435 / B Actor Loss: 0.0509 / B Critic Loss: 0.0494
# ...
# 3100 Episode / Step: 540759 / A Score: 0.55 / B Score: 0.55 / A Actor Loss: 0.0154 / A Critic Loss: 0.0452 / B Actor Loss: -0.0188 / B Critic Loss: 0.0426
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3110 Episode / Step: 543695 / A Score: 1.45 / B Score: 0.20 / A Actor Loss: -0.0227 / A Critic Loss: 0.0290 / B Actor Loss: 0.0199 / B Critic Loss: 0.0452
# 3120 Episode / Step: 547036 / A Score: 1.20 / B Score: 0.35 / A Actor Loss: 0.0002 / A Critic Loss: 0.0246 / B Actor Loss: -0.0079 / B Critic Loss: 0.0311
# 3130 Episode / Step: 553049 / A Score: 1.55 / B Score: 1.55 / A Actor Loss: 0.0056 / A Critic Loss: 0.0215 / B Actor Loss: -0.0107 / B Critic Loss: 0.0250
# 3140 Episode / Step: 556651 / A Score: 1.40 / B Score: 0.50 / A Actor Loss: -0.0149 / A Critic Loss: 0.0249 / B Actor Loss: 0.0109 / B Critic Loss: 0.0386
# 3150 Episode / Step: 558552 / A Score: 0.00 / B Score: 0.85 / A Actor Loss: 0.0450 / A Critic Loss: 0.0491 / B Actor Loss: -0.0374 / B Critic Loss: 0.0389
# 3160 Episode / Step: 560095 / A Score: -0.15 / B Score: 0.90 / A Actor Loss: 0.0622 / A Critic Loss: 0.0696 / B Actor Loss: -0.0243 / B Critic Loss: 0.0507
# 3170 Episode / Step: 566302 / A Score: 1.70 / B Score: 1.40 / A Actor Loss: -0.0011 / A Critic Loss: 0.0208 / B Actor Loss: -0.0018 / B Critic Loss: 0.0255
# 3180 Episode / Step: 571681 / A Score: 1.15 / B Score: 1.55 / A Actor Loss: 0.0134 / A Critic Loss: 0.0232 / B Actor Loss: -0.0084 / B Critic Loss: 0.0224
# 3190 Episode / Step: 579187 / A Score: 1.60 / B Score: 1.85 / A Actor Loss: -0.0068 / A Critic Loss: 0.0209 / B Actor Loss: 0.0016 / B Critic Loss: 0.0197
# 3200 Episode / Step: 581265 / A Score: 0.10 / B Score: 1.10 / A Actor Loss: 0.0526 / A Critic Loss: 0.0578 / B Actor Loss: -0.0377 / B Critic Loss: 0.0367
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3210 Episode / Step: 595536 / A Score: 3.05 / B Score: 3.25 / A Actor Loss: -0.0098 / A Critic Loss: 0.0120 / B Actor Loss: 0.0034 / B Critic Loss: 0.0099
# 3220 Episode / Step: 605029 / A Score: 2.95 / B Score: 1.70 / A Actor Loss: -0.0023 / A Critic Loss: 0.0101 / B Actor Loss: 0.0041 / B Critic Loss: 0.0161
# 3230 Episode / Step: 609705 / A Score: 1.45 / B Score: 1.05 / A Actor Loss: 0.0033 / A Critic Loss: 0.0241 / B Actor Loss: -0.0034 / B Critic Loss: 0.0223
# 3240 Episode / Step: 624338 / A Score: 2.85 / B Score: 3.20 / A Actor Loss: 0.0022 / A Critic Loss: 0.0117 / B Actor Loss: -0.0029 / B Critic Loss: 0.0103
# 3250 Episode / Step: 632262 / A Score: 2.70 / B Score: 1.00 / A Actor Loss: -0.0168 / A Critic Loss: 0.0098 / B Actor Loss: 0.0217 / B Critic Loss: 0.0161
# 3260 Episode / Step: 635261 / A Score: 1.65 / B Score: 0.10 / A Actor Loss: -0.0022 / A Critic Loss: 0.0178 / B Actor Loss: 0.0049 / B Critic Loss: 0.0350
# 3270 Episode / Step: 642255 / A Score: 2.35 / B Score: 1.35 / A Actor Loss: 0.0029 / A Critic Loss: 0.0152 / B Actor Loss: -0.0067 / B Critic Loss: 0.0225
# 3280 Episode / Step: 645468 / A Score: 1.40 / B Score: 0.30 / A Actor Loss: 0.0036 / A Critic Loss: 0.0328 / B Actor Loss: 0.0080 / B Critic Loss: 0.0326
# 3290 Episode / Step: 649424 / A Score: 2.05 / B Score: 0.25 / A Actor Loss: -0.0087 / A Critic Loss: 0.0138 / B Actor Loss: 0.0098 / B Critic Loss: 0.0381
# 3300 Episode / Step: 653202 / A Score: 1.40 / B Score: 0.60 / A Actor Loss: 0.0048 / A Critic Loss: 0.0192 / B Actor Loss: -0.0013 / B Critic Loss: 0.0299
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3310 Episode / Step: 657351 / A Score: 1.90 / B Score: 0.55 / A Actor Loss: 0.0073 / A Critic Loss: 0.0163 / B Actor Loss: -0.0098 / B Critic Loss: 0.0276
# 3320 Episode / Step: 662009 / A Score: 1.50 / B Score: 1.10 / A Actor Loss: -0.0041 / A Critic Loss: 0.0271 / B Actor Loss: 0.0012 / B Critic Loss: 0.0389
# 3330 Episode / Step: 672943 / A Score: 2.45 / B Score: 2.30 / A Actor Loss: 0.0043 / A Critic Loss: 0.0130 / B Actor Loss: -0.0076 / B Critic Loss: 0.0150
# 3340 Episode / Step: 677725 / A Score: 1.05 / B Score: 1.15 / A Actor Loss: 0.0097 / A Critic Loss: 0.0294 / B Actor Loss: -0.0108 / B Critic Loss: 0.0249
# 3350 Episode / Step: 684060 / A Score: 1.25 / B Score: 1.70 / A Actor Loss: -0.0027 / A Critic Loss: 0.0206 / B Actor Loss: -0.0036 / B Critic Loss: 0.0177
# 3360 Episode / Step: 686092 / A Score: -0.40 / B Score: 1.35 / A Actor Loss: 0.0570 / A Critic Loss: 0.0484 / B Actor Loss: -0.0320 / B Critic Loss: 0.0288
# 3370 Episode / Step: 692033 / A Score: 0.85 / B Score: 1.70 / A Actor Loss: -0.0073 / A Critic Loss: 0.0216 / B Actor Loss: 0.0073 / B Critic Loss: 0.0149
# 3380 Episode / Step: 699477 / A Score: 1.20 / B Score: 2.30 / A Actor Loss: 0.0043 / A Critic Loss: 0.0174 / B Actor Loss: 0.0027 / B Critic Loss: 0.0129
# 3390 Episode / Step: 706900 / A Score: 2.20 / B Score: 1.65 / A Actor Loss: -0.0119 / A Critic Loss: 0.0195 / B Actor Loss: 0.0012 / B Critic Loss: 0.0199
# 3400 Episode / Step: 708495 / A Score: 0.35 / B Score: 0.35 / A Actor Loss: 0.0072 / A Critic Loss: 0.0398 / B Actor Loss: 0.0098 / B Critic Loss: 0.0427
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3410 Episode / Step: 710477 / A Score: 0.90 / B Score: -0.05 / A Actor Loss: -0.0263 / A Critic Loss: 0.0456 / B Actor Loss: 0.0596 / B Critic Loss: 0.0645
# 3420 Episode / Step: 717402 / A Score: 1.70 / B Score: 1.35 / A Actor Loss: 0.0081 / A Critic Loss: 0.0177 / B Actor Loss: -0.0074 / B Critic Loss: 0.0242
# 3430 Episode / Step: 721718 / A Score: 1.75 / B Score: -0.05 / A Actor Loss: -0.0188 / A Critic Loss: 0.0162 / B Actor Loss: 0.0119 / B Critic Loss: 0.0253
# 3440 Episode / Step: 723546 / A Score: 1.10 / B Score: -0.25 / A Actor Loss: -0.0344 / A Critic Loss: 0.0274 / B Actor Loss: 0.0657 / B Critic Loss: 0.0556
# 3450 Episode / Step: 736754 / A Score: 3.65 / B Score: 2.85 / A Actor Loss: 0.0082 / A Critic Loss: 0.0088 / B Actor Loss: -0.0148 / B Critic Loss: 0.0126
# 3460 Episode / Step: 739389 / A Score: 0.95 / B Score: 0.10 / A Actor Loss: 0.0010 / A Critic Loss: 0.0352 / B Actor Loss: 0.0208 / B Critic Loss: 0.0459
# 3470 Episode / Step: 747723 / A Score: 2.15 / B Score: 1.40 / A Actor Loss: -0.0024 / A Critic Loss: 0.0125 / B Actor Loss: -0.0082 / B Critic Loss: 0.0172
# 3480 Episode / Step: 750950 / A Score: 1.95 / B Score: -0.35 / A Actor Loss: -0.0270 / A Critic Loss: 0.0203 / B Actor Loss: 0.0348 / B Critic Loss: 0.0454
# 3490 Episode / Step: 760366 / A Score: 2.55 / B Score: 1.85 / A Actor Loss: 0.0060 / A Critic Loss: 0.0121 / B Actor Loss: -0.0114 / B Critic Loss: 0.0155
# 3500 Episode / Step: 771037 / A Score: 2.70 / B Score: 1.65 / A Actor Loss: 0.0036 / A Critic Loss: 0.0083 / B Actor Loss: 0.0013 / B Critic Loss: 0.0110
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3510 Episode / Step: 778178 / A Score: 1.60 / B Score: 1.70 / A Actor Loss: 0.0011 / A Critic Loss: 0.0171 / B Actor Loss: -0.0039 / B Critic Loss: 0.0210
# 3520 Episode / Step: 784775 / A Score: 1.45 / B Score: 1.05 / A Actor Loss: 0.0138 / A Critic Loss: 0.0157 / B Actor Loss: -0.0067 / B Critic Loss: 0.0202
# 3530 Episode / Step: 788817 / A Score: 0.75 / B Score: 1.30 / A Actor Loss: 0.0005 / A Critic Loss: 0.0256 / B Actor Loss: -0.0135 / B Critic Loss: 0.0294
# 3540 Episode / Step: 794970 / A Score: 1.45 / B Score: 0.85 / A Actor Loss: -0.0088 / A Critic Loss: 0.0140 / B Actor Loss: 0.0177 / B Critic Loss: 0.0192
# 3550 Episode / Step: 796846 / A Score: 0.90 / B Score: 0.00 / A Actor Loss: 0.0032 / A Critic Loss: 0.0367 / B Actor Loss: 0.0194 / B Critic Loss: 0.0470
# 3560 Episode / Step: 799144 / A Score: 1.00 / B Score: 0.05 / A Actor Loss: 0.0154 / A Critic Loss: 0.0580 / B Actor Loss: 0.0015 / B Critic Loss: 0.0531
# 3570 Episode / Step: 801987 / A Score: 1.40 / B Score: 0.10 / A Actor Loss: -0.0258 / A Critic Loss: 0.0224 / B Actor Loss: 0.0259 / B Critic Loss: 0.0425
# 3580 Episode / Step: 805436 / A Score: 1.25 / B Score: 0.50 / A Actor Loss: 0.0118 / A Critic Loss: 0.0321 / B Actor Loss: -0.0167 / B Critic Loss: 0.0369
# 3590 Episode / Step: 807190 / A Score: 0.70 / B Score: 0.25 / A Actor Loss: -0.0105 / A Critic Loss: 0.0483 / B Actor Loss: 0.0331 / B Critic Loss: 0.0590
# 3600 Episode / Step: 808856 / A Score: 1.35 / B Score: -0.50 / A Actor Loss: -0.0302 / A Critic Loss: 0.0426 / B Actor Loss: 0.0384 / B Critic Loss: 0.0520
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3610 Episode / Step: 814812 / A Score: 2.15 / B Score: 0.80 / A Actor Loss: 0.0013 / A Critic Loss: 0.0163 / B Actor Loss: -0.0089 / B Critic Loss: 0.0289
# 3620 Episode / Step: 825095 / A Score: 3.15 / B Score: 1.50 / A Actor Loss: -0.0013 / A Critic Loss: 0.0055 / B Actor Loss: -0.0038 / B Critic Loss: 0.0154
# 3630 Episode / Step: 827071 / A Score: 1.10 / B Score: -0.25 / A Actor Loss: -0.0017 / A Critic Loss: 0.0400 / B Actor Loss: 0.0207 / B Critic Loss: 0.0501
# 3640 Episode / Step: 830220 / A Score: 0.85 / B Score: 0.75 / A Actor Loss: -0.0003 / A Critic Loss: 0.0291 / B Actor Loss: 0.0036 / B Critic Loss: 0.0364
# 3650 Episode / Step: 832581 / A Score: 1.00 / B Score: 0.25 / A Actor Loss: 0.0117 / A Critic Loss: 0.0460 / B Actor Loss: -0.0179 / B Critic Loss: 0.0475
# 3660 Episode / Step: 837361 / A Score: 1.75 / B Score: 0.85 / A Actor Loss: -0.0129 / A Critic Loss: 0.0199 / B Actor Loss: -0.0024 / B Critic Loss: 0.0306
# 3670 Episode / Step: 841426 / A Score: 1.00 / B Score: 1.05 / A Actor Loss: 0.0110 / A Critic Loss: 0.0324 / B Actor Loss: -0.0194 / B Critic Loss: 0.0297
# 3680 Episode / Step: 853819 / A Score: 3.15 / B Score: 2.90 / A Actor Loss: -0.0029 / A Critic Loss: 0.0112 / B Actor Loss: -0.0079 / B Critic Loss: 0.0137
# 3690 Episode / Step: 859504 / A Score: 0.80 / B Score: 1.30 / A Actor Loss: 0.0119 / A Critic Loss: 0.0230 / B Actor Loss: -0.0034 / B Critic Loss: 0.0184
# 3700 Episode / Step: 862214 / A Score: 1.15 / B Score: 0.30 / A Actor Loss: -0.0197 / A Critic Loss: 0.0338 / B Actor Loss: 0.0199 / B Critic Loss: 0.0423
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3710 Episode / Step: 865071 / A Score: 1.50 / B Score: -0.20 / A Actor Loss: -0.0398 / A Critic Loss: 0.0167 / B Actor Loss: 0.0550 / B Critic Loss: 0.0398
# 3720 Episode / Step: 866382 / A Score: 1.00 / B Score: -0.35 / A Actor Loss: -0.0077 / A Critic Loss: 0.0494 / B Actor Loss: 0.0253 / B Critic Loss: 0.0526
# 3730 Episode / Step: 872414 / A Score: 2.00 / B Score: 0.70 / A Actor Loss: 0.0043 / A Critic Loss: 0.0131 / B Actor Loss: -0.0095 / B Critic Loss: 0.0255
# 3740 Episode / Step: 887839 / A Score: 4.70 / B Score: 3.40 / A Actor Loss: 0.0022 / A Critic Loss: 0.0052 / B Actor Loss: -0.0070 / B Critic Loss: 0.0118
# 3750 Episode / Step: 897456 / A Score: 2.95 / B Score: 1.95 / A Actor Loss: -0.0005 / A Critic Loss: 0.0126 / B Actor Loss: -0.0054 / B Critic Loss: 0.0184
# 3760 Episode / Step: 899455 / A Score: 0.70 / B Score: 0.20 / A Actor Loss: 0.0045 / A Critic Loss: 0.0406 / B Actor Loss: 0.0238 / B Critic Loss: 0.0467
# 3770 Episode / Step: 907453 / A Score: 2.95 / B Score: 1.20 / A Actor Loss: -0.0057 / A Critic Loss: 0.0122 / B Actor Loss: -0.0004 / B Critic Loss: 0.0238
# 3780 Episode / Step: 917696 / A Score: 3.55 / B Score: 1.80 / A Actor Loss: 0.0002 / A Critic Loss: 0.0065 / B Actor Loss: -0.0010 / B Critic Loss: 0.0173
# 3790 Episode / Step: 930504 / A Score: 3.95 / B Score: 2.20 / A Actor Loss: 0.0032 / A Critic Loss: 0.0060 / B Actor Loss: -0.0014 / B Critic Loss: 0.0150
# 3800 Episode / Step: 936701 / A Score: 1.95 / B Score: 1.05 / A Actor Loss: 0.0029 / A Critic Loss: 0.0155 / B Actor Loss: -0.0003 / B Critic Loss: 0.0233
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# 3810 Episode / Step: 950764 / A Score: 4.00 / B Score: 2.95 / A Actor Loss: 0.0006 / A Critic Loss: 0.0076 / B Actor Loss: -0.0009 / B Critic Loss: 0.0149
# 3820 Episode / Step: 966666 / A Score: 4.35 / B Score: 3.40 / A Actor Loss: 0.0008 / A Critic Loss: 0.0053 / B Actor Loss: -0.0009 / B Critic Loss: 0.0084
# 3830 Episode / Step: 975572 / A Score: 2.40 / B Score: 2.05 / A Actor Loss: 0.0022 / A Critic Loss: 0.0143 / B Actor Loss: -0.0032 / B Critic Loss: 0.0185
# 3840 Episode / Step: 981715 / A Score: 2.10 / B Score: 0.75 / A Actor Loss: -0.0031 / A Critic Loss: 0.0137 / B Actor Loss: 0.0068 / B Critic Loss: 0.0225
# 3850 Episode / Step: 993303 / A Score: 2.40 / B Score: 2.95 / A Actor Loss: 0.0049 / A Critic Loss: 0.0109 / B Actor Loss: -0.0066 / B Critic Loss: 0.0105
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/ckpt ...
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/ckpt ...
# TEST START
# 3860 Episode / Step: 1001676 / A Score: 2.35 / B Score: 1.85 / A Actor Loss: -0.0012 / A Critic Loss: 0.0163 / B Actor Loss: 0.0043 / B Critic Loss: 0.0164
# 3870 Episode / Step: 1002910 / A Score: -0.05 / B Score: 0.70 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 3880 Episode / Step: 1016292 / A Score: 2.70 / B Score: 3.85 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 3890 Episode / Step: 1030319 / A Score: 3.75 / B Score: 3.50 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 3900 Episode / Step: 1044429 / A Score: 3.90 / B Score: 3.50 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000

# %% [markdown]
# ## Test the pretrained model

# %%
env.close()

# %%
load_model = True
train_mode = False

load_path = save_path

engine_configuration_channel = EngineConfigurationChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel],
                       base_port=unity_base_port)
env.reset()

# Setup Unity Behavior
behavior_name_list = list(env.behavior_specs.keys())
behavior_A = behavior_name_list[0]
behavior_B = behavior_name_list[1]
engine_configuration_channel.set_configuration_parameters(time_scale=1.0)
dec_A, term_A = env.get_steps(behavior_A)
dec_B, term_B = env.get_steps(behavior_B)

# Setup objects of PPOAgent for agent_A and agent_B
agent_A = PPOAgent("A")
agent_B = PPOAgent("B")


episode = 0
actor_losses_A, critic_losses_A, scores_A, score_A = [], [], [], 0
actor_losses_B, critic_losses_B, scores_B, score_B = [], [], [], 0
for step in range(test_step):
    state_A = dec_A.obs[0]
    state_B = dec_B.obs[0]
    action_A = agent_A.get_action(state_A, train_mode)
    action_B = agent_B.get_action(state_B, train_mode)
    action_tuple_A, action_tuple_B = map(lambda x: ActionTuple(discrete=x), [action_A, action_B])
    env.set_actions(behavior_A, action_tuple_A)
    env.set_actions(behavior_B, action_tuple_B)
    env.step()

    dec_A, term_A = env.get_steps(behavior_A)
    dec_B, term_B = env.get_steps(behavior_B)
    done_A = len(term_A.agent_id) > 0
    done_B = len(term_B.agent_id) > 0
    next_state_A = term_A.obs[0] if done_A else dec_A.obs[0]
    next_state_B = term_B.obs[0] if done_B else dec_B.obs[0]
    reward_A = term_A.reward if done_A else dec_A.reward
    reward_B = term_B.reward if done_B else dec_B.reward
    score_A += reward_A[0]
    score_B += reward_B[0]

    if done_A or done_B:
        episode +=1
        scores_A.append(score_A)
        scores_B.append(score_B)
        score_A = score_B = 0

        # logging tensorboard
        if episode % print_interval == 0:
            mean_score_A = np.mean(scores_A)
            mean_score_B = np.mean(scores_B)
            mean_actor_loss_A = np.mean(actor_losses_A) if len(actor_losses_A) > 0 else 0
            mean_critic_loss_A = np.mean(critic_losses_A) if len(critic_losses_A) > 0 else 0
            mean_actor_loss_B = np.mean(actor_losses_B) if len(actor_losses_B) > 0 else 0
            mean_critic_loss_B = np.mean(critic_losses_B) if len(critic_losses_B) > 0 else 0
            agent_A.write_summary(mean_score_A, mean_actor_loss_A, mean_critic_loss_A, step)
            agent_B.write_summary(mean_score_B, mean_actor_loss_B, mean_critic_loss_B, step)
            actor_losses_A, critic_losses_A, scores_A = [], [], []
            actor_losses_B, critic_losses_B, scores_B = [], [], []

            print(f"{episode} Episode / Step: {step} / "  +\
                    f"A Score: {mean_score_A:.2f} / B Score: {mean_score_B:.2f} / " +\
                    f"A Actor Loss: {mean_actor_loss_A:.4f} / A Critic Loss: {mean_critic_loss_A:.4f} / " +\
                    f"B Actor Loss: {mean_actor_loss_B:.4f} / B Critic Loss: {mean_critic_loss_B:.4f}")

env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# ... Load Model from /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/A/Pong_Adversarial.ckpt ...
# ... Load Model from /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/Pong/Adversarial/20250925174406/B/Pong_Adversarial.ckpt ...
# 10 Episode / Step: 18222 / A Score: 5.00 / B Score: 4.55 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 20 Episode / Step: 29910 / A Score: 2.55 / B Score: 3.25 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 30 Episode / Step: 39041 / A Score: 2.15 / B Score: 2.30 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
# 40 Episode / Step: 46588 / A Score: 1.55 / B Score: 2.00 / A Actor Loss: 0.0000 / A Critic Loss: 0.0000 / B Actor Loss: 0.0000 / B Critic Loss: 0.0000
