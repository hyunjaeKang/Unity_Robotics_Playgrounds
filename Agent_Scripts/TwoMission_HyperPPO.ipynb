# %% [markdown]
# # TwoMission Hyper PPO

# %%
import os
from pathlib import Path
import numpy as np
import datetime
import platform
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from mlagents_envs.environment import UnityEnvironment, ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel\
                             import EngineConfigurationChannel
from mlagents_envs.side_channel.environment_parameters_channel\
                             import EnvironmentParametersChannel

# %% [markdown]
# ## Setting environments

# %%
# Global Setting
cur_dir = os.getcwd()
env_dir = os.path.abspath(os.path.join(cur_dir, "..", "Unity6000_Envs"))
test_dir = os.path.abspath(os.path.join(cur_dir, "temp", "pytorch_output"))

# %% [markdown]
# ### Pytorch Device

# %%
# Pytorch Device
if torch.backends.mps.is_available():
    g_device = torch.device("mps")
elif torch.cuda.is_available():
    g_device = torch.device("cuda")
else:
    g_device = torch.device("cpu")

print(g_device)
# Out:
# mps

# %% [markdown]
# ### Unity Enviroment

# %%
# Unity Enviroment
game = "TwoMissions"
os_name = platform.system()

if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# %% [markdown]
# ### Seting parameters

# %%
# Parameters
state_size = 127 # Ray(19 * 6 = 114) & position(3) & rotation(4) & velocity(3) & ball velocity(3)
action_size = 4 # Rotate(2) & Move(2)
goal_size = 2 # goal_signal

GOAL_OBS = 0
RAY_OBS = 1
VECTOR_OBS = 2

load_model = False
train_mode = True

discount_factor = 0.99
learning_rate = 3e-4
n_step = 2560
batch_size = 256
n_epoch = 3
_lambda = 0.95
epsilon = 0.2

run_step = 1000000 if train_mode else 0
test_step = 10000

print_interval = 10
save_interval = 100


unity_base_port = 1596

# %%
# NN model : Save and Load
date_time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
save_path = os.path.join(test_dir, f"saved_models/{game}/Hyper_PPO/{date_time}")
Path(save_path).mkdir(parents=True, exist_ok=True)
save_model_path = os.path.join(save_path, 'TwoMission_HyperPPO.ckpt')
# print(f"save_path :{save_path}")
# print(f"save_model_path :{save_model_path}")
load_model_path = "" # Need to update

# %% [markdown]
# ## HyperNetwork

# %%
class HyperNetwork(torch.nn.Module):
    def __init__(self, input_unit_size, action_size, hyper_input_size, **kwargs):
        super(HyperNetwork, self).__init__(**kwargs)
        self.input_unit_size = input_unit_size
        self.action_size = action_size
        self.hyper_input_size = hyper_input_size

        self.d1 = torch.nn.Linear(self.hyper_input_size, 256)
        self.d2 = torch.nn.Linear(256, 256)
        self.pi = torch.nn.Linear(256, self.input_unit_size * self.action_size)
        self.v = torch.nn.Linear(256, self.input_unit_size)

    def forward(self, x, h):
        h = F.relu(self.d1(h))
        h = F.relu(self.d2(h))
        target_weights_pi = F.tanh(self.pi(h))
        target_weights_v = F.tanh(self.v(h))

        x = x.unsqueeze(dim=1)
        target_weights_pi = target_weights_pi.view(-1, self.input_unit_size, self.action_size)
        result_pi = torch.bmm(x, target_weights_pi)
        result_pi = result_pi.squeeze(dim = 1)
        target_weights_v = target_weights_v.view(-1, self.input_unit_size, 1)
        result_v = torch.bmm(x, target_weights_v)

        return F.softmax(result_pi, dim=1), result_v.squeeze(dim=1)

# %% [markdown]
# ## HyperActorCritic Network

# %%
class HyperActorCritic(torch.nn.Module):
    def __init__(self, **kwargs):
        super(HyperActorCritic, self).__init__(**kwargs)
        self.d1 = torch.nn.Linear(state_size, 256)
        self.d2 = torch.nn.Linear(256, 256)
        self.hn = HyperNetwork(256, action_size, goal_size)

    def forward(self, x, h):
        x = F.relu(self.d1(x))
        x = F.relu(self.d2(x))
        return self.hn(x, h)

# %% [markdown]
# ## Agent class

# %%
# Agent Class
class HyperPPOAgent:
    def __init__(self):
        self.network = HyperActorCritic().to(g_device)
        self.optimizer = torch.optim.Adam(self.network.parameters(), lr=learning_rate)
        self.memory = list()
        self.writer = SummaryWriter(save_path)

        if load_model == True:
            print(f"... Load Model from {load_model_path} ...")
            checkpoint = torch.load(load_model_path, map_location=g_device)
            self.network.load_state_dict(checkpoint["network"])
            self.optimizer.load_state_dict(checkpoint["optimizer"])

    # get action
    def get_action(self, state, goal_signal, training=True):
        self.network.train(training)

        pi, _ = self.network(torch.FloatTensor(state).to(g_device), torch.FloatTensor(goal_signal).to(g_device))
        action = torch.multinomial(pi, num_samples=1).cpu().numpy()
        return action

    # Add replay memory
    def append_sample(self, state, goal_signal, action, reward, next_state, next_goal_signal, done):
        self.memory.append((state, goal_signal, action, reward, next_state, next_goal_signal, done))

    # training
    def train_model(self):
        self.network.train()

        state      = np.stack([m[0] for m in self.memory], axis=0)
        goal_signal= np.stack([m[1] for m in self.memory], axis=0)
        action     = np.stack([m[2] for m in self.memory], axis=0)
        reward     = np.stack([m[3] for m in self.memory], axis=0)
        next_state = np.stack([m[4] for m in self.memory], axis=0)
        next_goal_signal = np.stack([m[5] for m in self.memory], axis=0)
        done       = np.stack([m[6] for m in self.memory], axis=0)
        self.memory.clear()

        state, goal_signal, action, reward, next_state, next_goal_signal, done = map(lambda x: torch.FloatTensor(x).to(g_device),
                                                        [state, goal_signal, action, reward, next_state, next_goal_signal, done])
        # prob_old, adv, ret
        with torch.no_grad():
            pi_old, value = self.network(state, goal_signal)
            prob_old = pi_old.gather(1, action.long())

            _, next_value = self.network(next_state, next_goal_signal)
            delta = reward + (1 - done) * discount_factor * next_value - value
            adv = delta.clone()
            adv, done = map(lambda x: x.view(n_step, -1).transpose(0,1).contiguous(), [adv, done])
            for t in reversed(range(n_step-1)):
                adv[:, t] += (1 - done[:, t]) * discount_factor * _lambda * adv[:, t+1]
            adv = adv.transpose(0,1).contiguous().view(-1, 1)

            ret = adv + value

        # training loop
        actor_losses, critic_losses = [], []
        idxs = np.arange(len(reward))
        for _ in range(n_epoch):
            np.random.shuffle(idxs)
            for offset in range(0, len(reward), batch_size):
                idx = idxs[offset : offset + batch_size]

                _state, _goal_signal, _action, _ret, _adv, _prob_old =\
                    map(lambda x: x[idx], [state, goal_signal, action, ret, adv, prob_old])

                pi, value = self.network(_state, _goal_signal)
                prob = pi.gather(1, _action.long())

                # loss function for policy function
                ratio = prob / (_prob_old + 1e-7)
                surr1 = ratio * _adv
                surr2 = torch.clamp(ratio, min=1-epsilon, max=1+epsilon) * _adv
                actor_loss = -torch.min(surr1, surr2).mean()

                # loss function for value function
                critic_loss = F.mse_loss(value, _ret).mean()

                total_loss = actor_loss + critic_loss

                self.optimizer.zero_grad()
                total_loss.backward()
                self.optimizer.step()

                actor_losses.append(actor_loss.item())
                critic_losses.append(critic_loss.item())

        return np.mean(actor_losses), np.mean(critic_losses)

    # save model
    def save_model(self):
        print(f"... Save Model to {save_model_path} ...")
        torch.save({
            "network" : self.network.state_dict(),
            "optimizer" : self.optimizer.state_dict(),
        }, save_model_path)

    # logging
    def write_summary(self, score, actor_loss, critic_loss, step):
        self.writer.add_scalar("HyperPPOAgent_run/score", score, step)
        self.writer.add_scalar("HyperPPOAgent_model/actor_loss", actor_loss, step)
        self.writer.add_scalar("HyperPPOAgent_model/critic_loss", critic_loss, step)

# %% [markdown]
# ## Train Model

# %%
env.close()

# %%
engine_configuration_channel = EngineConfigurationChannel()
environment_parameters_channel = EnvironmentParametersChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel, environment_parameters_channel],
                       base_port=unity_base_port)
env.reset()

# Setup Unity Behavior
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=6.0)
dec, term = env.get_steps(behavior_name)
num_worker = len(dec)

# HyperPPOAgent
agent = HyperPPOAgent()
actor_losses, critic_losses, scores, episode, score = [], [], [], 0, 0
for step in range(run_step + test_step):
    if step == run_step:
        if train_mode:
            agent.save_model()
        print("TEST START")
        train_mode = False
        engine_configuration_channel.set_configuration_parameters(time_scale=1.0)

    goal_signal = dec.obs[GOAL_OBS]
    state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    action = agent.get_action(state, goal_signal, train_mode)
    action_tuple = ActionTuple()
    action_tuple.add_discrete(action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    # info from env
    dec, term = env.get_steps(behavior_name)
    done = [False] * num_worker
    next_goal_signal = dec.obs[GOAL_OBS]
    next_state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    reward = dec.reward
    for id in term.agent_id:
        _id = list(term.agent_id).index(id)
        done[id] = True
        next_goal_signal[id] = term.obs[GOAL_OBS][_id]
        next_state[id] = np.concatenate([term.obs[RAY_OBS][_id], term.obs[VECTOR_OBS][_id]], axis=-1)
        reward[id] = term.reward[_id]
    score += reward[0]

    if train_mode:
        for id in range(num_worker):
            agent.append_sample(state[id], goal_signal[id], action[id], [reward[id]], next_state[id], next_goal_signal[id], [done[id]])
        # training
        if (step+1) % n_step == 0:
            actor_loss, critic_loss = agent.train_model()
            actor_losses.append(actor_loss)
            critic_losses.append(critic_loss)

    if done[0]:
        episode +=1
        scores.append(score)
        score = 0

        # logging
        if episode % print_interval == 0:
            mean_score = np.mean(scores)
            mean_actor_loss = np.mean(actor_losses) if len(actor_losses) > 0 else 0
            mean_critic_loss = np.mean(critic_losses)  if len(critic_losses) > 0 else 0
            agent.write_summary(mean_score, mean_actor_loss, mean_critic_loss, step)
            actor_losses, critic_losses, scores = [], [], []

            print(f"{episode} Episode / Step: {step} / Score: {mean_score:.2f} / " +\
                    f"Actor loss: {mean_actor_loss:.2f} / Critic loss: {mean_critic_loss:.4f}" )

        # save model
        if train_mode and episode % save_interval == 0:
            agent.save_model()
env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# 10 Episode / Step: 9540 / Score: -0.58 / Actor loss: 0.01 / Critic loss: 0.0013
# 20 Episode / Step: 17684 / Score: -0.51 / Actor loss: 0.01 / Critic loss: 0.0007
# 30 Episode / Step: 25276 / Score: 0.12 / Actor loss: 0.01 / Critic loss: 0.0011
# 40 Episode / Step: 33379 / Score: -0.21 / Actor loss: 0.01 / Critic loss: 0.0008
# 50 Episode / Step: 43379 / Score: -0.50 / Actor loss: 0.01 / Critic loss: 0.0010
# 60 Episode / Step: 50683 / Score: -0.26 / Actor loss: 0.01 / Critic loss: 0.0011
# 70 Episode / Step: 55258 / Score: 0.37 / Actor loss: 0.01 / Critic loss: 0.0017
# 80 Episode / Step: 60770 / Score: 0.12 / Actor loss: 0.01 / Critic loss: 0.0021
# 90 Episode / Step: 65874 / Score: 0.15 / Actor loss: 0.01 / Critic loss: 0.0019
# 100 Episode / Step: 67836 / Score: 0.80 / Actor loss: 0.01 / Critic loss: 0.0025
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 110 Episode / Step: 73292 / Score: 0.03 / Actor loss: 0.01 / Critic loss: 0.0029
# 120 Episode / Step: 77611 / Score: -0.02 / Actor loss: 0.01 / Critic loss: 0.0031
# 130 Episode / Step: 80085 / Score: 0.58 / Actor loss: 0.01 / Critic loss: 0.0032
# 140 Episode / Step: 81661 / Score: 0.32 / Actor loss: 0.00 / Critic loss: 0.0000
# 150 Episode / Step: 84514 / Score: 0.46 / Actor loss: 0.00 / Critic loss: 0.0040
# 160 Episode / Step: 86854 / Score: 0.58 / Actor loss: 0.00 / Critic loss: 0.0000
# 170 Episode / Step: 88650 / Score: 0.61 / Actor loss: 0.00 / Critic loss: 0.0058
# 180 Episode / Step: 89486 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 190 Episode / Step: 90449 / Score: 0.55 / Actor loss: 0.01 / Critic loss: 0.0081
# 200 Episode / Step: 91629 / Score: 0.74 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 210 Episode / Step: 93297 / Score: 0.72 / Actor loss: 0.01 / Critic loss: 0.0083
# 220 Episode / Step: 94228 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 230 Episode / Step: 95346 / Score: 0.94 / Actor loss: 0.00 / Critic loss: 0.0093
# 240 Episode / Step: 96742 / Score: 0.73 / Actor loss: 0.00 / Critic loss: 0.0000
# 250 Episode / Step: 99932 / Score: 0.64 / Actor loss: 0.01 / Critic loss: 0.0075
# 260 Episode / Step: 100566 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 270 Episode / Step: 101251 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 280 Episode / Step: 102518 / Score: 0.74 / Actor loss: -0.01 / Critic loss: 0.0079
# 290 Episode / Step: 103287 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 300 Episode / Step: 104389 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 310 Episode / Step: 105239 / Score: 0.56 / Actor loss: -0.01 / Critic loss: 0.0113
# 320 Episode / Step: 105961 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 330 Episode / Step: 106760 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 340 Episode / Step: 108430 / Score: 0.52 / Actor loss: 0.01 / Critic loss: 0.0098
# 350 Episode / Step: 109416 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 360 Episode / Step: 110038 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 370 Episode / Step: 110834 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0098
# 380 Episode / Step: 111930 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 390 Episode / Step: 112611 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 400 Episode / Step: 113393 / Score: 0.96 / Actor loss: 0.01 / Critic loss: 0.0074
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 410 Episode / Step: 114073 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 420 Episode / Step: 114691 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 430 Episode / Step: 115407 / Score: 0.96 / Actor loss: -0.01 / Critic loss: 0.0059
# 440 Episode / Step: 116322 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 450 Episode / Step: 117009 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 460 Episode / Step: 117623 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 470 Episode / Step: 118261 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0086
# 480 Episode / Step: 118739 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 490 Episode / Step: 119355 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 500 Episode / Step: 120044 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 510 Episode / Step: 120739 / Score: 0.77 / Actor loss: -0.00 / Critic loss: 0.0076
# 520 Episode / Step: 121399 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 530 Episode / Step: 122542 / Score: 0.74 / Actor loss: 0.00 / Critic loss: 0.0000
# 540 Episode / Step: 123106 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0067
# 550 Episode / Step: 123714 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 560 Episode / Step: 124283 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 570 Episode / Step: 124792 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 580 Episode / Step: 125351 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 590 Episode / Step: 126212 / Score: 0.96 / Actor loss: -0.00 / Critic loss: 0.0074
# 600 Episode / Step: 126612 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 610 Episode / Step: 127221 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 620 Episode / Step: 127683 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 630 Episode / Step: 128291 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0070
# 640 Episode / Step: 129144 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 650 Episode / Step: 129859 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 660 Episode / Step: 130503 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 670 Episode / Step: 131134 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0072
# 680 Episode / Step: 131768 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 690 Episode / Step: 132501 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 700 Episode / Step: 133048 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 710 Episode / Step: 133587 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0087
# 720 Episode / Step: 134067 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 730 Episode / Step: 134557 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 740 Episode / Step: 135218 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 750 Episode / Step: 135961 / Score: 0.76 / Actor loss: -0.01 / Critic loss: 0.0063
# 760 Episode / Step: 136603 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 770 Episode / Step: 137189 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 780 Episode / Step: 137742 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 790 Episode / Step: 138294 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0058
# 800 Episode / Step: 138871 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 810 Episode / Step: 139393 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 820 Episode / Step: 140129 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 830 Episode / Step: 141017 / Score: 0.76 / Actor loss: 0.01 / Critic loss: 0.0068
# 840 Episode / Step: 141532 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 850 Episode / Step: 142409 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 860 Episode / Step: 143030 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 870 Episode / Step: 143550 / Score: 0.77 / Actor loss: -0.00 / Critic loss: 0.0058
# 880 Episode / Step: 144381 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 890 Episode / Step: 144992 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 900 Episode / Step: 145562 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 910 Episode / Step: 146083 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0094
# 920 Episode / Step: 146680 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 930 Episode / Step: 147497 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 940 Episode / Step: 148005 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 950 Episode / Step: 148620 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0071
# 960 Episode / Step: 149095 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 970 Episode / Step: 149721 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 980 Episode / Step: 150146 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 990 Episode / Step: 150610 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1000 Episode / Step: 151182 / Score: 0.97 / Actor loss: 0.02 / Critic loss: 0.0086
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1010 Episode / Step: 151853 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1020 Episode / Step: 152277 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1030 Episode / Step: 153198 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 1040 Episode / Step: 153831 / Score: 0.57 / Actor loss: -0.00 / Critic loss: 0.0062
# 1050 Episode / Step: 154417 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1060 Episode / Step: 154961 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1070 Episode / Step: 155508 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1080 Episode / Step: 156237 / Score: 0.56 / Actor loss: 0.00 / Critic loss: 0.0082
# 1090 Episode / Step: 156891 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 1100 Episode / Step: 157425 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1110 Episode / Step: 157862 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1120 Episode / Step: 158627 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 1130 Episode / Step: 159371 / Score: 0.16 / Actor loss: 0.01 / Critic loss: 0.0095
# 1140 Episode / Step: 159945 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1150 Episode / Step: 160459 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1160 Episode / Step: 161057 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1170 Episode / Step: 161663 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0101
# 1180 Episode / Step: 162177 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1190 Episode / Step: 162686 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1200 Episode / Step: 163283 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1210 Episode / Step: 164051 / Score: 0.76 / Actor loss: -0.00 / Critic loss: 0.0072
# 1220 Episode / Step: 164662 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1230 Episode / Step: 165239 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1240 Episode / Step: 165817 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1250 Episode / Step: 166368 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1260 Episode / Step: 167567 / Score: 0.94 / Actor loss: 0.00 / Critic loss: 0.0082
# 1270 Episode / Step: 168143 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1280 Episode / Step: 168807 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1290 Episode / Step: 169394 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0065
# 1300 Episode / Step: 169928 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1310 Episode / Step: 170550 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1320 Episode / Step: 171055 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1330 Episode / Step: 171541 / Score: 0.78 / Actor loss: 0.01 / Critic loss: 0.0073
# 1340 Episode / Step: 172038 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1350 Episode / Step: 172482 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1360 Episode / Step: 173035 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1370 Episode / Step: 173549 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1380 Episode / Step: 174186 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0048
# 1390 Episode / Step: 174602 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1400 Episode / Step: 175202 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1410 Episode / Step: 175865 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1420 Episode / Step: 176360 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 1430 Episode / Step: 176893 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0075
# 1440 Episode / Step: 177474 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1450 Episode / Step: 178533 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 1460 Episode / Step: 179100 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1470 Episode / Step: 179681 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0066
# 1480 Episode / Step: 180506 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1490 Episode / Step: 181061 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1500 Episode / Step: 181543 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1510 Episode / Step: 182253 / Score: 0.96 / Actor loss: 0.01 / Critic loss: 0.0079
# 1520 Episode / Step: 183083 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1530 Episode / Step: 183570 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1540 Episode / Step: 184145 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1550 Episode / Step: 184938 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0059
# 1560 Episode / Step: 185551 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1570 Episode / Step: 186075 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1580 Episode / Step: 186712 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1590 Episode / Step: 187308 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0079
# 1600 Episode / Step: 187834 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1610 Episode / Step: 188554 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 1620 Episode / Step: 189124 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1630 Episode / Step: 189677 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0069
# 1640 Episode / Step: 190275 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1650 Episode / Step: 190841 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 1660 Episode / Step: 191429 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1670 Episode / Step: 192059 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0076
# 1680 Episode / Step: 192836 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1690 Episode / Step: 193782 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 1700 Episode / Step: 194822 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0070
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1710 Episode / Step: 195344 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1720 Episode / Step: 195940 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1730 Episode / Step: 196473 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1740 Episode / Step: 196977 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 1750 Episode / Step: 197459 / Score: 0.98 / Actor loss: -0.01 / Critic loss: 0.0048
# 1760 Episode / Step: 198450 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 1770 Episode / Step: 199093 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 1780 Episode / Step: 199666 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1790 Episode / Step: 200528 / Score: 0.96 / Actor loss: 0.01 / Critic loss: 0.0072
# 1800 Episode / Step: 201019 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1810 Episode / Step: 201612 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1820 Episode / Step: 202375 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0068
# 1830 Episode / Step: 203657 / Score: 0.74 / Actor loss: 0.00 / Critic loss: 0.0000
# 1840 Episode / Step: 204258 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1850 Episode / Step: 204801 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0051
# 1860 Episode / Step: 205262 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1870 Episode / Step: 205817 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1880 Episode / Step: 206371 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1890 Episode / Step: 206962 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1900 Episode / Step: 207430 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0056
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 1910 Episode / Step: 207970 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1920 Episode / Step: 208562 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1930 Episode / Step: 209309 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1940 Episode / Step: 209912 / Score: 0.17 / Actor loss: 0.00 / Critic loss: 0.0000
# 1950 Episode / Step: 210585 / Score: 0.97 / Actor loss: 0.02 / Critic loss: 0.0116
# 1960 Episode / Step: 211390 / Score: 0.56 / Actor loss: 0.00 / Critic loss: 0.0000
# 1970 Episode / Step: 212217 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1980 Episode / Step: 212844 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0083
# 1990 Episode / Step: 213332 / Score: 0.58 / Actor loss: 0.00 / Critic loss: 0.0000
# 2000 Episode / Step: 213836 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2010 Episode / Step: 214266 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2020 Episode / Step: 214782 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2030 Episode / Step: 215525 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0092
# 2040 Episode / Step: 216006 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2050 Episode / Step: 216935 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 2060 Episode / Step: 217406 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2070 Episode / Step: 217847 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0040
# 2080 Episode / Step: 218395 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2090 Episode / Step: 218889 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2100 Episode / Step: 219638 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2110 Episode / Step: 220336 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0051
# 2120 Episode / Step: 220876 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2130 Episode / Step: 221362 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2140 Episode / Step: 221962 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2150 Episode / Step: 222458 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2160 Episode / Step: 223187 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0049
# 2170 Episode / Step: 223727 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2180 Episode / Step: 224271 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2190 Episode / Step: 224764 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2200 Episode / Step: 225394 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0051
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2210 Episode / Step: 225840 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2220 Episode / Step: 226389 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 2230 Episode / Step: 226874 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2240 Episode / Step: 227385 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2250 Episode / Step: 227900 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0078
# 2260 Episode / Step: 228674 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 2270 Episode / Step: 229402 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 2280 Episode / Step: 229988 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2290 Episode / Step: 230548 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0043
# 2300 Episode / Step: 231113 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2310 Episode / Step: 231960 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 2320 Episode / Step: 232613 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2330 Episode / Step: 233429 / Score: 0.96 / Actor loss: -0.00 / Critic loss: 0.0061
# 2340 Episode / Step: 233895 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2350 Episode / Step: 234451 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2360 Episode / Step: 234965 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2370 Episode / Step: 235443 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2380 Episode / Step: 235973 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0062
# 2390 Episode / Step: 236923 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 2400 Episode / Step: 237481 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2410 Episode / Step: 238067 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2420 Episode / Step: 238476 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0067
# 2430 Episode / Step: 238960 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2440 Episode / Step: 239574 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2450 Episode / Step: 240038 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2460 Episode / Step: 240629 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2470 Episode / Step: 241077 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0056
# 2480 Episode / Step: 241652 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2490 Episode / Step: 242243 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2500 Episode / Step: 242832 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2510 Episode / Step: 243361 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0061
# 2520 Episode / Step: 243827 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2530 Episode / Step: 244493 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2540 Episode / Step: 244987 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2550 Episode / Step: 246324 / Score: 0.93 / Actor loss: 0.01 / Critic loss: 0.0058
# 2560 Episode / Step: 247086 / Score: 0.56 / Actor loss: 0.00 / Critic loss: 0.0000
# 2570 Episode / Step: 247554 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2580 Episode / Step: 248216 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2590 Episode / Step: 248789 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0073
# 2600 Episode / Step: 249379 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2610 Episode / Step: 249985 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2620 Episode / Step: 250429 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2630 Episode / Step: 251008 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0057
# 2640 Episode / Step: 251483 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2650 Episode / Step: 252031 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2660 Episode / Step: 252522 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2670 Episode / Step: 253083 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2680 Episode / Step: 253725 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0052
# 2690 Episode / Step: 254235 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2700 Episode / Step: 254826 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2710 Episode / Step: 255268 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2720 Episode / Step: 255861 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2730 Episode / Step: 256441 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0056
# 2740 Episode / Step: 257043 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2750 Episode / Step: 257551 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 2760 Episode / Step: 258030 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2770 Episode / Step: 258548 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2780 Episode / Step: 259022 / Score: 0.98 / Actor loss: 0.02 / Critic loss: 0.0061
# 2790 Episode / Step: 259453 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2800 Episode / Step: 260037 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2810 Episode / Step: 260536 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2820 Episode / Step: 261175 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0045
# 2830 Episode / Step: 261691 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2840 Episode / Step: 262198 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2850 Episode / Step: 262664 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 2860 Episode / Step: 263320 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2870 Episode / Step: 263796 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0067
# 2880 Episode / Step: 264365 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2890 Episode / Step: 264795 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2900 Episode / Step: 265324 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 2910 Episode / Step: 265941 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2920 Episode / Step: 266730 / Score: 0.96 / Actor loss: 0.01 / Critic loss: 0.0066
# 2930 Episode / Step: 267296 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2940 Episode / Step: 267945 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2950 Episode / Step: 268500 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2960 Episode / Step: 268975 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0066
# 2970 Episode / Step: 269476 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2980 Episode / Step: 269924 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2990 Episode / Step: 270642 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 3000 Episode / Step: 271085 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3010 Episode / Step: 271685 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0046
# 3020 Episode / Step: 272221 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3030 Episode / Step: 272790 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3040 Episode / Step: 273606 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 3050 Episode / Step: 274132 / Score: 0.97 / Actor loss: -0.01 / Critic loss: 0.0067
# 3060 Episode / Step: 274545 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3070 Episode / Step: 275072 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3080 Episode / Step: 275617 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3090 Episode / Step: 276244 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3100 Episode / Step: 276750 / Score: 0.98 / Actor loss: -0.00 / Critic loss: 0.0047
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3110 Episode / Step: 277181 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3120 Episode / Step: 277673 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3130 Episode / Step: 278931 / Score: 0.74 / Actor loss: 0.00 / Critic loss: 0.0000
# 3140 Episode / Step: 279364 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0045
# 3150 Episode / Step: 279915 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3160 Episode / Step: 280327 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3170 Episode / Step: 280873 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3180 Episode / Step: 281427 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3190 Episode / Step: 281892 / Score: 0.98 / Actor loss: 0.02 / Critic loss: 0.0049
# 3200 Episode / Step: 282366 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3210 Episode / Step: 282919 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3220 Episode / Step: 283497 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3230 Episode / Step: 283982 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3240 Episode / Step: 284471 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0062
# 3250 Episode / Step: 284975 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3260 Episode / Step: 285381 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3270 Episode / Step: 285794 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3280 Episode / Step: 286308 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3290 Episode / Step: 286795 / Score: 0.78 / Actor loss: 0.01 / Critic loss: 0.0062
# 3300 Episode / Step: 287362 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3310 Episode / Step: 287849 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3320 Episode / Step: 288330 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 3330 Episode / Step: 288909 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3340 Episode / Step: 289510 / Score: 0.97 / Actor loss: 0.02 / Critic loss: 0.0069
# 3350 Episode / Step: 290523 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 3360 Episode / Step: 291098 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3370 Episode / Step: 291589 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3380 Episode / Step: 292112 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0049
# 3390 Episode / Step: 292898 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 3400 Episode / Step: 293493 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3410 Episode / Step: 293949 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3420 Episode / Step: 294387 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3430 Episode / Step: 294811 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0060
# 3440 Episode / Step: 295353 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3450 Episode / Step: 295889 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3460 Episode / Step: 296491 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3470 Episode / Step: 297183 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0060
# 3480 Episode / Step: 297804 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3490 Episode / Step: 298265 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3500 Episode / Step: 298677 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3510 Episode / Step: 299182 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3520 Episode / Step: 299694 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0034
# 3530 Episode / Step: 300137 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3540 Episode / Step: 300618 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3550 Episode / Step: 301114 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3560 Episode / Step: 301623 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3570 Episode / Step: 302390 / Score: 0.36 / Actor loss: 0.00 / Critic loss: 0.0042
# 3580 Episode / Step: 302882 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3590 Episode / Step: 303375 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3600 Episode / Step: 304045 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3610 Episode / Step: 304571 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3620 Episode / Step: 305043 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0062
# 3630 Episode / Step: 305482 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3640 Episode / Step: 305975 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3650 Episode / Step: 306528 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3660 Episode / Step: 307056 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3670 Episode / Step: 307556 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0062
# 3680 Episode / Step: 308006 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3690 Episode / Step: 308467 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3700 Episode / Step: 309184 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3710 Episode / Step: 309728 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3720 Episode / Step: 310212 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0048
# 3730 Episode / Step: 310703 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3740 Episode / Step: 311183 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3750 Episode / Step: 311776 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3760 Episode / Step: 312221 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3770 Episode / Step: 312682 / Score: 0.98 / Actor loss: -0.00 / Critic loss: 0.0039
# 3780 Episode / Step: 313150 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3790 Episode / Step: 313624 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3800 Episode / Step: 314184 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3810 Episode / Step: 314699 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3820 Episode / Step: 315365 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0069
# 3830 Episode / Step: 315883 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3840 Episode / Step: 316347 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3850 Episode / Step: 316781 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3860 Episode / Step: 317406 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3870 Episode / Step: 317910 / Score: 0.98 / Actor loss: 0.02 / Critic loss: 0.0059
# 3880 Episode / Step: 318338 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3890 Episode / Step: 318851 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3900 Episode / Step: 319809 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 3910 Episode / Step: 320280 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0030
# 3920 Episode / Step: 320695 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3930 Episode / Step: 321149 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3940 Episode / Step: 321548 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3950 Episode / Step: 321999 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3960 Episode / Step: 322640 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0035
# 3970 Episode / Step: 323438 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 3980 Episode / Step: 325070 / Score: 0.62 / Actor loss: 0.00 / Critic loss: 0.0000
# 3990 Episode / Step: 325551 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0033
# 4000 Episode / Step: 326150 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 4010 Episode / Step: 327660 / Score: 0.82 / Actor loss: 0.00 / Critic loss: 0.0000
# 4020 Episode / Step: 328102 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0035
# 4030 Episode / Step: 328567 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4040 Episode / Step: 328997 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4050 Episode / Step: 329520 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4060 Episode / Step: 330072 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4070 Episode / Step: 330558 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0044
# 4080 Episode / Step: 331065 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 4090 Episode / Step: 331592 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4100 Episode / Step: 332231 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 4110 Episode / Step: 332877 / Score: 0.77 / Actor loss: 0.02 / Critic loss: 0.0064
# 4120 Episode / Step: 333238 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4130 Episode / Step: 333657 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4140 Episode / Step: 334166 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4150 Episode / Step: 335067 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 4160 Episode / Step: 335486 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0068
# 4170 Episode / Step: 336240 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 4180 Episode / Step: 336681 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4190 Episode / Step: 337246 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4200 Episode / Step: 337655 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 4210 Episode / Step: 338253 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0050
# 4220 Episode / Step: 338838 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4230 Episode / Step: 339227 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4240 Episode / Step: 339668 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4250 Episode / Step: 340138 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4260 Episode / Step: 340639 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0050
# 4270 Episode / Step: 341251 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4280 Episode / Step: 341678 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4290 Episode / Step: 342147 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4300 Episode / Step: 342573 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 4310 Episode / Step: 343390 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0040
# 4320 Episode / Step: 343839 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4330 Episode / Step: 344369 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4340 Episode / Step: 344830 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4350 Episode / Step: 345283 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4360 Episode / Step: 345746 / Score: 0.98 / Actor loss: 0.02 / Critic loss: 0.0048
# 4370 Episode / Step: 346289 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4380 Episode / Step: 346683 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4390 Episode / Step: 347205 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4400 Episode / Step: 347635 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 4410 Episode / Step: 348312 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0042
# 4420 Episode / Step: 348827 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4430 Episode / Step: 349416 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4440 Episode / Step: 349827 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4450 Episode / Step: 350267 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4460 Episode / Step: 350744 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0049
# 4470 Episode / Step: 351228 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4480 Episode / Step: 351743 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ...
# 15610 Episode / Step: 931972 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0034
# 15620 Episode / Step: 932454 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15630 Episode / Step: 932964 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 15640 Episode / Step: 933439 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15650 Episode / Step: 933847 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15660 Episode / Step: 934321 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15670 Episode / Step: 934832 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0027
# 15680 Episode / Step: 935307 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15690 Episode / Step: 935869 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 15700 Episode / Step: 936331 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 15710 Episode / Step: 936772 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15720 Episode / Step: 937302 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0028
# 15730 Episode / Step: 937697 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15740 Episode / Step: 938187 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15750 Episode / Step: 938650 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15760 Episode / Step: 939164 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 15770 Episode / Step: 939592 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0020
# 15780 Episode / Step: 940571 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 15790 Episode / Step: 941090 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 15800 Episode / Step: 941640 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 15810 Episode / Step: 942126 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0038
# 15820 Episode / Step: 942518 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15830 Episode / Step: 943099 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 15840 Episode / Step: 943557 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15850 Episode / Step: 943973 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15860 Episode / Step: 944480 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 15870 Episode / Step: 945090 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0047
# 15880 Episode / Step: 945569 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15890 Episode / Step: 946004 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15900 Episode / Step: 947425 / Score: 0.73 / Actor loss: 0.01 / Critic loss: 0.0046
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 15910 Episode / Step: 947846 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15920 Episode / Step: 948391 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 15930 Episode / Step: 948845 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15940 Episode / Step: 949334 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 15950 Episode / Step: 949817 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0041
# 15960 Episode / Step: 950941 / Score: 0.34 / Actor loss: 0.00 / Critic loss: 0.0000
# 15970 Episode / Step: 951455 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 15980 Episode / Step: 952015 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 15990 Episode / Step: 953134 / Score: 0.94 / Actor loss: 0.02 / Critic loss: 0.0058
# 16000 Episode / Step: 953599 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16010 Episode / Step: 954084 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16020 Episode / Step: 954585 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16030 Episode / Step: 955027 / Score: 0.98 / Actor loss: -0.00 / Critic loss: 0.0021
# 16040 Episode / Step: 955523 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16050 Episode / Step: 956058 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16060 Episode / Step: 956568 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16070 Episode / Step: 957063 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16080 Episode / Step: 957852 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0034
# 16090 Episode / Step: 958343 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 16100 Episode / Step: 958731 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16110 Episode / Step: 959248 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16120 Episode / Step: 959674 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16130 Episode / Step: 960192 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0029
# 16140 Episode / Step: 960662 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 16150 Episode / Step: 961104 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16160 Episode / Step: 961750 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16170 Episode / Step: 962224 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16180 Episode / Step: 962744 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0035
# 16190 Episode / Step: 963149 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16200 Episode / Step: 963687 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16210 Episode / Step: 964166 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16220 Episode / Step: 964549 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16230 Episode / Step: 965095 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16240 Episode / Step: 965580 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0043
# 16250 Episode / Step: 966070 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16260 Episode / Step: 966705 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16270 Episode / Step: 967151 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16280 Episode / Step: 967675 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16290 Episode / Step: 968135 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0031
# 16300 Episode / Step: 968564 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16310 Episode / Step: 969125 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16320 Episode / Step: 969668 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16330 Episode / Step: 970158 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16340 Episode / Step: 970650 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0029
# 16350 Episode / Step: 971259 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16360 Episode / Step: 971868 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16370 Episode / Step: 972320 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16380 Episode / Step: 972870 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0048
# 16390 Episode / Step: 973300 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16400 Episode / Step: 973683 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16410 Episode / Step: 974179 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16420 Episode / Step: 974747 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16430 Episode / Step: 975180 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16440 Episode / Step: 975594 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0029
# 16450 Episode / Step: 976158 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16460 Episode / Step: 976639 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16470 Episode / Step: 977080 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16480 Episode / Step: 977530 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16490 Episode / Step: 977981 / Score: 0.98 / Actor loss: -0.00 / Critic loss: 0.0022
# 16500 Episode / Step: 978501 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16510 Episode / Step: 978986 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 16520 Episode / Step: 979465 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16530 Episode / Step: 979958 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16540 Episode / Step: 980402 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16550 Episode / Step: 980829 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0026
# 16560 Episode / Step: 981268 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16570 Episode / Step: 981762 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16580 Episode / Step: 982203 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16590 Episode / Step: 982703 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16600 Episode / Step: 983201 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0035
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16610 Episode / Step: 983708 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16620 Episode / Step: 984194 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16630 Episode / Step: 984626 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16640 Episode / Step: 985070 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16650 Episode / Step: 985468 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16660 Episode / Step: 985915 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0025
# 16670 Episode / Step: 986477 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16680 Episode / Step: 986986 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16690 Episode / Step: 987465 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16700 Episode / Step: 987950 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16710 Episode / Step: 988458 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0029
# 16720 Episode / Step: 988928 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16730 Episode / Step: 989528 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 16740 Episode / Step: 990055 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16750 Episode / Step: 990588 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16760 Episode / Step: 991071 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0033
# 16770 Episode / Step: 991816 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 16780 Episode / Step: 992279 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16790 Episode / Step: 992741 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16800 Episode / Step: 993182 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16810 Episode / Step: 993648 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0015
# 16820 Episode / Step: 994355 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16830 Episode / Step: 994877 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16840 Episode / Step: 995409 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16850 Episode / Step: 995858 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0018
# 16860 Episode / Step: 996353 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16870 Episode / Step: 996823 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16880 Episode / Step: 997285 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16890 Episode / Step: 997761 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16900 Episode / Step: 998211 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 16910 Episode / Step: 998663 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0020
# 16920 Episode / Step: 999158 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16930 Episode / Step: 999703 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# TEST START
# 16940 Episode / Step: 1000129 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16950 Episode / Step: 1000602 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16960 Episode / Step: 1001036 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16970 Episode / Step: 1001429 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 16980 Episode / Step: 1002017 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 16990 Episode / Step: 1002456 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17000 Episode / Step: 1002854 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17010 Episode / Step: 1003322 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17020 Episode / Step: 1003737 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17030 Episode / Step: 1004181 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17040 Episode / Step: 1004601 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17050 Episode / Step: 1005136 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 17060 Episode / Step: 1005683 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 17070 Episode / Step: 1006164 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17080 Episode / Step: 1006634 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17090 Episode / Step: 1007084 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17100 Episode / Step: 1007816 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 17110 Episode / Step: 1008400 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 17120 Episode / Step: 1008904 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17130 Episode / Step: 1009314 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 17140 Episode / Step: 1009855 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000

# %% [markdown]
# ## Test the pretrained model

# %%
load_model = True
train_mode = False

load_model_path = save_model_path

engine_configuration_channel = EngineConfigurationChannel()
environment_parameters_channel = EnvironmentParametersChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel, environment_parameters_channel],
                       base_port=unity_base_port)
env.reset()

# Setup Unity Behavior
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=6.0)
dec, term = env.get_steps(behavior_name)
num_worker = len(dec)

# HyperPPOAgent
agent = HyperPPOAgent()
actor_losses, critic_losses, scores, episode, score = [], [], [], 0, 0
for step in range(test_step):
    goal_signal = dec.obs[GOAL_OBS]
    state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    action = agent.get_action(state, goal_signal, train_mode)
    action_tuple = ActionTuple()
    action_tuple.add_discrete(action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    # info from env
    dec, term = env.get_steps(behavior_name)
    done = [False] * num_worker
    next_goal_signal = dec.obs[GOAL_OBS]
    next_state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    reward = dec.reward
    for id in term.agent_id:
        _id = list(term.agent_id).index(id)
        done[id] = True
        next_goal_signal[id] = term.obs[GOAL_OBS][_id]
        next_state[id] = np.concatenate([term.obs[RAY_OBS][_id], term.obs[VECTOR_OBS][_id]], axis=-1)
        reward[id] = term.reward[_id]
    score += reward[0]

    if done[0]:
        episode +=1
        scores.append(score)
        score = 0

        # logging
        if episode % print_interval == 0:
            mean_score = np.mean(scores)
            mean_actor_loss = np.mean(actor_losses) if len(actor_losses) > 0 else 0
            mean_critic_loss = np.mean(critic_losses)  if len(critic_losses) > 0 else 0
            agent.write_summary(mean_score, mean_actor_loss, mean_critic_loss, step)
            actor_losses, critic_losses, scores = [], [], []

            print(f"{episode} Episode / Step: {step} / Score: {mean_score:.2f} / " +\
                    f"Actor loss: {mean_actor_loss:.2f} / Critic loss: {mean_critic_loss:.4f}" )

env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# ... Load Model from /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155603/TwoMission_HyperPPO.ckpt ...
# 10 Episode / Step: 465 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 20 Episode / Step: 1269 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 30 Episode / Step: 2013 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 40 Episode / Step: 2511 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 50 Episode / Step: 3074 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 60 Episode / Step: 3562 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 70 Episode / Step: 4013 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 80 Episode / Step: 4505 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 90 Episode / Step: 4946 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 100 Episode / Step: 5418 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 110 Episode / Step: 6072 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 120 Episode / Step: 6516 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 130 Episode / Step: 7042 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 140 Episode / Step: 7505 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 150 Episode / Step: 8086 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 160 Episode / Step: 8608 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 170 Episode / Step: 9131 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 180 Episode / Step: 9619 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
