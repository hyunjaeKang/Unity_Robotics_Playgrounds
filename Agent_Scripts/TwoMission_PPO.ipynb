# %% [markdown]
# # TwoMission Hyper PPO

# %%
import os
from pathlib import Path
import numpy as np
import datetime
import platform
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from mlagents_envs.environment import UnityEnvironment, ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel\
                             import EngineConfigurationChannel
from mlagents_envs.side_channel.environment_parameters_channel\
                             import EnvironmentParametersChannel

# %% [markdown]
# ## Setting environments

# %%
# Global Setting
cur_dir = os.getcwd()
env_dir = os.path.abspath(os.path.join(cur_dir, "..", "Unity6000_Envs"))
test_dir = os.path.abspath(os.path.join(cur_dir, "temp", "pytorch_output"))

# %% [markdown]
# ### Pytorch Device

# %%
# Pytorch Device
if torch.backends.mps.is_available():
    g_device = torch.device("mps")
elif torch.cuda.is_available():
    g_device = torch.device("cuda")
else:
    g_device = torch.device("cpu")

print(g_device)
# Out:
# mps

# %% [markdown]
# ### Unity Enviroment

# %%
# Unity Enviroment
game = "TwoMissions"
os_name = platform.system()

if os_name == 'Linux':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.x86_64")
elif os_name == 'Darwin':
    env_name = os.path.join(env_dir, f"{game}_{os_name}.app")

# %% [markdown]
# ### Seting parameters

# %%
# Parameters
state_size = 127 # Ray(19 * 6 = 114) & position(3) & rotation(4) & velocity(3) & ball velocity(3)
action_size = 4 # Rotate(2) & Move(2)
goal_size = 2 # goal_signal

GOAL_OBS = 0
RAY_OBS = 1
VECTOR_OBS = 2

load_model = False
train_mode = True

discount_factor = 0.99
learning_rate = 3e-4
n_step = 2560
batch_size = 256
n_epoch = 3
_lambda = 0.95
epsilon = 0.2

run_step = 1000000 if train_mode else 0
test_step = 10000

print_interval = 10
save_interval = 100


unity_base_port = 1597

# %%
# NN model : Save and Load
date_time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
save_path = os.path.join(test_dir, f"saved_models/{game}/Hyper_PPO/{date_time}")
Path(save_path).mkdir(parents=True, exist_ok=True)
save_model_path = os.path.join(save_path, 'TwoMission_HyperPPO.ckpt')
# print(f"save_path :{save_path}")
# print(f"save_model_path :{save_model_path}")
load_model_path = "" # Need to update

# %% [markdown]
# ## HyperNetwork

# %%
# class HyperNetwork(torch.nn.Module):
#     def __init__(self, input_unit_size, action_size, hyper_input_size, **kwargs):
#         super(HyperNetwork, self).__init__(**kwargs)
#         self.input_unit_size = input_unit_size
#         self.action_size = action_size
#         self.hyper_input_size = hyper_input_size

#         self.d1 = torch.nn.Linear(self.hyper_input_size, 256)
#         self.d2 = torch.nn.Linear(256, 256)
#         self.pi = torch.nn.Linear(256, self.input_unit_size * self.action_size)
#         self.v = torch.nn.Linear(256, self.input_unit_size)

#     def forward(self, x, h):
#         h = F.relu(self.d1(h))
#         h = F.relu(self.d2(h))
#         target_weights_pi = F.tanh(self.pi(h))
#         target_weights_v = F.tanh(self.v(h))

#         x = x.unsqueeze(dim=1)
#         target_weights_pi = target_weights_pi.view(-1, self.input_unit_size, self.action_size)
#         result_pi = torch.bmm(x, target_weights_pi)
#         result_pi = result_pi.squeeze(dim = 1)
#         target_weights_v = target_weights_v.view(-1, self.input_unit_size, 1)
#         result_v = torch.bmm(x, target_weights_v)

#         return F.softmax(result_pi, dim=1), result_v.squeeze(dim=1)

# %% [markdown]
# ## ActorCritic Network

# %%
class ActorCritic(torch.nn.Module):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.d1 = torch.nn.Linear(state_size+2, 256)
        self.d2 = torch.nn.Linear(256, 256)
        self.pi = torch.nn.Linear(256, action_size)
        self.v = torch.nn.Linear(256, 1)

    def forward(self, x, h):
        x = torch.concat([x, h], dim = 1)
        x = F.relu(self.d1(x))
        x = F.relu(self.d2(x))
        return F.softmax(self.pi(x), dim=-1), self.v(x)

# %% [markdown]
# ## Agent class

# %%
# Agent Class
class HyperPPOAgent:
    def __init__(self):
        self.network = ActorCritic().to(g_device)
        self.optimizer = torch.optim.Adam(self.network.parameters(), lr=learning_rate)
        self.memory = list()
        self.writer = SummaryWriter(save_path)

        if load_model == True:
            print(f"... Load Model from {load_model_path} ...")
            checkpoint = torch.load(load_model_path, map_location=g_device)
            self.network.load_state_dict(checkpoint["network"])
            self.optimizer.load_state_dict(checkpoint["optimizer"])

    # get action
    def get_action(self, state, goal_signal, training=True):
        self.network.train(training)

        pi, _ = self.network(torch.FloatTensor(state).to(g_device), torch.FloatTensor(goal_signal).to(g_device))
        action = torch.multinomial(pi, num_samples=1).cpu().numpy()
        return action

    # Add replay memory
    def append_sample(self, state, goal_signal, action, reward, next_state, next_goal_signal, done):
        self.memory.append((state, goal_signal, action, reward, next_state, next_goal_signal, done))

    # training
    def train_model(self):
        self.network.train()

        state      = np.stack([m[0] for m in self.memory], axis=0)
        goal_signal= np.stack([m[1] for m in self.memory], axis=0)
        action     = np.stack([m[2] for m in self.memory], axis=0)
        reward     = np.stack([m[3] for m in self.memory], axis=0)
        next_state = np.stack([m[4] for m in self.memory], axis=0)
        next_goal_signal = np.stack([m[5] for m in self.memory], axis=0)
        done       = np.stack([m[6] for m in self.memory], axis=0)
        self.memory.clear()

        state, goal_signal, action, reward, next_state, next_goal_signal, done = map(lambda x: torch.FloatTensor(x).to(g_device),
                                                        [state, goal_signal, action, reward, next_state, next_goal_signal, done])
        # prob_old, adv, ret
        with torch.no_grad():
            pi_old, value = self.network(state, goal_signal)
            prob_old = pi_old.gather(1, action.long())

            _, next_value = self.network(next_state, next_goal_signal)
            delta = reward + (1 - done) * discount_factor * next_value - value
            adv = delta.clone()
            adv, done = map(lambda x: x.view(n_step, -1).transpose(0,1).contiguous(), [adv, done])
            for t in reversed(range(n_step-1)):
                adv[:, t] += (1 - done[:, t]) * discount_factor * _lambda * adv[:, t+1]
            adv = adv.transpose(0,1).contiguous().view(-1, 1)

            ret = adv + value

        # training loop
        actor_losses, critic_losses = [], []
        idxs = np.arange(len(reward))
        for _ in range(n_epoch):
            np.random.shuffle(idxs)
            for offset in range(0, len(reward), batch_size):
                idx = idxs[offset : offset + batch_size]

                _state, _goal_signal, _action, _ret, _adv, _prob_old =\
                    map(lambda x: x[idx], [state, goal_signal, action, ret, adv, prob_old])

                pi, value = self.network(_state, _goal_signal)
                prob = pi.gather(1, _action.long())

                # loss function for policy function
                ratio = prob / (_prob_old + 1e-7)
                surr1 = ratio * _adv
                surr2 = torch.clamp(ratio, min=1-epsilon, max=1+epsilon) * _adv
                actor_loss = -torch.min(surr1, surr2).mean()

                # loss function for value function
                critic_loss = F.mse_loss(value, _ret).mean()

                total_loss = actor_loss + critic_loss

                self.optimizer.zero_grad()
                total_loss.backward()
                self.optimizer.step()

                actor_losses.append(actor_loss.item())
                critic_losses.append(critic_loss.item())

        return np.mean(actor_losses), np.mean(critic_losses)

    # save model
    def save_model(self):
        print(f"... Save Model to {save_model_path} ...")
        torch.save({
            "network" : self.network.state_dict(),
            "optimizer" : self.optimizer.state_dict(),
        }, save_model_path)

    # logging
    def write_summary(self, score, actor_loss, critic_loss, step):
        self.writer.add_scalar("HyperPPOAgent_run/score", score, step)
        self.writer.add_scalar("HyperPPOAgent_model/actor_loss", actor_loss, step)
        self.writer.add_scalar("HyperPPOAgent_model/critic_loss", critic_loss, step)

# %% [markdown]
# ## Train Model

# %%
env.close()

# %%
engine_configuration_channel = EngineConfigurationChannel()
environment_parameters_channel = EnvironmentParametersChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel, environment_parameters_channel],
                       base_port=unity_base_port)
env.reset()

# Setup Unity Behavior
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=6.0)
dec, term = env.get_steps(behavior_name)
num_worker = len(dec)

# HyperPPOAgent
agent = HyperPPOAgent()
actor_losses, critic_losses, scores, episode, score = [], [], [], 0, 0
for step in range(run_step + test_step):
    if step == run_step:
        if train_mode:
            agent.save_model()
        print("TEST START")
        train_mode = False
        engine_configuration_channel.set_configuration_parameters(time_scale=1.0)

    goal_signal = dec.obs[GOAL_OBS]
    state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    action = agent.get_action(state, goal_signal, train_mode)
    action_tuple = ActionTuple()
    action_tuple.add_discrete(action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    # info from env
    dec, term = env.get_steps(behavior_name)
    done = [False] * num_worker
    next_goal_signal = dec.obs[GOAL_OBS]
    next_state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    reward = dec.reward
    for id in term.agent_id:
        _id = list(term.agent_id).index(id)
        done[id] = True
        next_goal_signal[id] = term.obs[GOAL_OBS][_id]
        next_state[id] = np.concatenate([term.obs[RAY_OBS][_id], term.obs[VECTOR_OBS][_id]], axis=-1)
        reward[id] = term.reward[_id]
    score += reward[0]

    if train_mode:
        for id in range(num_worker):
            agent.append_sample(state[id], goal_signal[id], action[id], [reward[id]], next_state[id], next_goal_signal[id], [done[id]])
        # training
        if (step+1) % n_step == 0:
            actor_loss, critic_loss = agent.train_model()
            actor_losses.append(actor_loss)
            critic_losses.append(critic_loss)

    if done[0]:
        episode +=1
        scores.append(score)
        score = 0

        # logging
        if episode % print_interval == 0:
            mean_score = np.mean(scores)
            mean_actor_loss = np.mean(actor_losses) if len(actor_losses) > 0 else 0
            mean_critic_loss = np.mean(critic_losses)  if len(critic_losses) > 0 else 0
            agent.write_summary(mean_score, mean_actor_loss, mean_critic_loss, step)
            actor_losses, critic_losses, scores = [], [], []

            print(f"{episode} Episode / Step: {step} / Score: {mean_score:.2f} / " +\
                    f"Actor loss: {mean_actor_loss:.2f} / Critic loss: {mean_critic_loss:.4f}" )

        # save model
        if train_mode and episode % save_interval == 0:
            agent.save_model()
env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# 10 Episode / Step: 9999 / Score: -0.50 / Actor loss: 0.02 / Critic loss: 0.0007
# 20 Episode / Step: 17359 / Score: -0.07 / Actor loss: 0.01 / Critic loss: 0.0006
# 30 Episode / Step: 24159 / Score: -0.04 / Actor loss: 0.01 / Critic loss: 0.0005
# 40 Episode / Step: 30928 / Score: -0.04 / Actor loss: 0.00 / Critic loss: 0.0006
# 50 Episode / Step: 39344 / Score: -0.22 / Actor loss: 0.00 / Critic loss: 0.0004
# 60 Episode / Step: 46081 / Score: 0.06 / Actor loss: -0.00 / Critic loss: 0.0007
# 70 Episode / Step: 51287 / Score: 0.24 / Actor loss: -0.00 / Critic loss: 0.0009
# 80 Episode / Step: 59395 / Score: -0.21 / Actor loss: 0.00 / Critic loss: 0.0007
# 90 Episode / Step: 67842 / Score: -0.22 / Actor loss: 0.00 / Critic loss: 0.0004
# 100 Episode / Step: 75152 / Score: -0.07 / Actor loss: 0.00 / Critic loss: 0.0006
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 110 Episode / Step: 83068 / Score: -0.30 / Actor loss: 0.00 / Critic loss: 0.0006
# 120 Episode / Step: 88203 / Score: 0.14 / Actor loss: 0.00 / Critic loss: 0.0010
# 130 Episode / Step: 95357 / Score: -0.06 / Actor loss: 0.00 / Critic loss: 0.0006
# 140 Episode / Step: 99811 / Score: 0.38 / Actor loss: -0.00 / Critic loss: 0.0010
# 150 Episode / Step: 104305 / Score: 0.08 / Actor loss: -0.00 / Critic loss: 0.0008
# 160 Episode / Step: 109616 / Score: 0.23 / Actor loss: 0.00 / Critic loss: 0.0005
# 170 Episode / Step: 113914 / Score: 0.39 / Actor loss: -0.00 / Critic loss: 0.0004
# 180 Episode / Step: 121258 / Score: -0.07 / Actor loss: 0.00 / Critic loss: 0.0005
# 190 Episode / Step: 130320 / Score: -0.35 / Actor loss: 0.00 / Critic loss: 0.0005
# 200 Episode / Step: 132648 / Score: 0.68 / Actor loss: 0.00 / Critic loss: 0.0004
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 210 Episode / Step: 137895 / Score: 0.24 / Actor loss: 0.00 / Critic loss: 0.0006
# 220 Episode / Step: 145019 / Score: -0.06 / Actor loss: 0.00 / Critic loss: 0.0006
# 230 Episode / Step: 152151 / Score: -0.06 / Actor loss: 0.01 / Critic loss: 0.0006
# 240 Episode / Step: 158300 / Score: 0.09 / Actor loss: 0.01 / Critic loss: 0.0008
# 250 Episode / Step: 161654 / Score: 0.53 / Actor loss: 0.00 / Critic loss: 0.0006
# 260 Episode / Step: 166895 / Score: 0.24 / Actor loss: 0.00 / Critic loss: 0.0007
# 270 Episode / Step: 175529 / Score: -0.43 / Actor loss: 0.00 / Critic loss: 0.0005
# 280 Episode / Step: 182698 / Score: -0.06 / Actor loss: 0.01 / Critic loss: 0.0008
# 290 Episode / Step: 187219 / Score: 0.37 / Actor loss: 0.00 / Critic loss: 0.0011
# 300 Episode / Step: 192248 / Score: 0.55 / Actor loss: 0.01 / Critic loss: 0.0019
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 310 Episode / Step: 195057 / Score: 0.66 / Actor loss: 0.00 / Critic loss: 0.0018
# 320 Episode / Step: 197938 / Score: 0.66 / Actor loss: 0.01 / Critic loss: 0.0016
# 330 Episode / Step: 203427 / Score: 0.13 / Actor loss: 0.04 / Critic loss: 0.0039
# 340 Episode / Step: 208482 / Score: -0.25 / Actor loss: 0.06 / Critic loss: 0.0059
# 350 Episode / Step: 211667 / Score: 0.44 / Actor loss: 0.07 / Critic loss: 0.0082
# 360 Episode / Step: 213974 / Score: 0.69 / Actor loss: 0.05 / Critic loss: 0.0046
# 370 Episode / Step: 216664 / Score: 0.47 / Actor loss: 0.04 / Critic loss: 0.0030
# 380 Episode / Step: 220213 / Score: 0.12 / Actor loss: 0.04 / Critic loss: 0.0041
# 390 Episode / Step: 225722 / Score: -0.18 / Actor loss: 0.03 / Critic loss: 0.0041
# 400 Episode / Step: 227989 / Score: 0.79 / Actor loss: 0.02 / Critic loss: 0.0021
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 410 Episode / Step: 230684 / Score: 0.67 / Actor loss: 0.01 / Critic loss: 0.0025
# 420 Episode / Step: 233417 / Score: 0.46 / Actor loss: 0.01 / Critic loss: 0.0024
# 430 Episode / Step: 236898 / Score: 0.53 / Actor loss: 0.02 / Critic loss: 0.0031
# 440 Episode / Step: 238770 / Score: 0.41 / Actor loss: 0.01 / Critic loss: 0.0033
# 450 Episode / Step: 239898 / Score: 0.74 / Actor loss: 0.00 / Critic loss: 0.0000
# 460 Episode / Step: 241676 / Score: 0.61 / Actor loss: 0.02 / Critic loss: 0.0065
# 470 Episode / Step: 242388 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 480 Episode / Step: 242930 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 490 Episode / Step: 243869 / Score: 0.95 / Actor loss: 0.01 / Critic loss: 0.0078
# 500 Episode / Step: 245673 / Score: 0.41 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 510 Episode / Step: 246525 / Score: 0.56 / Actor loss: 0.01 / Critic loss: 0.0097
# 520 Episode / Step: 247566 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 530 Episode / Step: 248412 / Score: 0.76 / Actor loss: 0.01 / Critic loss: 0.0099
# 540 Episode / Step: 248996 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 550 Episode / Step: 250543 / Score: 0.62 / Actor loss: 0.00 / Critic loss: 0.0000
# 560 Episode / Step: 252135 / Score: 0.82 / Actor loss: -0.00 / Critic loss: 0.0049
# 570 Episode / Step: 252676 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 580 Episode / Step: 254529 / Score: 0.81 / Actor loss: 0.00 / Critic loss: 0.0028
# 590 Episode / Step: 255137 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 600 Episode / Step: 255724 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 610 Episode / Step: 256466 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0048
# 620 Episode / Step: 257065 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 630 Episode / Step: 257755 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 640 Episode / Step: 258392 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 650 Episode / Step: 259110 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0056
# 660 Episode / Step: 259638 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 670 Episode / Step: 260495 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 680 Episode / Step: 261150 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0054
# 690 Episode / Step: 261729 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 700 Episode / Step: 262358 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 710 Episode / Step: 264014 / Score: 0.62 / Actor loss: 0.01 / Critic loss: 0.0069
# 720 Episode / Step: 265116 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 730 Episode / Step: 265717 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 740 Episode / Step: 266408 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0059
# 750 Episode / Step: 267188 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 760 Episode / Step: 267882 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 770 Episode / Step: 268681 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 780 Episode / Step: 269303 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0093
# 790 Episode / Step: 270274 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 800 Episode / Step: 271103 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 810 Episode / Step: 271703 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0087
# 820 Episode / Step: 272415 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 830 Episode / Step: 274033 / Score: 0.62 / Actor loss: -0.00 / Critic loss: 0.0091
# 840 Episode / Step: 274852 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 850 Episode / Step: 275908 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 860 Episode / Step: 276528 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0080
# 870 Episode / Step: 277191 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 880 Episode / Step: 278214 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 890 Episode / Step: 278811 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 900 Episode / Step: 279665 / Score: 0.76 / Actor loss: 0.01 / Critic loss: 0.0080
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 910 Episode / Step: 280224 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 920 Episode / Step: 281064 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 930 Episode / Step: 281613 / Score: 0.97 / Actor loss: -0.01 / Critic loss: 0.0067
# 940 Episode / Step: 282259 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 950 Episode / Step: 282822 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 960 Episode / Step: 283785 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 970 Episode / Step: 284336 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0090
# 980 Episode / Step: 284896 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 990 Episode / Step: 285708 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1000 Episode / Step: 286394 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1010 Episode / Step: 286844 / Score: 0.98 / Actor loss: -0.01 / Critic loss: 0.0046
# 1020 Episode / Step: 287310 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1030 Episode / Step: 287823 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1040 Episode / Step: 288379 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1050 Episode / Step: 288971 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1060 Episode / Step: 289538 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0060
# 1070 Episode / Step: 290174 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1080 Episode / Step: 290785 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1090 Episode / Step: 291373 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1100 Episode / Step: 292895 / Score: 0.92 / Actor loss: -0.00 / Critic loss: 0.0055
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1110 Episode / Step: 293652 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1120 Episode / Step: 294627 / Score: 0.75 / Actor loss: 0.01 / Critic loss: 0.0058
# 1130 Episode / Step: 295196 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1140 Episode / Step: 295907 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1150 Episode / Step: 296558 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 1160 Episode / Step: 297230 / Score: 0.57 / Actor loss: 0.01 / Critic loss: 0.0101
# 1170 Episode / Step: 298227 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 1180 Episode / Step: 299080 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 1190 Episode / Step: 299694 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0077
# 1200 Episode / Step: 300291 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1210 Episode / Step: 300893 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1220 Episode / Step: 301635 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 1230 Episode / Step: 302311 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0096
# 1240 Episode / Step: 302907 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1250 Episode / Step: 303535 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1260 Episode / Step: 303996 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1270 Episode / Step: 304629 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1280 Episode / Step: 305246 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0068
# 1290 Episode / Step: 305838 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1300 Episode / Step: 306493 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1310 Episode / Step: 307082 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1320 Episode / Step: 307973 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0052
# 1330 Episode / Step: 308532 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1340 Episode / Step: 309115 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1350 Episode / Step: 309771 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0045
# 1360 Episode / Step: 310455 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1370 Episode / Step: 310967 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1380 Episode / Step: 311637 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1390 Episode / Step: 312154 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1400 Episode / Step: 312987 / Score: 0.56 / Actor loss: 0.00 / Critic loss: 0.0050
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1410 Episode / Step: 313680 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1420 Episode / Step: 314363 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1430 Episode / Step: 314832 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1440 Episode / Step: 315518 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0061
# 1450 Episode / Step: 316083 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1460 Episode / Step: 316721 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1470 Episode / Step: 317257 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1480 Episode / Step: 317717 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0061
# 1490 Episode / Step: 318212 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1500 Episode / Step: 318717 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1510 Episode / Step: 319234 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1520 Episode / Step: 320067 / Score: 0.96 / Actor loss: 0.02 / Critic loss: 0.0059
# 1530 Episode / Step: 320618 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1540 Episode / Step: 321178 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1550 Episode / Step: 322144 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 1560 Episode / Step: 322812 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0055
# 1570 Episode / Step: 323533 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 1580 Episode / Step: 324211 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1590 Episode / Step: 324746 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1600 Episode / Step: 325490 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0048
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1610 Episode / Step: 326012 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1620 Episode / Step: 326601 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1630 Episode / Step: 327556 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 1640 Episode / Step: 328119 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0059
# 1650 Episode / Step: 328853 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 1660 Episode / Step: 329462 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1670 Episode / Step: 330032 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1680 Episode / Step: 330659 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0056
# 1690 Episode / Step: 331271 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1700 Episode / Step: 331922 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1710 Episode / Step: 332457 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1720 Episode / Step: 333042 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0068
# 1730 Episode / Step: 333673 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1740 Episode / Step: 335241 / Score: 0.82 / Actor loss: 0.00 / Critic loss: 0.0000
# 1750 Episode / Step: 335757 / Score: 0.77 / Actor loss: -0.01 / Critic loss: 0.0034
# 1760 Episode / Step: 336361 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1770 Episode / Step: 336997 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1780 Episode / Step: 337490 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1790 Episode / Step: 338037 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0038
# 1800 Episode / Step: 338592 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1810 Episode / Step: 339098 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1820 Episode / Step: 339595 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 1830 Episode / Step: 340242 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1840 Episode / Step: 340859 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0056
# 1850 Episode / Step: 341439 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1860 Episode / Step: 341926 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1870 Episode / Step: 342435 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1880 Episode / Step: 342999 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 1890 Episode / Step: 343573 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0044
# 1900 Episode / Step: 344770 / Score: 0.54 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 1910 Episode / Step: 345280 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1920 Episode / Step: 345850 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0048
# 1930 Episode / Step: 346327 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 1940 Episode / Step: 346926 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1950 Episode / Step: 347373 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1960 Episode / Step: 347873 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 1970 Episode / Step: 348488 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0046
# 1980 Episode / Step: 349089 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 1990 Episode / Step: 349639 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2000 Episode / Step: 350243 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2010 Episode / Step: 350757 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0039
# 2020 Episode / Step: 351495 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 2030 Episode / Step: 352027 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2040 Episode / Step: 352599 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2050 Episode / Step: 353195 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2060 Episode / Step: 354630 / Score: 0.83 / Actor loss: 0.00 / Critic loss: 0.0030
# 2070 Episode / Step: 355214 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2080 Episode / Step: 355765 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2090 Episode / Step: 356348 / Score: 0.97 / Actor loss: 0.02 / Critic loss: 0.0058
# 2100 Episode / Step: 357115 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2110 Episode / Step: 358593 / Score: 0.93 / Actor loss: 0.01 / Critic loss: 0.0064
# 2120 Episode / Step: 359146 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2130 Episode / Step: 359747 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2140 Episode / Step: 360361 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2150 Episode / Step: 360903 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2160 Episode / Step: 361402 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0072
# 2170 Episode / Step: 361959 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2180 Episode / Step: 362597 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2190 Episode / Step: 363107 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2200 Episode / Step: 363666 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0077
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2210 Episode / Step: 364418 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 2220 Episode / Step: 364959 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2230 Episode / Step: 365490 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2240 Episode / Step: 366091 / Score: 0.57 / Actor loss: 0.01 / Critic loss: 0.0072
# 2250 Episode / Step: 366666 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2260 Episode / Step: 367473 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 2270 Episode / Step: 368149 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2280 Episode / Step: 368703 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0051
# 2290 Episode / Step: 369241 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2300 Episode / Step: 369781 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2310 Episode / Step: 370362 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2320 Episode / Step: 370974 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2330 Episode / Step: 371448 / Score: 0.98 / Actor loss: -0.01 / Critic loss: 0.0049
# 2340 Episode / Step: 371956 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2350 Episode / Step: 372569 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2360 Episode / Step: 373188 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2370 Episode / Step: 373678 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2380 Episode / Step: 374394 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0041
# 2390 Episode / Step: 375859 / Score: 0.83 / Actor loss: 0.00 / Critic loss: 0.0000
# 2400 Episode / Step: 376320 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0057
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2410 Episode / Step: 377522 / Score: 0.94 / Actor loss: 0.00 / Critic loss: 0.0000
# 2420 Episode / Step: 378183 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 2430 Episode / Step: 378952 / Score: 0.56 / Actor loss: 0.01 / Critic loss: 0.0059
# 2440 Episode / Step: 379461 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2450 Episode / Step: 379996 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2460 Episode / Step: 380439 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 2470 Episode / Step: 381074 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 2480 Episode / Step: 381540 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0048
# 2490 Episode / Step: 382044 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2500 Episode / Step: 382532 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2510 Episode / Step: 383096 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2520 Episode / Step: 383754 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2530 Episode / Step: 384310 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0037
# 2540 Episode / Step: 384861 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2550 Episode / Step: 385611 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 2560 Episode / Step: 386272 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2570 Episode / Step: 387229 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0053
# 2580 Episode / Step: 387846 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2590 Episode / Step: 388393 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2600 Episode / Step: 388934 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2610 Episode / Step: 389493 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0080
# 2620 Episode / Step: 390215 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 2630 Episode / Step: 390740 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2640 Episode / Step: 391367 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2650 Episode / Step: 391981 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0032
# 2660 Episode / Step: 392583 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2670 Episode / Step: 393173 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2680 Episode / Step: 393747 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2690 Episode / Step: 394248 / Score: 0.98 / Actor loss: -0.00 / Critic loss: 0.0037
# 2700 Episode / Step: 394940 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2710 Episode / Step: 395561 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2720 Episode / Step: 396155 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2730 Episode / Step: 396810 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0060
# 2740 Episode / Step: 397340 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2750 Episode / Step: 397920 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2760 Episode / Step: 398489 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2770 Episode / Step: 399130 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2780 Episode / Step: 399807 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0051
# 2790 Episode / Step: 400327 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2800 Episode / Step: 400866 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2810 Episode / Step: 401484 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2820 Episode / Step: 402060 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0070
# 2830 Episode / Step: 402587 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2840 Episode / Step: 403185 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2850 Episode / Step: 404045 / Score: 0.56 / Actor loss: 0.00 / Critic loss: 0.0000
# 2860 Episode / Step: 404626 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0040
# 2870 Episode / Step: 405205 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2880 Episode / Step: 405794 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2890 Episode / Step: 406259 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 2900 Episode / Step: 406838 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 2910 Episode / Step: 407403 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0047
# 2920 Episode / Step: 407984 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2930 Episode / Step: 408512 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2940 Episode / Step: 409096 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 2950 Episode / Step: 409755 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0063
# 2960 Episode / Step: 410372 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2970 Episode / Step: 411060 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2980 Episode / Step: 411620 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 2990 Episode / Step: 412208 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0033
# 3000 Episode / Step: 412731 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3010 Episode / Step: 413544 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 3020 Episode / Step: 414123 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3030 Episode / Step: 414776 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0031
# 3040 Episode / Step: 415424 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3050 Episode / Step: 415985 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3060 Episode / Step: 416530 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3070 Episode / Step: 417245 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 3080 Episode / Step: 417770 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0045
# 3090 Episode / Step: 418398 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3100 Episode / Step: 419031 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3110 Episode / Step: 419464 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3120 Episode / Step: 420067 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0045
# 3130 Episode / Step: 420656 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3140 Episode / Step: 421321 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3150 Episode / Step: 422119 / Score: 0.76 / Actor loss: 0.00 / Critic loss: 0.0000
# 3160 Episode / Step: 422876 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0048
# 3170 Episode / Step: 423375 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3180 Episode / Step: 423905 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3190 Episode / Step: 424564 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3200 Episode / Step: 425425 / Score: 0.76 / Actor loss: -0.01 / Critic loss: 0.0019
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3210 Episode / Step: 426024 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3220 Episode / Step: 426656 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3230 Episode / Step: 427168 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3240 Episode / Step: 427703 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0037
# 3250 Episode / Step: 428344 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3260 Episode / Step: 428877 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3270 Episode / Step: 429425 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3280 Episode / Step: 430028 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3290 Episode / Step: 430487 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0031
# 3300 Episode / Step: 430979 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3310 Episode / Step: 431437 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3320 Episode / Step: 431911 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 3330 Episode / Step: 432468 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3340 Episode / Step: 433140 / Score: 0.97 / Actor loss: 0.02 / Critic loss: 0.0035
# 3350 Episode / Step: 433657 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3360 Episode / Step: 434115 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3370 Episode / Step: 434653 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3380 Episode / Step: 435321 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0056
# 3390 Episode / Step: 435904 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3400 Episode / Step: 436504 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3410 Episode / Step: 437116 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3420 Episode / Step: 437782 / Score: 0.57 / Actor loss: 0.01 / Critic loss: 0.0040
# 3430 Episode / Step: 438322 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3440 Episode / Step: 438808 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3450 Episode / Step: 439419 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3460 Episode / Step: 439954 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3470 Episode / Step: 440540 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0032
# 3480 Episode / Step: 441126 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3490 Episode / Step: 441808 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 3500 Episode / Step: 442244 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3510 Episode / Step: 442940 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0053
# 3520 Episode / Step: 443403 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 3530 Episode / Step: 443869 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3540 Episode / Step: 444453 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 3550 Episode / Step: 444961 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3560 Episode / Step: 445382 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3570 Episode / Step: 445928 / Score: 0.97 / Actor loss: 0.02 / Critic loss: 0.0073
# 3580 Episode / Step: 446572 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3590 Episode / Step: 447102 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 3600 Episode / Step: 447666 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3610 Episode / Step: 448286 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0046
# 3620 Episode / Step: 448913 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3630 Episode / Step: 449466 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3640 Episode / Step: 449938 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3650 Episode / Step: 450514 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3660 Episode / Step: 450986 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0066
# 3670 Episode / Step: 451525 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3680 Episode / Step: 452021 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 3690 Episode / Step: 452576 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3700 Episode / Step: 453186 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0064
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3710 Episode / Step: 453741 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3720 Episode / Step: 454425 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3730 Episode / Step: 454904 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3740 Episode / Step: 455399 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3750 Episode / Step: 455984 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0047
# 3760 Episode / Step: 456680 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3770 Episode / Step: 457539 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 3780 Episode / Step: 458245 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0031
# 3790 Episode / Step: 458805 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3800 Episode / Step: 459339 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3810 Episode / Step: 459842 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3820 Episode / Step: 460313 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 3830 Episode / Step: 460828 / Score: 0.97 / Actor loss: -0.01 / Critic loss: 0.0036
# 3840 Episode / Step: 461474 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3850 Episode / Step: 461985 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3860 Episode / Step: 462541 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3870 Episode / Step: 463096 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3880 Episode / Step: 463627 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0052
# 3890 Episode / Step: 464207 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3900 Episode / Step: 464798 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 3910 Episode / Step: 465422 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3920 Episode / Step: 466008 / Score: 0.97 / Actor loss: 0.02 / Critic loss: 0.0057
# 3930 Episode / Step: 466647 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3940 Episode / Step: 467210 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3950 Episode / Step: 467733 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3960 Episode / Step: 468271 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 3970 Episode / Step: 468912 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0054
# 3980 Episode / Step: 469512 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 3990 Episode / Step: 470014 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 4000 Episode / Step: 470570 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 4010 Episode / Step: 471199 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0058
# 4020 Episode / Step: 471858 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4030 Episode / Step: 472369 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4040 Episode / Step: 472926 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4050 Episode / Step: 473434 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4060 Episode / Step: 473963 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0045
# 4070 Episode / Step: 474657 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4080 Episode / Step: 475188 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4090 Episode / Step: 475702 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4100 Episode / Step: 476287 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0038
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 4110 Episode / Step: 477813 / Score: 0.62 / Actor loss: 0.00 / Critic loss: 0.0000
# 4120 Episode / Step: 478389 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4130 Episode / Step: 478887 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0045
# 4140 Episode / Step: 479474 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4150 Episode / Step: 480032 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4160 Episode / Step: 480520 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4170 Episode / Step: 481397 / Score: 0.96 / Actor loss: 0.01 / Critic loss: 0.0026
# 4180 Episode / Step: 481876 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4190 Episode / Step: 482565 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4200 Episode / Step: 483989 / Score: 0.83 / Actor loss: 0.01 / Critic loss: 0.0042
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 4210 Episode / Step: 484557 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4220 Episode / Step: 485152 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4230 Episode / Step: 485744 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4240 Episode / Step: 486236 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4250 Episode / Step: 486723 / Score: 0.78 / Actor loss: 0.02 / Critic loss: 0.0058
# 4260 Episode / Step: 487201 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 4270 Episode / Step: 487812 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4280 Episode / Step: 488362 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4290 Episode / Step: 489847 / Score: 0.63 / Actor loss: 0.01 / Critic loss: 0.0034
# 4300 Episode / Step: 490336 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 4310 Episode / Step: 490937 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4320 Episode / Step: 491422 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4330 Episode / Step: 491906 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0056
# 4340 Episode / Step: 492394 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4350 Episode / Step: 493449 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0000
# 4360 Episode / Step: 493891 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 4370 Episode / Step: 495290 / Score: 0.93 / Actor loss: 0.00 / Critic loss: 0.0042
# 4380 Episode / Step: 495815 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4390 Episode / Step: 496351 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4400 Episode / Step: 496916 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0066
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 4410 Episode / Step: 497458 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4420 Episode / Step: 498054 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4430 Episode / Step: 498659 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4440 Episode / Step: 499239 / Score: 0.97 / Actor loss: -0.00 / Critic loss: 0.0048
# 4450 Episode / Step: 500068 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 4460 Episode / Step: 500655 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 4470 Episode / Step: 501208 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 4480 Episode / Step: 501815 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0045
# ...
# 12700 Episode / Step: 928917 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 12710 Episode / Step: 929420 / Score: 0.98 / Actor loss: -0.00 / Critic loss: 0.0046
# 12720 Episode / Step: 930498 / Score: 0.75 / Actor loss: 0.00 / Critic loss: 0.0000
# 12730 Episode / Step: 931044 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 12740 Episode / Step: 931674 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 12750 Episode / Step: 932181 / Score: 0.78 / Actor loss: 0.01 / Critic loss: 0.0048
# 12760 Episode / Step: 932689 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 12770 Episode / Step: 933113 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12780 Episode / Step: 933573 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12790 Episode / Step: 934082 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12800 Episode / Step: 934496 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0074
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 12810 Episode / Step: 935043 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 12820 Episode / Step: 935595 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 12830 Episode / Step: 936023 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12840 Episode / Step: 936407 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12850 Episode / Step: 936815 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12860 Episode / Step: 937431 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0040
# 12870 Episode / Step: 937869 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12880 Episode / Step: 938464 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 12890 Episode / Step: 939105 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 12900 Episode / Step: 939680 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0049
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 12910 Episode / Step: 940218 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 12920 Episode / Step: 940728 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 12930 Episode / Step: 941263 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 12940 Episode / Step: 941717 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12950 Episode / Step: 942198 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0059
# 12960 Episode / Step: 942725 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 12970 Episode / Step: 943159 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12980 Episode / Step: 943666 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 12990 Episode / Step: 944197 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13000 Episode / Step: 944672 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0032
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13010 Episode / Step: 945107 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13020 Episode / Step: 945613 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13030 Episode / Step: 945998 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13040 Episode / Step: 946479 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13050 Episode / Step: 946942 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13060 Episode / Step: 947346 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0028
# 13070 Episode / Step: 947834 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13080 Episode / Step: 948403 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13090 Episode / Step: 948930 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13100 Episode / Step: 949460 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13110 Episode / Step: 949869 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0043
# 13120 Episode / Step: 950424 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13130 Episode / Step: 951098 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13140 Episode / Step: 951972 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 13150 Episode / Step: 952546 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0043
# 13160 Episode / Step: 953032 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13170 Episode / Step: 953463 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13180 Episode / Step: 953940 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13190 Episode / Step: 954399 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13200 Episode / Step: 955844 / Score: 0.83 / Actor loss: 0.00 / Critic loss: 0.0027
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13210 Episode / Step: 956303 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13220 Episode / Step: 956819 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 13230 Episode / Step: 957262 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13240 Episode / Step: 957730 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0030
# 13250 Episode / Step: 958142 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13260 Episode / Step: 958573 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13270 Episode / Step: 958984 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13280 Episode / Step: 959441 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13290 Episode / Step: 959911 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13300 Episode / Step: 961035 / Score: 0.74 / Actor loss: 0.01 / Critic loss: 0.0048
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13310 Episode / Step: 961791 / Score: 0.96 / Actor loss: 0.00 / Critic loss: 0.0000
# 13320 Episode / Step: 962281 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13330 Episode / Step: 962724 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0056
# 13340 Episode / Step: 963112 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13350 Episode / Step: 963531 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13360 Episode / Step: 964007 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13370 Episode / Step: 964377 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13380 Episode / Step: 964888 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 13390 Episode / Step: 965361 / Score: 0.58 / Actor loss: 0.00 / Critic loss: 0.0041
# 13400 Episode / Step: 965816 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13410 Episode / Step: 966332 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13420 Episode / Step: 966754 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13430 Episode / Step: 967204 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13440 Episode / Step: 968055 / Score: 0.96 / Actor loss: 0.01 / Critic loss: 0.0045
# 13450 Episode / Step: 968632 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13460 Episode / Step: 969064 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13470 Episode / Step: 969651 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13480 Episode / Step: 970144 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13490 Episode / Step: 970550 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0040
# 13500 Episode / Step: 970972 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13510 Episode / Step: 971610 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13520 Episode / Step: 973532 / Score: 0.80 / Actor loss: 0.01 / Critic loss: 0.0048
# 13530 Episode / Step: 974026 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13540 Episode / Step: 974618 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 13550 Episode / Step: 975006 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13560 Episode / Step: 975725 / Score: 0.96 / Actor loss: 0.01 / Critic loss: 0.0044
# 13570 Episode / Step: 976169 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13580 Episode / Step: 976678 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 13590 Episode / Step: 977130 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 13600 Episode / Step: 977671 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13610 Episode / Step: 978220 / Score: 0.77 / Actor loss: 0.01 / Critic loss: 0.0060
# 13620 Episode / Step: 978626 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13630 Episode / Step: 979089 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13640 Episode / Step: 979626 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13650 Episode / Step: 980084 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13660 Episode / Step: 980704 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0030
# 13670 Episode / Step: 981262 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13680 Episode / Step: 981755 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13690 Episode / Step: 982192 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13700 Episode / Step: 982651 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13710 Episode / Step: 983107 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0046
# 13720 Episode / Step: 983495 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13730 Episode / Step: 983968 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13740 Episode / Step: 984417 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13750 Episode / Step: 984929 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13760 Episode / Step: 985364 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13770 Episode / Step: 985895 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0033
# 13780 Episode / Step: 986335 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13790 Episode / Step: 986979 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13800 Episode / Step: 987403 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13810 Episode / Step: 987840 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13820 Episode / Step: 988879 / Score: 0.95 / Actor loss: 0.00 / Critic loss: 0.0040
# 13830 Episode / Step: 989336 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13840 Episode / Step: 989977 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13850 Episode / Step: 990415 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13860 Episode / Step: 990887 / Score: 0.78 / Actor loss: 0.01 / Critic loss: 0.0055
# 13870 Episode / Step: 991391 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13880 Episode / Step: 991919 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 13890 Episode / Step: 992435 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 13900 Episode / Step: 992926 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 13910 Episode / Step: 993350 / Score: 0.98 / Actor loss: 0.01 / Critic loss: 0.0062
# 13920 Episode / Step: 993749 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13930 Episode / Step: 994205 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13940 Episode / Step: 994682 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 13950 Episode / Step: 995343 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13960 Episode / Step: 995904 / Score: 0.97 / Actor loss: 0.01 / Critic loss: 0.0050
# 13970 Episode / Step: 996437 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13980 Episode / Step: 997025 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 13990 Episode / Step: 997469 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14000 Episode / Step: 997985 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 14010 Episode / Step: 999344 / Score: 0.83 / Actor loss: 0.00 / Critic loss: 0.0047
# 14020 Episode / Step: 999825 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# ... Save Model to /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# TEST START
# 14030 Episode / Step: 1000284 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 14040 Episode / Step: 1000771 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14050 Episode / Step: 1001421 / Score: 0.57 / Actor loss: 0.00 / Critic loss: 0.0000
# 14060 Episode / Step: 1001888 / Score: 0.58 / Actor loss: 0.00 / Critic loss: 0.0000
# 14070 Episode / Step: 1002256 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14080 Episode / Step: 1002773 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 14090 Episode / Step: 1003251 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14100 Episode / Step: 1003737 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 14110 Episode / Step: 1004167 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14120 Episode / Step: 1004631 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 14130 Episode / Step: 1005035 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14140 Episode / Step: 1005405 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14150 Episode / Step: 1005881 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14160 Episode / Step: 1007331 / Score: 0.83 / Actor loss: 0.00 / Critic loss: 0.0000
# 14170 Episode / Step: 1007796 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14180 Episode / Step: 1008252 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14190 Episode / Step: 1008723 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 14200 Episode / Step: 1009179 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 14210 Episode / Step: 1009651 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000

# %% [markdown]
# ## Test the pretrained model

# %%
load_model = True
train_mode = False

load_model_path = save_model_path

engine_configuration_channel = EngineConfigurationChannel()
environment_parameters_channel = EnvironmentParametersChannel()
env = UnityEnvironment(file_name=env_name,
                       side_channels=[engine_configuration_channel, environment_parameters_channel],
                       base_port=unity_base_port)
env.reset()

# Setup Unity Behavior
behavior_name = list(env.behavior_specs.keys())[0]
spec = env.behavior_specs[behavior_name]
engine_configuration_channel.set_configuration_parameters(time_scale=6.0)
dec, term = env.get_steps(behavior_name)
num_worker = len(dec)

# HyperPPOAgent
agent = HyperPPOAgent()
actor_losses, critic_losses, scores, episode, score = [], [], [], 0, 0
for step in range(test_step):
    goal_signal = dec.obs[GOAL_OBS]
    state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    action = agent.get_action(state, goal_signal, train_mode)
    action_tuple = ActionTuple()
    action_tuple.add_discrete(action)
    env.set_actions(behavior_name, action_tuple)
    env.step()

    # info from env
    dec, term = env.get_steps(behavior_name)
    done = [False] * num_worker
    next_goal_signal = dec.obs[GOAL_OBS]
    next_state = np.concatenate([dec.obs[RAY_OBS], dec.obs[VECTOR_OBS]], axis=-1)
    reward = dec.reward
    for id in term.agent_id:
        _id = list(term.agent_id).index(id)
        done[id] = True
        next_goal_signal[id] = term.obs[GOAL_OBS][_id]
        next_state[id] = np.concatenate([term.obs[RAY_OBS][_id], term.obs[VECTOR_OBS][_id]], axis=-1)
        reward[id] = term.reward[_id]
    score += reward[0]

    if done[0]:
        episode +=1
        scores.append(score)
        score = 0

        # logging
        if episode % print_interval == 0:
            mean_score = np.mean(scores)
            mean_actor_loss = np.mean(actor_losses) if len(actor_losses) > 0 else 0
            mean_critic_loss = np.mean(critic_losses)  if len(critic_losses) > 0 else 0
            agent.write_summary(mean_score, mean_actor_loss, mean_critic_loss, step)
            actor_losses, critic_losses, scores = [], [], []

            print(f"{episode} Episode / Step: {step} / Score: {mean_score:.2f} / " +\
                    f"Actor loss: {mean_actor_loss:.2f} / Critic loss: {mean_critic_loss:.4f}" )

env.close()
# Out:
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# ... Load Model from /Users/hyunjae.k/110_HyunJae_Git/2025_Playgrounds/Unity_Robotics_Playgrounds/Agent_Scripts/temp/pytorch_output/saved_models/TwoMissions/Hyper_PPO/20250929155705/TwoMission_HyperPPO.ckpt ...
# 10 Episode / Step: 443 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 20 Episode / Step: 912 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 30 Episode / Step: 1463 / Score: 0.77 / Actor loss: 0.00 / Critic loss: 0.0000
# 40 Episode / Step: 1842 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 50 Episode / Step: 2339 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 60 Episode / Step: 2876 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 70 Episode / Step: 3494 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 80 Episode / Step: 4005 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 90 Episode / Step: 4440 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 100 Episode / Step: 4949 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 110 Episode / Step: 5464 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 120 Episode / Step: 6074 / Score: 0.97 / Actor loss: 0.00 / Critic loss: 0.0000
# 130 Episode / Step: 6523 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 140 Episode / Step: 7923 / Score: 0.83 / Actor loss: 0.00 / Critic loss: 0.0000
# 150 Episode / Step: 8403 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 160 Episode / Step: 8866 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
# 170 Episode / Step: 9302 / Score: 0.78 / Actor loss: 0.00 / Critic loss: 0.0000
# 180 Episode / Step: 9718 / Score: 0.98 / Actor loss: 0.00 / Critic loss: 0.0000
